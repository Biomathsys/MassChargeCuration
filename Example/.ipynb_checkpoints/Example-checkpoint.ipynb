# %% [markdown]
# # Usage example on model of _Corynebacterium tuberculostearicum (high GC Gram+)_.
# In this notebook we show how to use the Mass Charge Curation python package. As an example model we use a model of [_Corynebacterium tuberculostearicum (high GC Gram+)_, strain DSM 44922](https://www.ncbi.nlm.nih.gov/assembly/GCF_013408445.1/) created with [CarveMe Version 1.5.1](https://carveme.readthedocs.io/en/latest/index.html), which here is simply called _model.xml_.

# %% [markdown]
# If you are interested in a more verbose output you can uncomment the following line:

# %%
import logging; logging.basicConfig(format='%(levelname)s: %(filename)s %(lineno)d, %(funcName)s: %(message)s', level=logging.INFO)

# %% [markdown]
# ## Dependencies
# First we will check if all dependencies of the curation package are fullfilled.

# %%
try: import numpy
except Exception as e: print("You seem to be missing numpy. You can usually install it via 'pip install numpy'"); raise e
try: import pandas
except Exception as e: print("You seem to be missing pandas. You can usually install it via 'pip install pandas'"); raise e
try: import requests
except Exception as e: print("You seem to be missing requests. You can usually install it via 'pip install requests'"); raise e
try: import matplotlib
except Exception as e: print("You seem to be missing matplotlib. You can usually install it via 'pip install matplotlib'"); raise e
try: import z3
except Exception as e: print("You seem to be missing z3 or the corresponding python bindings. See https://github.com/Z3Prover/z3 on how to install it."); raise e

# %% [markdown]
# Next we see if the Mass Charge Curation package is installed properly.

# %%
try: import MCC
except Exception as e: print("The mass charge curation package does not seem to be installed correctly. Make sure you have the correct python version installed and try running pip install -e ./.. in the folder of this notebook."); raise e

# %% [markdown]
# ## Setting input path
# We can use the package with different type of models. Depending on what else we intend to do with the model we can already read it in using libsbml or cobraPy or immediatly pass in the path of the model (This will cause the module to read it in itself using libsbml).

# %%
model = "e_coli_core.xml"

# Alternatives:
# reading in the model beforehand using libsbml:
'''
import libsbml
reader = libsbml.SBMLReader()
document = reader.readSBML(model)
model = document.getModel()
'''
# reading in the model beforehand using cobraPy:
'''
import cobra
model = cobra.io.read_sbml_model(model)
'''
print(model)
# Out:
# e_coli_core.xml

# %% [markdown]
# ## Basic Model Information
# First we can take a quick look at the model using the module ModelInterface class:

# %%
mi = MCC.ModelInterface(model)
print(f"The model has {len(mi.metabolites)} metabolites and {len(mi.reactions)} reactions.")
unbalanced_reactions = [r_id for r_id, r in mi.reactions.items() if (not r.is_balanced())]
print(f"There are {len(unbalanced_reactions)} unbalanced reactions with {len(mi.get_pseudo_reactions())} pseudo reactions.")
# Out:
# The model has 72 metabolites and 95 reactions.
# There are 20 unbalanced reactions with 21 pseudo reactions.

# %% [markdown]
# ## Curating Mass and Charge
# We can now instantiate a curation class. There are different ways to use the package, depending how data should be gathered, how much curation has already been done and how much data is available offline.
#
# We will first give an example of the most simple usage, downloading as many databases as possible and updating all [identifiers.org](https://identifiers.org/) identifiers we need for the package to work optimally. This will take significantly longer (**~ 15 Minutes**) than running the algorithm on an already annotated model, however it is important to use the most up-to-date identifiers if we want to include as much information as possible.
#
# This will create a folder _/data_ in the current directory where all database information is downloaded to.
#
# The arguments are as follows:
# * **model**: Model we want to curate.
UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   balancer.generate_visual_report().show()

# %% [markdown]
# ### Metabolite Report
# The algorithm should be able to give a reason for every assignment that it chooses. We can have a look at these reasons in the metabolite report of the balancer.
#
# The report holds valuable information how the algorithm decided which assignment to choose and can be useful during further manual curation. The entries of the resulting DataFrame are the following:
# * **Id**: Id of the metabolite in the model.
# * **Name**: Name of the metabolite in the model.
# * **Determined Formula**: Formula that was assigned by the algorithm.
# * **Determined Charge**: Charge that was assigned by the algorithm.
# * **Previous Formula**: Formula that was assigned before the algorithm.
# * **Previous Charge**: Charge that was assigned before the algorithm.
# * **Inferrence Type**: Category of how the assignment was determined.
#     - Unconstrained: No information about the metabolite was found or only incomplete (wildcard containing) formulae were found and we could not find a concrete formula either. Should contain a wildcard.
#     - Inferred: No information about the metabolite was found or only incomplete (wildcard containing formulae were found, however we arrived at a concrete formula. Should not contain a wildcard.
#     - Clean: Information about the metabolite was found and used.
# * **Reasoning**: Reasoning how the assignment was determined. Can contain:
#     - database name:database identifier: The formula could be found in this database under this identifier.
#     - (unconstrained) Target: This assignment was chosen because it is the same as in the original (target) model. Unconstrained means that the original (target) model seemed to be missing a wildcard symbol that was thus added.
#     - Reaction_id (metabolite id -> Reasoning...): The assignment for this metabolite must follow from other reasons. The given reaction id and metabolite reasons make it so that if the model must be balanced, this metabolite must have the determined assignment.
#     - Used Databases: The databases which back up the determined assignment.
#     - Previous Databases: The databases which back up the previous assignment.

# %%
metabolite_report_df = balancer.generate_metabolite_report()
metabolite_report_df[::200]
# Out:
#            Id       Name Determined Formula  Determined Charge  \
# 0  M_lac__D_c  D-Lactate             C3H5O3                 -1
#
#   Previous Formula  Previous Charge Inferrence Type  \
# 0           C3H5O3               -1           Clean
#
#                                            Reasoning          Used Databases  \
# 0  unconstrained Target & Adherence & seed.compou...  seed.compound:cpd00221
#
#        Previous Databases Similarity
# 0  seed.compound:cpd00221       Same

# %% [markdown]
# Usually we are interested in the assignments which differ from the original report. We can do this by indexing the Dataframe accordingly.

# %%
# If you like to see the entire report, uncomment the following line
#pandas.set_option("display.max_row", None)
metabolite_report_df[metabolite_report_df["Similarity"] != "Same"]
# Out:
#          Id               Name Determined Formula  Determined Charge  \
# 71  M_adp_c  ADP C10H12N5O10P2      C10H13N5O10P2                 -2
#
#    Previous Formula  Previous Charge Inferrence Type               Reasoning  \
# 71    C10H12N5O10P2               -3           Clean  seed.compound:cpd00008
#
#             Used Databases Previous Databases   Similarity
# 71  seed.compound:cpd00008                     Proton Diff

# %% [markdown]
# We might also be interested in all assignments which are not backed by a database:

# %%
metabolite_report_df[metabolite_report_df["Used Databases"] == ""]
# Out:
# Empty DataFrame
# Columns: [Id, Name, Determined Formula, Determined Charge, Previous Formula, Previous Charge, Inferrence Type, Reasoning, Used Databases, Previous Databases, Similarity]
# Index: []

# %% [markdown]
# ### Reaction Report
# Finally, especially for further curation, we might be interested in the remaining imbalanced reactions. For this the algorithm can also provide a report.
#
# The report also includes reactions which are technically balanced but where many protons had to be added to arrive at that result.
#
# The fields are as follows:
# * **Id**: Id of the reaction in the model.
# * **Unbalanced Reaction**: Name of the reaction in the model and corresponding equation.
# * **Unbalanced Type**: Type of imbalance. Can be both Mass and charge, only mass, only charge or high proton count.
# * **Reason**: Set of reactions which caused the reaction to be imbalanced. This effectively means that these reactions could not be balanced together. The sets are minimal, but for example for BTS2, it would not help to remove HCYSMT, as BTS2 would require protons to have no charge and HCYSMT is only one of many reactions which then would not be balanced.
# * **Shared Metabolites**: Metabolites which are shared between the reactions which are listed in Reason. Can give an indication where the problem might lie.
# * **Mass Difference**: Mass imbalance.
# * **Charge Difference**: Charge imbalance.

# %%
balancer.generate_reaction_report()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0330e974ed7d> in <module>
# ----> 1 balancer.generate_reaction_report()
#
# ~/Systems Biology HiWi/MassChargeCuration/MCC/Balancing/MCC.py in generate_reaction_report(self, filename, proton_threshold)
#     165
#     166     def generate_reaction_report(self, filename=None, proton_threshold = 7):
# --> 167         return reaction_report(self, filename, proton_threshold)
#     168
#     169
#
# ~/Systems Biology HiWi/MassChargeCuration/MCC/ReportGeneration/reaction_report.py in reaction_report(curator, filename, proton_threshold)
#      36                                     "Charge Difference" : charge_balance
#      37             })
# ---> 38         elif curator.proton_adjusted_reactions[reaction.id] > proton_threshold:
#      39             reaction_report.append({"Id" : reaction.id,
#      40                                     "Unbalanced Reaction" : str(reaction),
#
# KeyError: 'R_PFL'

# %% [markdown]
# ### Writing Files
# The mass charge curation writes directly to the model that was given to it. Thus, if we want to write our model, we can just pass the model to cobrapy. If you want to keep your old model, you should make sure to not overwrite it here.

# %%
balancer.model_interface.write_model("model_MCC.xml")

# %% [markdown]
# For the reports, we can add filenames to the functions to write the visual report to a .png file and the metabolite and reaction DataFrames to .csv files.

# %%
balancer.generate_visual_report(f"{model}_visual")
balancer.generate_metabolite_report(f"{model}_metabolites")
balancer.generate_reaction_report(f"{model}_reactions")
pass

# %% [markdown]
# ## Fixing Assignments
# For some metabolites we might want to fix their assignment, based on some knowledge that is not encoded in the used databases or is not used as it will yield a (theoretically) suboptimal result. We can do this by passing a dictionary mapping the metabolites id to the fixed assignment. If, for example, we want the metabolite with the id "M_h2o_c" to have the certain formula "CO2" and charge of 5 and the metabolite with the id "M_h_c" have a formula of "C5" and a charge of -7, we can tell this to our algorithm in the following way:

# %%
fixed_assignments = {"M_h2o_c" : ("CO2", 5), "M_h_c" : ("C5", -7)}
balancer = MCC.MassChargeCuration(model = model, data_path = "./data", run_optimization = True, update_ids = False, fixed_assignments = fixed_assignments)
# Out:
# INFO: DataCollection.py 141, gather_info: 1/1019: Getting information for M_10fthf_c
# INFO: DataCollection.py 141, gather_info: 2/1019: Getting information for M_12dgr140_c
# INFO: DataCollection.py 141, gather_info: 3/1019: Getting information for M_12dgr140_p
# INFO: DataCollection.py 141, gather_info: 4/1019: Getting information for M_12dgr141_c
# INFO: satCore.py 63, resolve_unsat: [9.557 s] unsat cores were: [[R_FAO11], [R_KGD2], [R_SIRA2], [R_TNTR3], [R_TNTR4], [R_KAS2], [R_RHACOAE60, R_ACSPHAC60], [R_TMDS3, R_MTHFD], [R_MTHFR3, R_GLYCL], [R_MTHFR2, R_GHMT2r], [R_H2CO3D2, R_H2CO3D], [R_RHACOAE100, R_ACSPHAC100], [R_RHACOAE141, R_ACSPHAC141], [R_FACOAL140, R_FACOAE140], [R_PLIPA1E141pp, R_FACOAL141t2pp], [R_RHACOAE80, R_ACSPHAC80], [R_RHACOAE140, R_ACSPHAC140], [R_FACOAL141, R_FACOAE141], [R_TMDS, R_MOHMT], [R_AMPMS2, R_AHMMPS_1], [R_DASYN190190, R_CDAPPA190], [R_GLYCS_II, R_GLYCS_I], [R_HPPK2, R_DHPS2], [R_RNTR2, R_APSR], [R_SPODM], [R_GTPCII, R_DHPPDA], [R_HMR_0188, R_FACOAE120], [R_PAPSR, R_METSOXR2], [R_PRFGS], [R_THIORDXi, R_AHSERL4], [R_GLUTRS_2, R_GLUTRR], [R_FACOAL60t2pp, R_FACOAE60], [R_RHACOAE142, R_ACSPHAC142], [R_RHACOAEP90, R_ACSPHACP90], [R_RHACOAEP50, R_ACSPHACP50], [R_RHACOAEP60, R_ACSPHACP60], [R_TRDR, R_RNTR1], [R_FACOAL_70_c, R_FACOAE70], [R_PPAt4pp, R_PPAt2pp], [R_GLCS3_1, R_GLCP3], [R_RHACOAE141d5, R_ACSPHAC141d5], [R_RHACOAEP40, R_ACSPHACP40], [R_PRFGS_1], [R_RHACOAEP101, R_ACSPHAC101], [R_HMEDR], [R_RHACOAE70, R_ACSPHAC70], [R_MOTS3, R_MOTH3], [R_QMO2], [R_HMR_0260, R_FACOAL1812], [R_MELIBt3ipp, R_MELIBt2pp], [R_KAS7], [R_GTPCII2, R_DHPPDA2], [R_HPPK, R_DHNPA_1], [R_RHACOAE121, R_ACSPHAC121], [R_RNDR3b, R_GRXR], [R_RHACOAET60, R_ACSPHACT60], [R_FAO1], [R_BUTt4pp, R_BUTt2rpp], [R_RHACOAE90, R_ACSPHAC90], [R_RHACOAEP100, R_ACSPHACP100], [R_RHACOAE121d6, R_ACSPHAC121d6], [R_FACOAL161, R_FACOAE161], [R_FACOAL181t2pp, R_FACOAL181], [R_RHACOAEP80, R_ACSPHACP80], [R_FACOAL90i, R_FACOAE90], [R_RHACOAE120, R_ACSPHAC120], [R_RHACOAET40, R_ACSPHACT40], [R_RHACOAE50, R_ACSPHAC50], [R_MTHFD2i, R_GLYCL_2], [R_PEAt, R_PEALtabc], [R_DTBTST, R_BTS3r], [R_UGMDDS, R_UAAGDS], [R_RHACOAEP70, R_ACSPHACP70], [R_RHACOAE160, R_ACSPHAC160], [R_PAPA140pp, R_DAGK140, R_12DGR140tipp], [R_VECOAH, R_VCACT, R_HVCD], [R_FTHFLi], [R_CYO1_KT], [R_FAS120, R_FACOAL120t2pp, R_DDCAt2pp], [R_HMEDS, R_FPRA], [R_NADHXE, R_NADHXD, R_NADHHR], [R_NADPHXE, R_NADPHXD, R_NADPHHR], [R_PGPP181, R_PG181abcpp, R_CLPNS181pp, R_CLPNH181pp], [R_PYOVD2tex, R_FE3PYOVDL2, R_FE3PYOVDDR2, R_FE3PYOVD2tonex], [R_SMIA2abc, R_SMIA1Eabc, R_SMIA1]]
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_hmbpp_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_o2s_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_tntmmh_c. Setting it to 0.
# INFO: MCC.py 39, __init__: [56.586 s] Finished balancibility check. 752 non-pseudo reactions were unbalancable.
# INFO: MCC.py 46, __init__: [26.829 s] Finished adherence optimization.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_2agpe161_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_R_3h4atba_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_R_3h4atbcoa_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_R_3hphxa_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_R_3hphxacoa_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_abg4_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_air_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_ala_L_thr__L_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_ala_gln_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_ala_his_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_ala_leu_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_alagly_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_alahis_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_alaleu_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_alathr_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_alatrp_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_fpram_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_cys_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_cys_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_gln_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_leu_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_leu_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_met_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_phe_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_phe_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_tyr_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_gly_tyr_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_glygln_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_glyglu_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_glyglygln_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_glymet_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_glyser_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_hdcea_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_hisgly_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_hishis_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_lgt_s_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_lysglugly_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_nadhx__S_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_nadphx__S_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_nonacoa_c. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_serglugly_e. Setting it to 0.
# WARNING: fullBalancer.py 167, assign_from_solver: Could not find charge for metabolite M_ugmd_c. Setting it to 0.
# INFO: MCC.py 52, __init__: [25.779 s] Finished formula optimization.
# INFO: util.py 78, adjust_proton_count: added 29.0 protons to reaction R_FAS140
# INFO: util.py 78, adjust_proton_count: added 24.0 protons to reaction R_STAS
# INFO: util.py 78, adjust_proton_count: added 14.0 protons to reaction R_TNTR1
# INFO: util.py 78, adjust_proton_count: added 14.0 protons to reaction R_TNTR1x
# INFO: util.py 78, adjust_proton_count: added 14.0 protons to reaction R_TNTR2
# INFO: util.py 78, adjust_proton_count: added 14.0 protons to reaction R_TNTR2x

# %%
unbalanced_reactions = [r_id for r_id, r in balancer.model_interface.reactions.items() if (not r.is_balanced())]
print(f"There are {len(unbalanced_reactions)} unbalanced reactions with {len(balancer.model_interface.get_pseudo_reactions())} pseudo reactions.")
# Out:
# There are 963 unbalanced reactions with 196 pseudo reactions.

# %%
balancer.model_interface.metabolites["M_h2o_c"]
# Out:
# Metabolite(id='M_h2o_c', name='H2O H2O', formula=CO2, charge=5, SBO=247)

# %%
balancer.model_interface.metabolites["M_h_c"]
# Out:
# Metabolite(id='M_h_c', name='H+', formula=C5, charge=-7, SBO=247)

# %% [markdown]
# We can see that setting strange values for water and hydrogen will make many reactions unbalancable but that the balancer adheres to the fixed values.

# %% [markdown]
# ## Using BioCyc flat files
# If you have access (currently requires an explicit academic license or a subscription) and downloaded the BioCyc flat files, you can pass the corresponding directory as well. Assuming we have already updated all the ids in the last step, we can set _update_ids_ to _False_.
#
# The additional argument is:
# * **biocyc_path**: Directory containing BioCyc flat files.

# %%
balancer = MCC.MassChargeCuration(model = model, data_path = "./data", update_ids = True, biocyc_path = "./data/23.5/data")

# %% [markdown]
# # Usage example on model of _Corynebacterium tuberculostearicum (high GC Gram+)_.
# In this notebook we show how to use the Mass Charge Curation python package. As an example model we use a model of [_Corynebacterium tuberculostearicum (high GC Gram+)_, strain DSM 44922](https://www.ncbi.nlm.nih.gov/assembly/GCF_013408445.1/) created with [CarveMe Version 1.5.1](https://carveme.readthedocs.io/en/latest/index.html), which here is simply called _model.xml_.

# %% [markdown]
# If you are interested in a more verbose output you can uncomment the following line:

# %%
import logging; logging.basicConfig(format='%(levelname)s: %(filename)s %(lineno)d, %(funcName)s: %(message)s', level=logging.INFO)

# %% [markdown]
# ## Dependencies
# First we will check if all dependencies of the curation package are fullfilled.

# %%
try: import numpy
except Exception as e: print("You seem to be missing numpy. You can usually install it via 'pip install numpy'"); raise e
try: import pandas
except Exception as e: print("You seem to be missing pandas. You can usually install it via 'pip install pandas'"); raise e
try: import z3
except Exception as e: print("You seem to be missing z3 or the corresponding python bindings. See https://github.com/Z3Prover/z3 on how to install it."); raise e

# %% [markdown]
# Next we see if the Mass Charge Curation package is installed properly.

# %%
try: import MCC
except Exception as e: print("The mass charge curation package does not seem to be installed correctly. Make sure you have the correct python version installed and try running pip install -e ./.. in the folder of this notebook."); raise e

# %% [markdown]
# ## Loading the model
# Once all dependencies are installed, we can take a look at our example model.

# %% [markdown]
# First we will read in our model using cobrapy.

# %%
model = cobra.io.read_sbml_model("model.xml")
print(f"The model has {len(model.metabolites)} metabolites and {len(model.reactions)} reactions.")
# Out:
# The model has 1019 metabolites and 1481 reactions.

# %%
model.reactions.get_by_id("ACYP_2").annotation
# Out:
# {'sbo': 'SBO:0000176',
#  'ec-code': '3.6.1.7',
#  'metanetx.reaction': 'MNXR95427',
#  'kegg.reaction': 'R00317',
#  'seed.reaction': 'rxn00227'}

# %% [markdown]
# We can first take a look at how many reactions in our model are unbalanced.

# %% [markdown]
# ## Curating Mass and Charge
# We can now instantiate a curation class. There are different ways to use the package, depending how data should be gathered, how much curation has already been done and how much data is available offline.
#
# We will first give an example of the most simple usage, downloading as many databases as possible and updating all [identifiers.org](https://identifiers.org/) identifiers we need for the package to work optimally. This will take significantly longer (~ 15 Minutes) than running the algorithm on an already annotated model, however it is important to use the most up-to-date identifiers if we want to include as much information as possible.
#
# This will create a folder _/data_ in the current directory where all database information is downloaded to.
#
# The arguments are as follows:
# * **model**: Model we want to curate.
# * **data_path**: Path to the directory containing database files. Defaults to _/data_. If the directory does not exist, it will be created. If a file cannot be found, we will try to download it.
# * **update_ids**: If this is set to _True_, we will first try to update all [identifiers.org](https://identifiers.org/) ids. This will take a while but is important to properly index the different databases. Defaults to _False_.
#
# **Note**: It is expected to see _No objective coefficients in model. Unclear what should be optimized_ warnings here, this poses no problem for this package.

# %%
balancer = MCC.MassChargeCuration(model = model, data_path = "./data", run_optimization = True, update_ids = False)
# Out:
# INFO: DataCollection.py 137, gather_info: 1/1019: Getting information for 10fthf_c
# INFO: DataCollection.py 137, gather_info: 2/1019: Getting information for 12dgr140_c
# INFO: DataCollection.py 137, gather_info: 3/1019: Getting information for 12dgr140_p
# INFO: DataCollection.py 137, gather_info: 4/1019: Getting information for 12dgr141_c
# INFO: DataCollection.py 137, gather_info: 5/1019: Getting information for 12dgr141_p
# INFO: DataCollection.py 137, gather_info: 6/1019: Getting information for 12dgr160_c
# INFO: DataCollection.py 137, gather_info: 7/1019: Getting information for 12dgr160_e
# INFO: DataCollection.py 137, gather_info: 8/1019: Getting information for 12dgr160_p
# INFO: DataCollection.py 137, gather_info: 9/1019: Getting information for 12dgr180_c
# INFO: DataCollection.py 137, gather_info: 10/1019: Getting information for 12dgr180_e
# INFO: DataCollection.py 137, gather_info: 11/1019: Getting information for 12dgr180_p
# INFO: DataCollection.py 137, gather_info: 12/1019: Getting information for 12dgr181_c
# INFO: DataCollection.py 137, gather_info: 13/1019: Getting information for 12dgr181_p
# INFO: DataCollection.py 137, gather_info: 14/1019: Getting information for 12ppd__S_c
# INFO: DataCollection.py 137, gather_info: 15/1019: Getting information for 12ppd__S_e
# INFO: DataCollection.py 137, gather_info: 16/1019: Getting information for 13dpg_c
# INFO: DataCollection.py 137, gather_info: 17/1019: Getting information for 15dap_c
# INFO: DataCollection.py 137, gather_info: 18/1019: Getting information for 1ag160_e
# INFO: DataCollection.py 137, gather_info: 19/1019: Getting information for 1ag180_e
# INFO: DataCollection.py 137, gather_info: 20/1019: Getting information for 1ag181d9_e
# INFO: DataCollection.py 137, gather_info: 21/1019: Getting information for 1ag182d9d12_e
# INFO: DataCollection.py 137, gather_info: 22/1019: Getting information for 1p3h5c_c
# INFO: DataCollection.py 137, gather_info: 23/1019: Getting information for 1pyr5c_c
# INFO: DataCollection.py 137, gather_info: 24/1019: Getting information for 23dhdp_c
# INFO: DataCollection.py 137, gather_info: 25/1019: Getting information for 23dhmb_c
# INFO: DataCollection.py 137, gather_info: 26/1019: Getting information for 23dhmp_c
# INFO: DataCollection.py 137, gather_info: 27/1019: Getting information for 25aics_c
# INFO: DataCollection.py 137, gather_info: 28/1019: Getting information for 25dhpp_c
# INFO: DataCollection.py 137, gather_info: 29/1019: Getting information for 25drapp_c
# INFO: DataCollection.py 137, gather_info: 30/1019: Getting information for 26dap_LL_c
# INFO: DataCollection.py 137, gather_info: 31/1019: Getting information for 26dap__M_c
# INFO: DataCollection.py 137, gather_info: 32/1019: Getting information for 2agpe120_c
# INFO: DataCollection.py 137, gather_info: 33/1019: Getting information for 2agpe120_p
# INFO: DataCollection.py 137, gather_info: 34/1019: Getting information for 2agpe141_c
# INFO: DataCollection.py 137, gather_info: 35/1019: Getting information for 2agpe141_p
# INFO: DataCollection.py 137, gather_info: 36/1019: Getting information for 2agpe160_c
# INFO: DataCollection.py 137, gather_info: 37/1019: Getting information for 2agpe160_p
# INFO: DataCollection.py 137, gather_info: 38/1019: Getting information for 2agpe161_c
# INFO: DataCollection.py 137, gather_info: 39/1019: Getting information for 2agpe161_p
# INFO: DataCollection.py 137, gather_info: 40/1019: Getting information for 2agpg140_c
# INFO: DataCollection.py 137, gather_info: 41/1019: Getting information for 2agpg140_p
# INFO: DataCollection.py 137, gather_info: 42/1019: Getting information for 2agpg180_c
# INFO: DataCollection.py 137, gather_info: 43/1019: Getting information for 2agpg180_p
# INFO: DataCollection.py 137, gather_info: 44/1019: Getting information for 2ahbut_c
# INFO: DataCollection.py 137, gather_info: 45/1019: Getting information for 2ahhmd_c
# INFO: DataCollection.py 137, gather_info: 46/1019: Getting information for 2ahhmp_c
# INFO: DataCollection.py 137, gather_info: 47/1019: Getting information for 2aobut_c
# INFO: DataCollection.py 137, gather_info: 48/1019: Getting information for 2cpr5p_c
# INFO: DataCollection.py 137, gather_info: 49/1019: Getting information for 2dda7p_c
# INFO: DataCollection.py 137, gather_info: 50/1019: Getting information for 2dhp_c
# INFO: DataCollection.py 137, gather_info: 51/1019: Getting information for 2dmmq8_c
# INFO: DataCollection.py 137, gather_info: 52/1019: Getting information for 2dmmql8_c
# INFO: DataCollection.py 137, gather_info: 53/1019: Getting information for 2dr1p_c
# INFO: DataCollection.py 137, gather_info: 54/1019: Getting information for 2dr5p_c
# INFO: DataCollection.py 137, gather_info: 55/1019: Getting information for 2hadnt_c
# INFO: DataCollection.py 137, gather_info: 56/1019: Getting information for 2ippm_c
# INFO: DataCollection.py 137, gather_info: 57/1019: Getting information for 2m35mdntha_c
# INFO: DataCollection.py 137, gather_info: 58/1019: Getting information for 2m35mdntha_e
# INFO: DataCollection.py 137, gather_info: 59/1019: Getting information for 2mahmp_c
# INFO: DataCollection.py 137, gather_info: 60/1019: Getting information for 2mcacn_c
# INFO: DataCollection.py 137, gather_info: 61/1019: Getting information for 2mcit_c
# INFO: DataCollection.py 137, gather_info: 62/1019: Getting information for 2me4p_c
# INFO: DataCollection.py 137, gather_info: 63/1019: Getting information for 2mecdp_c
# INFO: DataCollection.py 137, gather_info: 64/1019: Getting information for 2obut_c
# INFO: DataCollection.py 137, gather_info: 65/1019: Getting information for 2p4c2me_c
# INFO: DataCollection.py 137, gather_info: 66/1019: Getting information for 2pg_c
# INFO: DataCollection.py 137, gather_info: 67/1019: Getting information for 2sephchc_c
# INFO: DataCollection.py 137, gather_info: 68/1019: Getting information for 2shchc_c
# INFO: DataCollection.py 137, gather_info: 69/1019: Getting information for 34hpp_c
# INFO: DataCollection.py 137, gather_info: 70/1019: Getting information for 35dnta_c
# INFO: DataCollection.py 137, gather_info: 71/1019: Getting information for 35dnta_e
# INFO: DataCollection.py 137, gather_info: 72/1019: Getting information for 3c2hmp_c
# INFO: DataCollection.py 137, gather_info: 73/1019: Getting information for 3c3hmp_c
# INFO: DataCollection.py 137, gather_info: 74/1019: Getting information for 3c4mop_c
# INFO: DataCollection.py 137, gather_info: 75/1019: Getting information for 3dhq_c
# INFO: DataCollection.py 137, gather_info: 76/1019: Getting information for 3dhsk_c
# INFO: DataCollection.py 137, gather_info: 77/1019: Getting information for 3hbcoa__R_c
# INFO: DataCollection.py 137, gather_info: 78/1019: Getting information for 3hbcoa_c
# INFO: DataCollection.py 137, gather_info: 79/1019: Getting information for 3hpcoa_c
# INFO: DataCollection.py 137, gather_info: 80/1019: Getting information for 3hptcoa_c
# INFO: DataCollection.py 137, gather_info: 81/1019: Getting information for 3ig3p_c
# INFO: DataCollection.py 137, gather_info: 82/1019: Getting information for 3mb_c
# INFO: DataCollection.py 137, gather_info: 83/1019: Getting information for 3mb_e
# INFO: DataCollection.py 137, gather_info: 84/1019: Getting information for 3mb_p
# INFO: DataCollection.py 137, gather_info: 85/1019: Getting information for 3mob_c
# INFO: DataCollection.py 137, gather_info: 86/1019: Getting information for 3mop_c
# INFO: DataCollection.py 137, gather_info: 87/1019: Getting information for 3opcoa_c
# INFO: DataCollection.py 137, gather_info: 88/1019: Getting information for 3optcoa_c
# INFO: DataCollection.py 137, gather_info: 89/1019: Getting information for 3pg_c
# INFO: DataCollection.py 137, gather_info: 90/1019: Getting information for 3php_c
# INFO: DataCollection.py 137, gather_info: 91/1019: Getting information for 3psme_c
# INFO: DataCollection.py 137, gather_info: 92/1019: Getting information for 4abut_c
# INFO: DataCollection.py 137, gather_info: 93/1019: Getting information for 4abut_e
# INFO: DataCollection.py 137, gather_info: 94/1019: Getting information for 4abut_p
# INFO: DataCollection.py 137, gather_info: 95/1019: Getting information for 4abz_c
# INFO: DataCollection.py 137, gather_info: 96/1019: Getting information for 4adcho_c
# INFO: DataCollection.py 137, gather_info: 97/1019: Getting information for 4ahmmp_c
# INFO: DataCollection.py 137, gather_info: 98/1019: Getting information for 4ahmmp_e
# INFO: DataCollection.py 137, gather_info: 99/1019: Getting information for 4ampm_c
# INFO: DataCollection.py 137, gather_info: 100/1019: Getting information for 4c2me_c
# INFO: DataCollection.py 137, gather_info: 101/1019: Getting information for 4hadnt_c
# INFO: DataCollection.py 137, gather_info: 102/1019: Getting information for 4hba_c
# INFO: DataCollection.py 137, gather_info: 103/1019: Getting information for 4hba_e
# INFO: DataCollection.py 137, gather_info: 104/1019: Getting information for 4hglusa_c
# INFO: DataCollection.py 137, gather_info: 105/1019: Getting information for 4hpro_LT_c
# INFO: DataCollection.py 137, gather_info: 106/1019: Getting information for 4izp_c
# INFO: DataCollection.py 137, gather_info: 107/1019: Getting information for 4mhetz_c
# INFO: DataCollection.py 137, gather_info: 108/1019: Getting information for 4mop_c
# INFO: DataCollection.py 137, gather_info: 109/1019: Getting information for 4mpetz_c
# INFO: DataCollection.py 137, gather_info: 110/1019: Getting information for 4pasp_c
# INFO: DataCollection.py 137, gather_info: 111/1019: Getting information for 4ppan_c
# INFO: DataCollection.py 137, gather_info: 112/1019: Getting information for 4ppcys_c
# INFO: DataCollection.py 137, gather_info: 113/1019: Getting information for 4r5au_c
# INFO: DataCollection.py 137, gather_info: 114/1019: Getting information for 5aizc_c
# INFO: DataCollection.py 137, gather_info: 115/1019: Getting information for 5aop_c
# INFO: DataCollection.py 137, gather_info: 116/1019: Getting information for 5aprbu_c
# INFO: DataCollection.py 137, gather_info: 117/1019: Getting information for 5apru_c
# INFO: DataCollection.py 137, gather_info: 118/1019: Getting information for 5aptn_c
# INFO: DataCollection.py 137, gather_info: 119/1019: Getting information for 5dglcn_c
# INFO: DataCollection.py 137, gather_info: 120/1019: Getting information for 5dglcn_e
# INFO: DataCollection.py 137, gather_info: 121/1019: Getting information for 5dglcn_p
# INFO: DataCollection.py 137, gather_info: 122/1019: Getting information for 5drib_c
# INFO: DataCollection.py 137, gather_info: 123/1019: Getting information for 5drib_e
# INFO: DataCollection.py 137, gather_info: 124/1019: Getting information for 5fthf_c
# INFO: DataCollection.py 137, gather_info: 125/1019: Getting information for 5mcsn_c
# INFO: DataCollection.py 137, gather_info: 126/1019: Getting information for 5mthf_c
# INFO: DataCollection.py 137, gather_info: 127/1019: Getting information for 6hmhpt_c
# INFO: DataCollection.py 137, gather_info: 128/1019: Getting information for 6hmhptpp_c
# INFO: DataCollection.py 137, gather_info: 129/1019: Getting information for 6pgc_c
# INFO: DataCollection.py 137, gather_info: 130/1019: Getting information for 6pgl_c
# INFO: DataCollection.py 137, gather_info: 131/1019: Getting information for LalaLglu_c
# INFO: DataCollection.py 137, gather_info: 132/1019: Getting information for LalaLglu_e
# INFO: DataCollection.py 137, gather_info: 133/1019: Getting information for LalaLglu_p
# INFO: DataCollection.py 137, gather_info: 134/1019: Getting information for R3hdec4coa_c
# INFO: DataCollection.py 137, gather_info: 135/1019: Getting information for R3hdec4e_c
# INFO: DataCollection.py 137, gather_info: 136/1019: Getting information for R_3h4atba_c
# INFO: DataCollection.py 137, gather_info: 137/1019: Getting information for R_3h4atbcoa_c
# INFO: DataCollection.py 137, gather_info: 138/1019: Getting information for R_3h6atha_c
# INFO: DataCollection.py 137, gather_info: 139/1019: Getting information for R_3h6athcoa_c
# INFO: DataCollection.py 137, gather_info: 140/1019: Getting information for R_3hcddec5ecoa_c
# INFO: DataCollection.py 137, gather_info: 141/1019: Getting information for R_3hcmrs7e_c
# INFO: DataCollection.py 137, gather_info: 142/1019: Getting information for R_3hcmrs7ecoa_c
# INFO: DataCollection.py 137, gather_info: 143/1019: Getting information for R_3hdcaa_c
# INFO: DataCollection.py 137, gather_info: 144/1019: Getting information for R_3hdcoa_c
# INFO: DataCollection.py 137, gather_info: 145/1019: Getting information for R_3hdd5ea_c
# INFO: DataCollection.py 137, gather_info: 146/1019: Getting information for R_3hdd6coa_c
# INFO: DataCollection.py 137, gather_info: 147/1019: Getting information for R_3hdd6e_c
# INFO: DataCollection.py 137, gather_info: 148/1019: Getting information for R_3hdda_c
# INFO: DataCollection.py 137, gather_info: 149/1019: Getting information for R_3hddcoa_c
# INFO: DataCollection.py 137, gather_info: 150/1019: Getting information for R_3hhcoa_c
# INFO: DataCollection.py 137, gather_info: 151/1019: Getting information for R_3hhdca_c
# INFO: DataCollection.py 137, gather_info: 152/1019: Getting information for R_3hhdcoa_c
# INFO: DataCollection.py 137, gather_info: 153/1019: Getting information for R_3hhpa_c
# INFO: DataCollection.py 137, gather_info: 154/1019: Getting information for R_3hhpcoa_c
# INFO: DataCollection.py 137, gather_info: 155/1019: Getting information for R_3hhxa_c
# INFO: DataCollection.py 137, gather_info: 156/1019: Getting information for R_3hhxa_e
# INFO: DataCollection.py 137, gather_info: 157/1019: Getting information for R_3hhxa_p
# INFO: DataCollection.py 137, gather_info: 158/1019: Getting information for R_3hmrscoa_c
# INFO: DataCollection.py 137, gather_info: 159/1019: Getting information for R_3hnonaa_c
# INFO: DataCollection.py 137, gather_info: 160/1019: Getting information for R_3hnonacoa_c
# INFO: DataCollection.py 137, gather_info: 161/1019: Getting information for R_3hocoa_c
# INFO: DataCollection.py 137, gather_info: 162/1019: Getting information for R_3hocta_c
# INFO: DataCollection.py 137, gather_info: 163/1019: Getting information for R_3hpba_c
# INFO: DataCollection.py 137, gather_info: 164/1019: Getting information for R_3hpbcoa_c
# INFO: DataCollection.py 137, gather_info: 165/1019: Getting information for R_3hpdeca_c
# INFO: DataCollection.py 137, gather_info: 166/1019: Getting information for R_3hpdecacoa_c
# INFO: DataCollection.py 137, gather_info: 167/1019: Getting information for R_3hphpa_c
# INFO: DataCollection.py 137, gather_info: 168/1019: Getting information for R_3hphpcoa_c
# INFO: DataCollection.py 137, gather_info: 169/1019: Getting information for R_3hphxa_c
# INFO: DataCollection.py 137, gather_info: 170/1019: Getting information for R_3hphxacoa_c
# INFO: DataCollection.py 137, gather_info: 171/1019: Getting information for R_3hpnona_c
# INFO: DataCollection.py 137, gather_info: 172/1019: Getting information for R_3hpnonacoa_c
# INFO: DataCollection.py 137, gather_info: 173/1019: Getting information for R_3hpocta_c
# INFO: DataCollection.py 137, gather_info: 174/1019: Getting information for R_3hpoctacoa_c
# INFO: DataCollection.py 137, gather_info: 175/1019: Getting information for R_3hppta_c
# INFO: DataCollection.py 137, gather_info: 176/1019: Getting information for R_3hpptcoa_c
# INFO: DataCollection.py 137, gather_info: 177/1019: Getting information for R_3hpt_c
# INFO: DataCollection.py 137, gather_info: 178/1019: Getting information for R_3hptcoa_c
# INFO: DataCollection.py 137, gather_info: 179/1019: Getting information for R_3htd58coa_c
# INFO: DataCollection.py 137, gather_info: 180/1019: Getting information for R_3htd58e_c
# INFO: DataCollection.py 137, gather_info: 181/1019: Getting information for R_3htd5coa_c
# INFO: DataCollection.py 137, gather_info: 182/1019: Getting information for R_3htd5e_c
# INFO: DataCollection.py 137, gather_info: 183/1019: Getting information for R_3httdca_c
# INFO: DataCollection.py 137, gather_info: 184/1019: Getting information for S2hglut_c
# INFO: DataCollection.py 137, gather_info: 185/1019: Getting information for aacald_c
# INFO: DataCollection.py 137, gather_info: 186/1019: Getting information for aacoa_c
# INFO: DataCollection.py 137, gather_info: 187/1019: Getting information for aact_c
# INFO: DataCollection.py 137, gather_info: 188/1019: Getting information for abg4_c
# INFO: DataCollection.py 137, gather_info: 189/1019: Getting information for abg4_e
# INFO: DataCollection.py 137, gather_info: 190/1019: Getting information for ac_c
# INFO: DataCollection.py 137, gather_info: 191/1019: Getting information for ac_e
# INFO: DataCollection.py 137, gather_info: 192/1019: Getting information for ac_p
# INFO: DataCollection.py 137, gather_info: 193/1019: Getting information for acald_c
# INFO: DataCollection.py 137, gather_info: 194/1019: Getting information for acald_e
# INFO: DataCollection.py 137, gather_info: 195/1019: Getting information for acald_p
# INFO: DataCollection.py 137, gather_info: 196/1019: Getting information for accoa_c
# INFO: DataCollection.py 137, gather_info: 197/1019: Getting information for acetol_c
# INFO: DataCollection.py 137, gather_info: 198/1019: Getting information for acg5p_c
# INFO: DataCollection.py 137, gather_info: 199/1019: Getting information for acg5sa_c
# INFO: DataCollection.py 137, gather_info: 200/1019: Getting information for acgam1p_c
# INFO: DataCollection.py 137, gather_info: 201/1019: Getting information for acgam6p_c
# INFO: DataCollection.py 137, gather_info: 202/1019: Getting information for acgam_e
# INFO: DataCollection.py 137, gather_info: 203/1019: Getting information for acglu_c
# INFO: DataCollection.py 137, gather_info: 204/1019: Getting information for acglu_e
# INFO: DataCollection.py 137, gather_info: 205/1019: Getting information for achms_c
# INFO: DataCollection.py 137, gather_info: 206/1019: Getting information for acmana_c
# INFO: DataCollection.py 137, gather_info: 207/1019: Getting information for acmanap_c
# INFO: DataCollection.py 137, gather_info: 208/1019: Getting information for acorn_c
# INFO: DataCollection.py 137, gather_info: 209/1019: Getting information for acser_c
# INFO: DataCollection.py 137, gather_info: 210/1019: Getting information for actn__R_c
# INFO: DataCollection.py 137, gather_info: 211/1019: Getting information for actn__R_e
# INFO: DataCollection.py 137, gather_info: 212/1019: Getting information for actp_c
# INFO: DataCollection.py 137, gather_info: 213/1019: Getting information for acysbmn_c
# INFO: DataCollection.py 137, gather_info: 214/1019: Getting information for acysbmn_e
# INFO: DataCollection.py 137, gather_info: 215/1019: Getting information for ade_c
# INFO: DataCollection.py 137, gather_info: 216/1019: Getting information for adhlam_c
# INFO: DataCollection.py 137, gather_info: 217/1019: Getting information for adn_c
# INFO: DataCollection.py 137, gather_info: 218/1019: Getting information for adp_c
# INFO: DataCollection.py 137, gather_info: 219/1019: Getting information for adpglc_c
# INFO: DataCollection.py 137, gather_info: 220/1019: Getting information for adprib_c
# INFO: DataCollection.py 137, gather_info: 221/1019: Getting information for ahcys_c
# INFO: DataCollection.py 137, gather_info: 222/1019: Getting information for ahdt_c
# INFO: DataCollection.py 137, gather_info: 223/1019: Getting information for aicar_c
# INFO: DataCollection.py 137, gather_info: 224/1019: Getting information for air_c
# INFO: DataCollection.py 137, gather_info: 225/1019: Getting information for akg_c
# INFO: DataCollection.py 137, gather_info: 226/1019: Getting information for ala_B_c
# INFO: DataCollection.py 137, gather_info: 227/1019: Getting information for ala_B_e
# INFO: DataCollection.py 137, gather_info: 228/1019: Getting information for ala_B_p
# INFO: DataCollection.py 137, gather_info: 229/1019: Getting information for ala_L_asp__L_c
# INFO: DataCollection.py 137, gather_info: 230/1019: Getting information for ala_L_asp__L_e
# INFO: DataCollection.py 137, gather_info: 231/1019: Getting information for ala_L_glu__L_c
# INFO: DataCollection.py 137, gather_info: 232/1019: Getting information for ala_L_glu__L_e
# INFO: DataCollection.py 137, gather_info: 233/1019: Getting information for ala_L_thr__L_c
# INFO: DataCollection.py 137, gather_info: 234/1019: Getting information for ala_L_thr__L_e
# INFO: DataCollection.py 137, gather_info: 235/1019: Getting information for ala__D_c
# INFO: DataCollection.py 137, gather_info: 236/1019: Getting information for ala__D_e
# INFO: DataCollection.py 137, gather_info: 237/1019: Getting information for ala__L_c
# INFO: DataCollection.py 137, gather_info: 238/1019: Getting information for ala__L_e
# INFO: DataCollection.py 137, gather_info: 239/1019: Getting information for ala_gln_c
# INFO: DataCollection.py 137, gather_info: 240/1019: Getting information for ala_gln_e
# INFO: DataCollection.py 137, gather_info: 241/1019: Getting information for ala_his_c
# INFO: DataCollection.py 137, gather_info: 242/1019: Getting information for ala_his_e
# INFO: DataCollection.py 137, gather_info: 243/1019: Getting information for ala_leu_c
# INFO: DataCollection.py 137, gather_info: 244/1019: Getting information for ala_leu_e
# INFO: DataCollection.py 137, gather_info: 245/1019: Getting information for alaala_c
# INFO: DataCollection.py 137, gather_info: 246/1019: Getting information for alac__S_c
# INFO: DataCollection.py 137, gather_info: 247/1019: Getting information for alagly_c
# INFO: DataCollection.py 137, gather_info: 248/1019: Getting information for alagly_e
# INFO: DataCollection.py 137, gather_info: 249/1019: Getting information for alahis_c
# INFO: DataCollection.py 137, gather_info: 250/1019: Getting information for alahis_e
# INFO: DataCollection.py 137, gather_info: 251/1019: Getting information for alahis_p
# INFO: DataCollection.py 137, gather_info: 252/1019: Getting information for alaleu_c
# INFO: DataCollection.py 137, gather_info: 253/1019: Getting information for alaleu_e
# INFO: DataCollection.py 137, gather_info: 254/1019: Getting information for alaleu_p
# INFO: DataCollection.py 137, gather_info: 255/1019: Getting information for alathr_c
# INFO: DataCollection.py 137, gather_info: 256/1019: Getting information for alathr_e
# INFO: DataCollection.py 137, gather_info: 257/1019: Getting information for alathr_p
# INFO: DataCollection.py 137, gather_info: 258/1019: Getting information for alatrp_c
# INFO: DataCollection.py 137, gather_info: 259/1019: Getting information for alatrp_e
# INFO: DataCollection.py 137, gather_info: 260/1019: Getting information for alatrp_p
# INFO: DataCollection.py 137, gather_info: 261/1019: Getting information for allphn_c
# INFO: DataCollection.py 137, gather_info: 262/1019: Getting information for alpro_c
# INFO: DataCollection.py 137, gather_info: 263/1019: Getting information for amet_c
# INFO: DataCollection.py 137, gather_info: 264/1019: Getting information for amp_c
# INFO: DataCollection.py 137, gather_info: 265/1019: Getting information for anth_c
# INFO: DataCollection.py 137, gather_info: 266/1019: Getting information for ap4a_c
# INFO: DataCollection.py 137, gather_info: 267/1019: Getting information for aps_c
# INFO: DataCollection.py 137, gather_info: 268/1019: Getting information for arab__D_c
# INFO: DataCollection.py 137, gather_info: 269/1019: Getting information for arab__D_p
# INFO: DataCollection.py 137, gather_info: 270/1019: Getting information for arab__L_c
# INFO: DataCollection.py 137, gather_info: 271/1019: Getting information for arab__L_p
# INFO: DataCollection.py 137, gather_info: 272/1019: Getting information for arbt6p_c
# INFO: DataCollection.py 137, gather_info: 273/1019: Getting information for arbt6p_e
# INFO: DataCollection.py 137, gather_info: 274/1019: Getting information for arbt_e
# INFO: DataCollection.py 137, gather_info: 275/1019: Getting information for arg__L_c
# INFO: DataCollection.py 137, gather_info: 276/1019: Getting information for arg__L_e
# INFO: DataCollection.py 137, gather_info: 277/1019: Getting information for arg__L_p
# INFO: DataCollection.py 137, gather_info: 278/1019: Getting information for argsuc_c
# INFO: DataCollection.py 137, gather_info: 279/1019: Getting information for asn__L_c
# INFO: DataCollection.py 137, gather_info: 280/1019: Getting information for asn__L_e
# INFO: DataCollection.py 137, gather_info: 281/1019: Getting information for asn__L_p
# INFO: DataCollection.py 137, gather_info: 282/1019: Getting information for aso3_c
# INFO: DataCollection.py 137, gather_info: 283/1019: Getting information for aso3_e
# INFO: DataCollection.py 137, gather_info: 284/1019: Getting information for aso3_p
# INFO: DataCollection.py 137, gather_info: 285/1019: Getting information for aso4_c
# INFO: DataCollection.py 137, gather_info: 286/1019: Getting information for aso4_p
# INFO: DataCollection.py 137, gather_info: 287/1019: Getting information for asp__L_c
# INFO: DataCollection.py 137, gather_info: 288/1019: Getting information for asp__L_e
# INFO: DataCollection.py 137, gather_info: 289/1019: Getting information for asp__L_p
# INFO: DataCollection.py 137, gather_info: 290/1019: Getting information for aspsa_c
# INFO: DataCollection.py 137, gather_info: 291/1019: Getting information for atp_c
# INFO: DataCollection.py 137, gather_info: 292/1019: Getting information for b2coa_c
# INFO: DataCollection.py 137, gather_info: 293/1019: Getting information for betald_c
# INFO: DataCollection.py 137, gather_info: 294/1019: Getting information for bhb_c
# INFO: DataCollection.py 137, gather_info: 295/1019: Getting information for bmn_c
# INFO: DataCollection.py 137, gather_info: 296/1019: Getting information for bmn_e
# INFO: DataCollection.py 137, gather_info: 297/1019: Getting information for bmnmsh_c
# INFO: DataCollection.py 137, gather_info: 298/1019: Getting information for btcoa_c
# INFO: DataCollection.py 137, gather_info: 299/1019: Getting information for btn_c
# INFO: DataCollection.py 137, gather_info: 300/1019: Getting information for but_c
# INFO: DataCollection.py 137, gather_info: 301/1019: Getting information for but_e
# INFO: DataCollection.py 137, gather_info: 302/1019: Getting information for but_p
# INFO: DataCollection.py 137, gather_info: 303/1019: Getting information for ca2_c
# INFO: DataCollection.py 137, gather_info: 304/1019: Getting information for ca2_e
# INFO: DataCollection.py 137, gather_info: 305/1019: Getting information for camp_c
# INFO: DataCollection.py 137, gather_info: 306/1019: Getting information for cbasp_c
# INFO: DataCollection.py 137, gather_info: 307/1019: Getting information for cbp_c
# INFO: DataCollection.py 137, gather_info: 308/1019: Getting information for cd2_c
# INFO: DataCollection.py 137, gather_info: 309/1019: Getting information for cd2_e
# INFO: DataCollection.py 137, gather_info: 310/1019: Getting information for cd2_p
# INFO: DataCollection.py 137, gather_info: 311/1019: Getting information for cdp_c
# INFO: DataCollection.py 137, gather_info: 312/1019: Getting information for cdpc16c19g_c
# INFO: DataCollection.py 137, gather_info: 313/1019: Getting information for cdpc19c19g_c
# INFO: DataCollection.py 137, gather_info: 314/1019: Getting information for cdpdhdecg_c
# INFO: DataCollection.py 137, gather_info: 315/1019: Getting information for cdpdodec11eg_c
# INFO: DataCollection.py 137, gather_info: 316/1019: Getting information for cdpdtdec7eg_c
# INFO: DataCollection.py 137, gather_info: 317/1019: Getting information for cgly_c
# INFO: DataCollection.py 137, gather_info: 318/1019: Getting information for cgly_e
# INFO: DataCollection.py 137, gather_info: 319/1019: Getting information for cgly_p
# INFO: DataCollection.py 137, gather_info: 320/1019: Getting information for chol_c
# INFO: DataCollection.py 137, gather_info: 321/1019: Getting information for chol_e
# INFO: DataCollection.py 137, gather_info: 322/1019: Getting information for chol_p
# INFO: DataCollection.py 137, gather_info: 323/1019: Getting information for chor_c
# INFO: DataCollection.py 137, gather_info: 324/1019: Getting information for cigam_c
# INFO: DataCollection.py 137, gather_info: 325/1019: Getting information for cit_c
# INFO: DataCollection.py 137, gather_info: 326/1019: Getting information for cit_e
# INFO: DataCollection.py 137, gather_info: 327/1019: Getting information for citr__L_c
# INFO: DataCollection.py 137, gather_info: 328/1019: Getting information for cl_c
# INFO: DataCollection.py 137, gather_info: 329/1019: Getting information for cl_e
# INFO: DataCollection.py 137, gather_info: 330/1019: Getting information for clpn141_p
# INFO: DataCollection.py 137, gather_info: 331/1019: Getting information for clpn160_p
# INFO: DataCollection.py 137, gather_info: 332/1019: Getting information for clpn181_p
# INFO: DataCollection.py 137, gather_info: 333/1019: Getting information for cmcbtt_c
# INFO: DataCollection.py 137, gather_info: 334/1019: Getting information for cmcbtt_e
# INFO: DataCollection.py 137, gather_info: 335/1019: Getting information for cmcbtt_p
# INFO: DataCollection.py 137, gather_info: 336/1019: Getting information for cmp_c
# INFO: DataCollection.py 137, gather_info: 337/1019: Getting information for cmp_e
# INFO: DataCollection.py 137, gather_info: 338/1019: Getting information for co2_c
# INFO: DataCollection.py 137, gather_info: 339/1019: Getting information for co2_e
# INFO: DataCollection.py 137, gather_info: 340/1019: Getting information for co2_p
# INFO: DataCollection.py 137, gather_info: 341/1019: Getting information for coa_c
# INFO: DataCollection.py 137, gather_info: 342/1019: Getting information for cobalt2_c
# INFO: DataCollection.py 137, gather_info: 343/1019: Getting information for cobalt2_e
# INFO: DataCollection.py 137, gather_info: 344/1019: Getting information for cobalt2_p
# INFO: DataCollection.py 137, gather_info: 345/1019: Getting information for cpppg3_c
# INFO: DataCollection.py 137, gather_info: 346/1019: Getting information for creat_c
# INFO: DataCollection.py 137, gather_info: 347/1019: Getting information for creat_e
# INFO: DataCollection.py 137, gather_info: 348/1019: Getting information for creat_p
# INFO: DataCollection.py 137, gather_info: 349/1019: Getting information for cro4_c
# INFO: DataCollection.py 137, gather_info: 350/1019: Getting information for cro4_p
# INFO: DataCollection.py 137, gather_info: 351/1019: Getting information for csn_c
# INFO: DataCollection.py 137, gather_info: 352/1019: Getting information for ctp_c
# INFO: DataCollection.py 137, gather_info: 353/1019: Getting information for cu2_c
# INFO: DataCollection.py 137, gather_info: 354/1019: Getting information for cu2_e
# INFO: DataCollection.py 137, gather_info: 355/1019: Getting information for cu2_p
# INFO: DataCollection.py 137, gather_info: 356/1019: Getting information for cys__L_c
# INFO: DataCollection.py 137, gather_info: 357/1019: Getting information for cys__L_e
# INFO: DataCollection.py 137, gather_info: 358/1019: Getting information for cys__L_p
# INFO: DataCollection.py 137, gather_info: 359/1019: Getting information for cyst__L_c
# INFO: DataCollection.py 137, gather_info: 360/1019: Getting information for cytd_c
# INFO: DataCollection.py 137, gather_info: 361/1019: Getting information for dad_2_c
# INFO: DataCollection.py 137, gather_info: 362/1019: Getting information for dad_5_c
# INFO: DataCollection.py 137, gather_info: 363/1019: Getting information for dadp_c
# INFO: DataCollection.py 137, gather_info: 364/1019: Getting information for dag181d9_e
# INFO: DataCollection.py 137, gather_info: 365/1019: Getting information for dag182d9d12_e
# INFO: DataCollection.py 137, gather_info: 366/1019: Getting information for damp_c
# INFO: DataCollection.py 137, gather_info: 367/1019: Getting information for datp_c
# INFO: DataCollection.py 137, gather_info: 368/1019: Getting information for db4p_c
# INFO: DataCollection.py 137, gather_info: 369/1019: Getting information for dca_c
# INFO: DataCollection.py 137, gather_info: 370/1019: Getting information for dca_e
# INFO: DataCollection.py 137, gather_info: 371/1019: Getting information for dca_p
# INFO: DataCollection.py 137, gather_info: 372/1019: Getting information for dcacoa_c
# INFO: DataCollection.py 137, gather_info: 373/1019: Getting information for dcamp_c
# INFO: DataCollection.py 137, gather_info: 374/1019: Getting information for dcdp_c
# INFO: DataCollection.py 137, gather_info: 375/1019: Getting information for dcmp_c
# INFO: DataCollection.py 137, gather_info: 376/1019: Getting information for dctp_c
# INFO: DataCollection.py 137, gather_info: 377/1019: Getting information for ddca_c
# INFO: DataCollection.py 137, gather_info: 378/1019: Getting information for ddca_e
# INFO: DataCollection.py 137, gather_info: 379/1019: Getting information for ddca_p
# INFO: DataCollection.py 137, gather_info: 380/1019: Getting information for ddcacoa_c
# INFO: DataCollection.py 137, gather_info: 381/1019: Getting information for decdp_c
# INFO: DataCollection.py 137, gather_info: 382/1019: Getting information for decdp_tb_c
# INFO: DataCollection.py 137, gather_info: 383/1019: Getting information for dgdp_c
# INFO: DataCollection.py 137, gather_info: 384/1019: Getting information for dgmp_c
# INFO: DataCollection.py 137, gather_info: 385/1019: Getting information for dgsn_c
# INFO: DataCollection.py 137, gather_info: 386/1019: Getting information for dgtp_c
# INFO: DataCollection.py 137, gather_info: 387/1019: Getting information for dha_c
# INFO: DataCollection.py 137, gather_info: 388/1019: Getting information for dhap_c
# INFO: DataCollection.py 137, gather_info: 389/1019: Getting information for dhf_c
# INFO: DataCollection.py 137, gather_info: 390/1019: Getting information for dhlam_c
# INFO: DataCollection.py 137, gather_info: 391/1019: Getting information for dhlpro_c
# INFO: DataCollection.py 137, gather_info: 392/1019: Getting information for dhna_c
# INFO: DataCollection.py 137, gather_info: 393/1019: Getting information for dhnpt_c
# INFO: DataCollection.py 137, gather_info: 394/1019: Getting information for dhor__S_c
# INFO: DataCollection.py 137, gather_info: 395/1019: Getting information for dhpmp_c
# INFO: DataCollection.py 137, gather_info: 396/1019: Getting information for dhpt_c
# INFO: DataCollection.py 137, gather_info: 397/1019: Getting information for dhptd_c
# INFO: DataCollection.py 137, gather_info: 398/1019: Getting information for dhptd_e
# INFO: DataCollection.py 137, gather_info: 399/1019: Getting information for din_c
# INFO: DataCollection.py 137, gather_info: 400/1019: Getting information for dmlz_c
# INFO: DataCollection.py 137, gather_info: 401/1019: Getting information for dmpp_c
# INFO: DataCollection.py 137, gather_info: 402/1019: Getting information for dnad_c
# INFO: DataCollection.py 137, gather_info: 403/1019: Getting information for dpcoa_c
# INFO: DataCollection.py 137, gather_info: 404/1019: Getting information for drib_c
# INFO: DataCollection.py 137, gather_info: 405/1019: Getting information for drib_e
# INFO: DataCollection.py 137, gather_info: 406/1019: Getting information for dscl_c
# INFO: DataCollection.py 137, gather_info: 407/1019: Getting information for dtbt_c
# INFO: DataCollection.py 137, gather_info: 408/1019: Getting information for dtdp_c
# INFO: DataCollection.py 137, gather_info: 409/1019: Getting information for dtmp_c
# INFO: DataCollection.py 137, gather_info: 410/1019: Getting information for dttp_c
# INFO: DataCollection.py 137, gather_info: 411/1019: Getting information for dudp_c
# INFO: DataCollection.py 137, gather_info: 412/1019: Getting information for dump_c
# INFO: DataCollection.py 137, gather_info: 413/1019: Getting information for duri_c
# INFO: DataCollection.py 137, gather_info: 414/1019: Getting information for dutp_c
# INFO: DataCollection.py 137, gather_info: 415/1019: Getting information for dxyl5p_c
# INFO: DataCollection.py 137, gather_info: 416/1019: Getting information for e4hglu_c
# INFO: DataCollection.py 137, gather_info: 417/1019: Getting information for e4p_c
# INFO: DataCollection.py 137, gather_info: 418/1019: Getting information for eig3p_c
# INFO: DataCollection.py 137, gather_info: 419/1019: Getting information for etha_c
# INFO: DataCollection.py 137, gather_info: 420/1019: Getting information for etha_e
# INFO: DataCollection.py 137, gather_info: 421/1019: Getting information for etoh_c
# INFO: DataCollection.py 137, gather_info: 422/1019: Getting information for etoh_p
# INFO: DataCollection.py 137, gather_info: 423/1019: Getting information for f1p_c
# INFO: DataCollection.py 137, gather_info: 424/1019: Getting information for f6p_c
# INFO: DataCollection.py 137, gather_info: 425/1019: Getting information for fad_c
# INFO: DataCollection.py 137, gather_info: 426/1019: Getting information for fadh2_c
# INFO: DataCollection.py 137, gather_info: 427/1019: Getting information for fald_c
# INFO: DataCollection.py 137, gather_info: 428/1019: Getting information for fald_p
# INFO: DataCollection.py 137, gather_info: 429/1019: Getting information for fcmcbtt_c
# INFO: DataCollection.py 137, gather_info: 430/1019: Getting information for fdp_c
# INFO: DataCollection.py 137, gather_info: 431/1019: Getting information for fdxox_c
# INFO: MetaNetX.py 58, get_assignments_by_id: Found for MNXM178 : ('Fe2S2*', nan)
# INFO: DataCollection.py 137, gather_info: 432/1019: Getting information for fdxrd_c
# INFO: DataCollection.py 137, gather_info: 433/1019: Getting information for fe2_c
# INFO: DataCollection.py 137, gather_info: 434/1019: Getting information for fe2_e
# INFO: DataCollection.py 137, gather_info: 435/1019: Getting information for fe2_p
# INFO: DataCollection.py 137, gather_info: 436/1019: Getting information for fe3_c
# INFO: DataCollection.py 137, gather_info: 437/1019: Getting information for fe3_e
# INFO: DataCollection.py 137, gather_info: 438/1019: Getting information for fe3_p
# INFO: DataCollection.py 137, gather_info: 439/1019: Getting information for fe3dcit_e
# INFO: DataCollection.py 137, gather_info: 440/1019: Getting information for fe3pyovd_kt_e
# INFO: DataCollection.py 137, gather_info: 441/1019: Getting information for fe3pyovd_kt_p
# INFO: DataCollection.py 137, gather_info: 442/1019: Getting information for fgam_c
# INFO: DataCollection.py 137, gather_info: 443/1019: Getting information for ficytc_c
# INFO: DataCollection.py 137, gather_info: 444/1019: Getting information for fmcbtt_c
# INFO: DataCollection.py 137, gather_info: 445/1019: Getting information for fmn_c
# INFO: DataCollection.py 137, gather_info: 446/1019: Getting information for fmnh2_c
# INFO: DataCollection.py 137, gather_info: 447/1019: Getting information for focytc_c
# INFO: DataCollection.py 137, gather_info: 448/1019: Getting information for fol_c
# INFO: DataCollection.py 137, gather_info: 449/1019: Getting information for fol_e
# INFO: DataCollection.py 137, gather_info: 450/1019: Getting information for for_c
# INFO: DataCollection.py 137, gather_info: 451/1019: Getting information for for_p
# INFO: DataCollection.py 137, gather_info: 452/1019: Getting information for forcoa_c
# INFO: DataCollection.py 137, gather_info: 453/1019: Getting information for forglu_c
# INFO: DataCollection.py 137, gather_info: 454/1019: Getting information for fpram_c
# INFO: DataCollection.py 137, gather_info: 455/1019: Getting information for fprica_c
# INFO: DataCollection.py 137, gather_info: 456/1019: Getting information for frdp_c
# INFO: DataCollection.py 137, gather_info: 457/1019: Getting information for frmd_c
# INFO: DataCollection.py 137, gather_info: 458/1019: Getting information for fru_c
# INFO: DataCollection.py 137, gather_info: 459/1019: Getting information for fru_e
# INFO: DataCollection.py 137, gather_info: 460/1019: Getting information for fru_p
# INFO: DataCollection.py 137, gather_info: 461/1019: Getting information for fum_c
# INFO: DataCollection.py 137, gather_info: 462/1019: Getting information for fum_e
# INFO: DataCollection.py 137, gather_info: 463/1019: Getting information for fum_p
# INFO: DataCollection.py 137, gather_info: 464/1019: Getting information for g1p_c
# INFO: DataCollection.py 137, gather_info: 465/1019: Getting information for g3p_c
# INFO: DataCollection.py 137, gather_info: 466/1019: Getting information for g6p_c
# INFO: DataCollection.py 137, gather_info: 467/1019: Getting information for gal1p_c
# INFO: DataCollection.py 137, gather_info: 468/1019: Getting information for gal_c
# INFO: DataCollection.py 137, gather_info: 469/1019: Getting information for gal_p
# INFO: DataCollection.py 137, gather_info: 470/1019: Getting information for gam1p_c
# INFO: DataCollection.py 137, gather_info: 471/1019: Getting information for gam6p_c
# INFO: DataCollection.py 137, gather_info: 472/1019: Getting information for gam_e
# INFO: DataCollection.py 137, gather_info: 473/1019: Getting information for gar_c
# INFO: DataCollection.py 137, gather_info: 474/1019: Getting information for gcald_c
# INFO: DataCollection.py 137, gather_info: 475/1019: Getting information for gcald_e
# INFO: DataCollection.py 137, gather_info: 476/1019: Getting information for gdp_c
# INFO: DataCollection.py 137, gather_info: 477/1019: Getting information for gdpmann_c
# INFO: DataCollection.py 137, gather_info: 478/1019: Getting information for gdptp_c
# INFO: DataCollection.py 137, gather_info: 479/1019: Getting information for ggdp_c
# INFO: DataCollection.py 137, gather_info: 480/1019: Getting information for glc__D_c
# INFO: DataCollection.py 137, gather_info: 481/1019: Getting information for glc__D_e
# INFO: DataCollection.py 137, gather_info: 482/1019: Getting information for glc__D_p
# INFO: DataCollection.py 137, gather_info: 483/1019: Getting information for glcn__D_c
# INFO: DataCollection.py 137, gather_info: 484/1019: Getting information for glcn__D_e
# INFO: DataCollection.py 137, gather_info: 485/1019: Getting information for glcn_c
# INFO: DataCollection.py 137, gather_info: 486/1019: Getting information for glcn_e
# INFO: DataCollection.py 137, gather_info: 487/1019: Getting information for glcn_p
# INFO: DataCollection.py 137, gather_info: 488/1019: Getting information for glcur_c
# INFO: DataCollection.py 137, gather_info: 489/1019: Getting information for glcur_e
# INFO: DataCollection.py 137, gather_info: 490/1019: Getting information for glcur_p
# INFO: DataCollection.py 137, gather_info: 491/1019: Getting information for gln__L_c
# INFO: DataCollection.py 137, gather_info: 492/1019: Getting information for gln__L_e
# INFO: DataCollection.py 137, gather_info: 493/1019: Getting information for glu1sa_c
# INFO: DataCollection.py 137, gather_info: 494/1019: Getting information for glu5p_c
# INFO: DataCollection.py 137, gather_info: 495/1019: Getting information for glu5sa_c
# INFO: DataCollection.py 137, gather_info: 496/1019: Getting information for glu__D_c
# INFO: DataCollection.py 137, gather_info: 497/1019: Getting information for glu__L_c
# INFO: DataCollection.py 137, gather_info: 498/1019: Getting information for glu__L_e
# INFO: DataCollection.py 137, gather_info: 499/1019: Getting information for glu__L_p
# INFO: DataCollection.py 137, gather_info: 500/1019: Getting information for glutar_c
# INFO: DataCollection.py 137, gather_info: 501/1019: Getting information for glutrna_c
# INFO: DataCollection.py 137, gather_info: 502/1019: Getting information for glx_c
# INFO: DataCollection.py 137, gather_info: 503/1019: Getting information for gly_asn__L_c
# INFO: DataCollection.py 137, gather_info: 504/1019: Getting information for gly_asn__L_e
# INFO: DataCollection.py 137, gather_info: 505/1019: Getting information for gly_asp__L_c
# INFO: DataCollection.py 137, gather_info: 506/1019: Getting information for gly_asp__L_e
# INFO: DataCollection.py 137, gather_info: 507/1019: Getting information for gly_c
# INFO: DataCollection.py 137, gather_info: 508/1019: Getting information for gly_cys_c
# INFO: DataCollection.py 137, gather_info: 509/1019: Getting information for gly_cys_e
# INFO: DataCollection.py 137, gather_info: 510/1019: Getting information for gly_e
# INFO: DataCollection.py 137, gather_info: 511/1019: Getting information for gly_gln_c
# INFO: DataCollection.py 137, gather_info: 512/1019: Getting information for gly_gln_e
# INFO: DataCollection.py 137, gather_info: 513/1019: Getting information for gly_glu__L_c
# INFO: DataCollection.py 137, gather_info: 514/1019: Getting information for gly_glu__L_e
# INFO: DataCollection.py 137, gather_info: 515/1019: Getting information for gly_leu_c
# INFO: DataCollection.py 137, gather_info: 516/1019: Getting information for gly_leu_e
# INFO: DataCollection.py 137, gather_info: 517/1019: Getting information for gly_met_c
# INFO: DataCollection.py 137, gather_info: 518/1019: Getting information for gly_met_e
# INFO: DataCollection.py 137, gather_info: 519/1019: Getting information for gly_phe_c
# INFO: DataCollection.py 137, gather_info: 520/1019: Getting information for gly_phe_e
# INFO: DataCollection.py 137, gather_info: 521/1019: Getting information for gly_pro__L_c
# INFO: DataCollection.py 137, gather_info: 522/1019: Getting information for gly_pro__L_e
# INFO: DataCollection.py 137, gather_info: 523/1019: Getting information for gly_tyr_c
# INFO: DataCollection.py 137, gather_info: 524/1019: Getting information for gly_tyr_e
# INFO: DataCollection.py 137, gather_info: 525/1019: Getting information for glyald_c
# INFO: DataCollection.py 137, gather_info: 526/1019: Getting information for glyald_e
# INFO: DataCollection.py 137, gather_info: 527/1019: Getting information for glyb_c
# INFO: DataCollection.py 137, gather_info: 528/1019: Getting information for glyb_e
# INFO: DataCollection.py 137, gather_info: 529/1019: Getting information for glyb_p
# INFO: DataCollection.py 137, gather_info: 530/1019: Getting information for glyc3p_c
# INFO: DataCollection.py 137, gather_info: 531/1019: Getting information for glyc3p_e
# INFO: DataCollection.py 137, gather_info: 532/1019: Getting information for glyc__R_c
# INFO: DataCollection.py 137, gather_info: 533/1019: Getting information for glyc_c
# INFO: DataCollection.py 137, gather_info: 534/1019: Getting information for glyc_e
# INFO: DataCollection.py 137, gather_info: 535/1019: Getting information for glyc_p
# INFO: DataCollection.py 137, gather_info: 536/1019: Getting information for glyclt_c
# INFO: DataCollection.py 137, gather_info: 537/1019: Getting information for glyclt_e
# INFO: DataCollection.py 137, gather_info: 538/1019: Getting information for glyclt_p
# INFO: DataCollection.py 137, gather_info: 539/1019: Getting information for glyg4n_c
# INFO: DataCollection.py 137, gather_info: 540/1019: Getting information for glygln_c
# INFO: DataCollection.py 137, gather_info: 541/1019: Getting information for glygln_e
# INFO: DataCollection.py 137, gather_info: 542/1019: Getting information for glygln_p
# INFO: DataCollection.py 137, gather_info: 543/1019: Getting information for glyglu_c
# INFO: DataCollection.py 137, gather_info: 544/1019: Getting information for glyglu_e
# INFO: DataCollection.py 137, gather_info: 545/1019: Getting information for glyglu_p
# INFO: DataCollection.py 137, gather_info: 546/1019: Getting information for glygly_c
# INFO: DataCollection.py 137, gather_info: 547/1019: Getting information for glygly_e
# INFO: DataCollection.py 137, gather_info: 548/1019: Getting information for glygly_p
# INFO: DataCollection.py 137, gather_info: 549/1019: Getting information for glyglygln_c
# INFO: DataCollection.py 137, gather_info: 550/1019: Getting information for glyglygln_e
# INFO: DataCollection.py 137, gather_info: 551/1019: Getting information for glymet_c
# INFO: DataCollection.py 137, gather_info: 552/1019: Getting information for glymet_e
# INFO: DataCollection.py 137, gather_info: 553/1019: Getting information for glymet_p
# INFO: DataCollection.py 137, gather_info: 554/1019: Getting information for glyphe_c
# INFO: DataCollection.py 137, gather_info: 555/1019: Getting information for glyphe_e
# INFO: DataCollection.py 137, gather_info: 556/1019: Getting information for glyphe_p
# INFO: DataCollection.py 137, gather_info: 557/1019: Getting information for glyser_c
# INFO: DataCollection.py 137, gather_info: 558/1019: Getting information for glyser_e
# INFO: DataCollection.py 137, gather_info: 559/1019: Getting information for glyser_p
# INFO: DataCollection.py 137, gather_info: 560/1019: Getting information for gmp_c
# INFO: DataCollection.py 137, gather_info: 561/1019: Getting information for grdp_c
# INFO: DataCollection.py 137, gather_info: 562/1019: Getting information for grxox_c
# INFO: DataCollection.py 137, gather_info: 563/1019: Getting information for grxrd_c
# INFO: DataCollection.py 137, gather_info: 564/1019: Getting information for gsn_c
# INFO: DataCollection.py 137, gather_info: 565/1019: Getting information for gthox_c
# INFO: DataCollection.py 137, gather_info: 566/1019: Getting information for gthrd_c
# ...
# INFO: DataCollection.py 137, gather_info: 836/1019: Getting information for pphn_c
# INFO: DataCollection.py 137, gather_info: 837/1019: Getting information for ppi_c
# INFO: DataCollection.py 137, gather_info: 838/1019: Getting information for ppp9_c
# INFO: DataCollection.py 137, gather_info: 839/1019: Getting information for pppg9_c
# INFO: DataCollection.py 137, gather_info: 840/1019: Getting information for pppi_c
# INFO: DataCollection.py 137, gather_info: 841/1019: Getting information for pprdn_c
# INFO: DataCollection.py 137, gather_info: 842/1019: Getting information for pqq_p
# INFO: DataCollection.py 137, gather_info: 843/1019: Getting information for pqqh2_p
# INFO: DataCollection.py 137, gather_info: 844/1019: Getting information for pram_c
# INFO: DataCollection.py 137, gather_info: 845/1019: Getting information for pran_c
# INFO: DataCollection.py 137, gather_info: 846/1019: Getting information for prbamp_c
# INFO: DataCollection.py 137, gather_info: 847/1019: Getting information for prbatp_c
# INFO: DataCollection.py 137, gather_info: 848/1019: Getting information for prfp_c
# INFO: DataCollection.py 137, gather_info: 849/1019: Getting information for prlp_c
# INFO: DataCollection.py 137, gather_info: 850/1019: Getting information for pro__L_c
# INFO: DataCollection.py 137, gather_info: 851/1019: Getting information for pro__L_e
# INFO: DataCollection.py 137, gather_info: 852/1019: Getting information for pro__L_p
# INFO: DataCollection.py 137, gather_info: 853/1019: Getting information for progly_c
# INFO: DataCollection.py 137, gather_info: 854/1019: Getting information for progly_e
# INFO: DataCollection.py 137, gather_info: 855/1019: Getting information for progly_p
# INFO: DataCollection.py 137, gather_info: 856/1019: Getting information for prpncoa_c
# INFO: DataCollection.py 137, gather_info: 857/1019: Getting information for prpp_c
# INFO: DataCollection.py 137, gather_info: 858/1019: Getting information for psd5p_c
# INFO: DataCollection.py 137, gather_info: 859/1019: Getting information for pser__L_c
# INFO: DataCollection.py 137, gather_info: 860/1019: Getting information for pt2coa_c
# INFO: DataCollection.py 137, gather_info: 861/1019: Getting information for pta_c
# INFO: DataCollection.py 137, gather_info: 862/1019: Getting information for pta_e
# INFO: DataCollection.py 137, gather_info: 863/1019: Getting information for pta_p
# INFO: DataCollection.py 137, gather_info: 864/1019: Getting information for ptcoa_c
# INFO: DataCollection.py 137, gather_info: 865/1019: Getting information for ptcys_c
# INFO: DataCollection.py 137, gather_info: 866/1019: Getting information for ptrc_c
# INFO: DataCollection.py 137, gather_info: 867/1019: Getting information for ptrc_e
# INFO: DataCollection.py 137, gather_info: 868/1019: Getting information for ptrc_p
# INFO: DataCollection.py 137, gather_info: 869/1019: Getting information for ptth_c
# INFO: DataCollection.py 137, gather_info: 870/1019: Getting information for pyam5p_c
# INFO: DataCollection.py 137, gather_info: 871/1019: Getting information for pydam_c
# INFO: DataCollection.py 137, gather_info: 872/1019: Getting information for pydx5p_c
# INFO: DataCollection.py 137, gather_info: 873/1019: Getting information for pydx_c
# INFO: DataCollection.py 137, gather_info: 874/1019: Getting information for pydxn_c
# INFO: DataCollection.py 137, gather_info: 875/1019: Getting information for pyovd_kt_e
# INFO: DataCollection.py 137, gather_info: 876/1019: Getting information for pyovd_kt_p
# INFO: DataCollection.py 137, gather_info: 877/1019: Getting information for pyr_c
# INFO: DataCollection.py 137, gather_info: 878/1019: Getting information for pyr_e
# INFO: DataCollection.py 137, gather_info: 879/1019: Getting information for pyr_p
# INFO: DataCollection.py 137, gather_info: 880/1019: Getting information for q8_c
# INFO: DataCollection.py 137, gather_info: 881/1019: Getting information for q8h2_c
# INFO: DataCollection.py 137, gather_info: 882/1019: Getting information for r1p_c
# INFO: DataCollection.py 137, gather_info: 883/1019: Getting information for r5p_c
# INFO: DataCollection.py 137, gather_info: 884/1019: Getting information for rhcys_c
# INFO: DataCollection.py 137, gather_info: 885/1019: Getting information for rib__D_c
# INFO: DataCollection.py 137, gather_info: 886/1019: Getting information for rib__D_e
# INFO: DataCollection.py 137, gather_info: 887/1019: Getting information for rib__D_p
# INFO: DataCollection.py 137, gather_info: 888/1019: Getting information for ribflv_c
# INFO: DataCollection.py 137, gather_info: 889/1019: Getting information for ribflv_e
# INFO: DataCollection.py 137, gather_info: 890/1019: Getting information for rnam_c
# INFO: DataCollection.py 137, gather_info: 891/1019: Getting information for ru5p__D_c
# INFO: DataCollection.py 137, gather_info: 892/1019: Getting information for s7p_c
# INFO: DataCollection.py 137, gather_info: 893/1019: Getting information for s_c
# INFO: DataCollection.py 137, gather_info: 894/1019: Getting information for s_e
# INFO: DataCollection.py 137, gather_info: 895/1019: Getting information for salc_c
# INFO: DataCollection.py 137, gather_info: 896/1019: Getting information for salc_e
# INFO: DataCollection.py 137, gather_info: 897/1019: Getting information for sarcs_c
# INFO: DataCollection.py 137, gather_info: 898/1019: Getting information for sbt__D_c
# INFO: DataCollection.py 137, gather_info: 899/1019: Getting information for sbt__D_e
# INFO: DataCollection.py 137, gather_info: 900/1019: Getting information for sbzcoa_c
# INFO: DataCollection.py 137, gather_info: 901/1019: Getting information for scl_c
# INFO: DataCollection.py 137, gather_info: 902/1019: Getting information for sdhlam_c
# INFO: DataCollection.py 137, gather_info: 903/1019: Getting information for ser__D_c
# INFO: DataCollection.py 137, gather_info: 904/1019: Getting information for ser__L_c
# INFO: DataCollection.py 137, gather_info: 905/1019: Getting information for ser__L_e
# INFO: DataCollection.py 137, gather_info: 906/1019: Getting information for ser__L_p
# INFO: DataCollection.py 137, gather_info: 907/1019: Getting information for serglugly_c
# INFO: DataCollection.py 137, gather_info: 908/1019: Getting information for serglugly_e
# INFO: DataCollection.py 137, gather_info: 909/1019: Getting information for sheme_c
# INFO: DataCollection.py 137, gather_info: 910/1019: Getting information for skm5p_c
# INFO: DataCollection.py 137, gather_info: 911/1019: Getting information for skm_c
# INFO: DataCollection.py 137, gather_info: 912/1019: Getting information for sl26da_c
# INFO: DataCollection.py 137, gather_info: 913/1019: Getting information for sl2a6o_c
# INFO: DataCollection.py 137, gather_info: 914/1019: Getting information for so3_c
# INFO: DataCollection.py 137, gather_info: 915/1019: Getting information for so3_e
# INFO: DataCollection.py 137, gather_info: 916/1019: Getting information for so3_p
# INFO: DataCollection.py 137, gather_info: 917/1019: Getting information for so4_c
# INFO: DataCollection.py 137, gather_info: 918/1019: Getting information for so4_e
# INFO: DataCollection.py 137, gather_info: 919/1019: Getting information for spmd_c
# INFO: DataCollection.py 137, gather_info: 920/1019: Getting information for spmd_e
# INFO: DataCollection.py 137, gather_info: 921/1019: Getting information for spmd_p
# INFO: DataCollection.py 137, gather_info: 922/1019: Getting information for stcoa_c
# INFO: DataCollection.py 137, gather_info: 923/1019: Getting information for stfrnA_c
# INFO: DataCollection.py 137, gather_info: 924/1019: Getting information for stfrnA_e
# INFO: DataCollection.py 137, gather_info: 925/1019: Getting information for stfrnB_e
# INFO: DataCollection.py 137, gather_info: 926/1019: Getting information for suc6p_c
# INFO: DataCollection.py 137, gather_info: 927/1019: Getting information for sucbz_c
# INFO: DataCollection.py 137, gather_info: 928/1019: Getting information for succ_c
# INFO: DataCollection.py 137, gather_info: 929/1019: Getting information for succ_e
# INFO: DataCollection.py 137, gather_info: 930/1019: Getting information for succ_p
# INFO: DataCollection.py 137, gather_info: 931/1019: Getting information for succoa_c
# INFO: DataCollection.py 137, gather_info: 932/1019: Getting information for suchms_c
# INFO: DataCollection.py 137, gather_info: 933/1019: Getting information for sucr_e
# INFO: DataCollection.py 137, gather_info: 934/1019: Getting information for sucsal_c
# INFO: DataCollection.py 137, gather_info: 935/1019: Getting information for tag160_e
# INFO: DataCollection.py 137, gather_info: 936/1019: Getting information for tag180_e
# INFO: DataCollection.py 137, gather_info: 937/1019: Getting information for tag181d9_e
# INFO: DataCollection.py 137, gather_info: 938/1019: Getting information for tag182d9d12_e
# INFO: DataCollection.py 137, gather_info: 939/1019: Getting information for tartr__D_c
# INFO: DataCollection.py 137, gather_info: 940/1019: Getting information for tartr__D_p
# INFO: DataCollection.py 137, gather_info: 941/1019: Getting information for taur_c
# INFO: DataCollection.py 137, gather_info: 942/1019: Getting information for taur_e
# INFO: DataCollection.py 137, gather_info: 943/1019: Getting information for tdcoa_c
# INFO: DataCollection.py 137, gather_info: 944/1019: Getting information for tdecoa_c
# INFO: DataCollection.py 137, gather_info: 945/1019: Getting information for thdp_c
# INFO: DataCollection.py 137, gather_info: 946/1019: Getting information for thf_c
# INFO: DataCollection.py 137, gather_info: 947/1019: Getting information for thm_c
# INFO: DataCollection.py 137, gather_info: 948/1019: Getting information for thm_e
# INFO: DataCollection.py 137, gather_info: 949/1019: Getting information for thmmp_c
# INFO: DataCollection.py 137, gather_info: 950/1019: Getting information for thmpp_c
# INFO: DataCollection.py 137, gather_info: 951/1019: Getting information for thr__L_c
# INFO: DataCollection.py 137, gather_info: 952/1019: Getting information for thr__L_e
# INFO: DataCollection.py 137, gather_info: 953/1019: Getting information for thr__L_p
# INFO: DataCollection.py 137, gather_info: 954/1019: Getting information for thrp_c
# INFO: DataCollection.py 137, gather_info: 955/1019: Getting information for thym_c
# INFO: DataCollection.py 137, gather_info: 956/1019: Getting information for thym_e
# INFO: DataCollection.py 137, gather_info: 957/1019: Getting information for thymd_c
# INFO: DataCollection.py 137, gather_info: 958/1019: Getting information for tnt_c
# INFO: DataCollection.py 137, gather_info: 959/1019: Getting information for tnt_e
# INFO: DataCollection.py 137, gather_info: 960/1019: Getting information for tnt_p
# INFO: DataCollection.py 137, gather_info: 961/1019: Getting information for tntmdh_c
# INFO: DataCollection.py 137, gather_info: 962/1019: Getting information for tntmmh_c
# INFO: DataCollection.py 137, gather_info: 963/1019: Getting information for trdox_c
# INFO: DataCollection.py 137, gather_info: 964/1019: Getting information for trdrd_c
# INFO: DataCollection.py 137, gather_info: 965/1019: Getting information for tre6p_c
# INFO: DataCollection.py 137, gather_info: 966/1019: Getting information for tre_c
# INFO: DataCollection.py 137, gather_info: 967/1019: Getting information for tre_e
# INFO: DataCollection.py 137, gather_info: 968/1019: Getting information for trnaglu_c
# INFO: DataCollection.py 137, gather_info: 969/1019: Getting information for trp__L_c
# INFO: DataCollection.py 137, gather_info: 970/1019: Getting information for trp__L_e
# INFO: DataCollection.py 137, gather_info: 971/1019: Getting information for tsul_c
# INFO: DataCollection.py 137, gather_info: 972/1019: Getting information for tsul_e
# INFO: DataCollection.py 137, gather_info: 973/1019: Getting information for ttdca_c
# INFO: DataCollection.py 137, gather_info: 974/1019: Getting information for ttdca_p
# INFO: DataCollection.py 137, gather_info: 975/1019: Getting information for ttdcea_c
# INFO: DataCollection.py 137, gather_info: 976/1019: Getting information for ttdcea_p
# INFO: DataCollection.py 137, gather_info: 977/1019: Getting information for tyr__L_c
# INFO: DataCollection.py 137, gather_info: 978/1019: Getting information for tyr__L_e
# INFO: DataCollection.py 137, gather_info: 979/1019: Getting information for uaGgla_c
# INFO: DataCollection.py 137, gather_info: 980/1019: Getting information for uaaGgla_c
# INFO: DataCollection.py 137, gather_info: 981/1019: Getting information for uaagmda_c
# INFO: DataCollection.py 137, gather_info: 982/1019: Getting information for uaccg_c
# INFO: DataCollection.py 137, gather_info: 983/1019: Getting information for uacgam_c
# INFO: DataCollection.py 137, gather_info: 984/1019: Getting information for uagmda_c
# INFO: DataCollection.py 137, gather_info: 985/1019: Getting information for uama_c
# INFO: DataCollection.py 137, gather_info: 986/1019: Getting information for uamag_c
# INFO: DataCollection.py 137, gather_info: 987/1019: Getting information for uamr_c
# INFO: DataCollection.py 137, gather_info: 988/1019: Getting information for udcpdp_c
# INFO: DataCollection.py 137, gather_info: 989/1019: Getting information for udcpp_c
# INFO: DataCollection.py 137, gather_info: 990/1019: Getting information for udp_c
# INFO: DataCollection.py 137, gather_info: 991/1019: Getting information for udpg_c
# INFO: DataCollection.py 137, gather_info: 992/1019: Getting information for udpgal_c
# INFO: DataCollection.py 137, gather_info: 993/1019: Getting information for ugmd_c
# INFO: DataCollection.py 137, gather_info: 994/1019: Getting information for ugmda_c
# INFO: DataCollection.py 137, gather_info: 995/1019: Getting information for ump_c
# INFO: DataCollection.py 137, gather_info: 996/1019: Getting information for uppg3_c
# INFO: DataCollection.py 137, gather_info: 997/1019: Getting information for ura_c
# INFO: DataCollection.py 137, gather_info: 998/1019: Getting information for ura_e
# INFO: DataCollection.py 137, gather_info: 999/1019: Getting information for ura_p
# INFO: DataCollection.py 137, gather_info: 1000/1019: Getting information for urcan_c
# INFO: DataCollection.py 137, gather_info: 1001/1019: Getting information for urea_c
# INFO: DataCollection.py 137, gather_info: 1002/1019: Getting information for uri_c
# INFO: DataCollection.py 137, gather_info: 1003/1019: Getting information for utp_c
# INFO: DataCollection.py 137, gather_info: 1004/1019: Getting information for vacc_c
# INFO: DataCollection.py 137, gather_info: 1005/1019: Getting information for vacccoa_c
# INFO: DataCollection.py 137, gather_info: 1006/1019: Getting information for val__L_c
# INFO: DataCollection.py 137, gather_info: 1007/1019: Getting information for val__L_e
# INFO: DataCollection.py 137, gather_info: 1008/1019: Getting information for xan_c
# INFO: DataCollection.py 137, gather_info: 1009/1019: Getting information for xan_e
# INFO: DataCollection.py 137, gather_info: 1010/1019: Getting information for xan_p
# INFO: DataCollection.py 137, gather_info: 1011/1019: Getting information for xmp_c
# INFO: DataCollection.py 137, gather_info: 1012/1019: Getting information for xtp_c
# INFO: DataCollection.py 137, gather_info: 1013/1019: Getting information for xtsn_c
# INFO: DataCollection.py 137, gather_info: 1014/1019: Getting information for xu5p__D_c
# INFO: DataCollection.py 137, gather_info: 1015/1019: Getting information for xyl__D_c
# INFO: DataCollection.py 137, gather_info: 1016/1019: Getting information for xyl__D_e
# INFO: DataCollection.py 137, gather_info: 1017/1019: Getting information for zn2_c
# INFO: DataCollection.py 137, gather_info: 1018/1019: Getting information for zn2_e
# INFO: DataCollection.py 137, gather_info: 1019/1019: Getting information for zn2_p
# INFO: MCC.py 33, __init__: [17.349 s] Finished constructing model.
# INFO: satCore.py 63, resolve_unsat: [0.758 s] unsat cores were: [[ANS2, AMPTASEPG], [FE3DCITabc], [DHNAOT], [MECDPDH, HMPPtr, ASAD], [CYO1b], [CYO1_KT], [HMEDS, HMEDR, FPRA]]
# INFO: MCC.py 36, __init__: [22.144 s] Finished balancibility check. 20 non-pseudo reactions were unbalancable.
# INFO: MCC.py 43, __init__: [26.604 s] Finished adherence optimization.
# INFO: MCC.py 49, __init__: [54.703 s] Finished formula optimization.

# %%
balancer.generate_metabolite_report(f"{model.id}_metabolites")
# Out:
#               Id                                               Name  \
# 0     12dgr140_c  1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 1     12dgr140_p  1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 2       1ag160_e                  1 Acyl sn glycerol  hexadecanoate
# 3       1ag180_e                  1 Acyl sn glycerol  octadecanoate
# 4     1ag181d9_e                        1 Acyl sn glycerol  nC181d9
# ...          ...                                                ...
# 1014     gdptp_c           Guanosine 3'-diphosphate 5'-triphosphate
# 1015       pqq_p                           Pyrroloquinoline-quinone
# 1016    ribflv_c                              Riboflavin C17H20N4O6
# 1017    ribflv_e                              Riboflavin C17H20N4O6
# 1018    uaGgla_c  Undecaprenyl-diphospho-N-acetylmuramoyl-L-alan...
#
#      Determined Formula  Determined Charge Previous Formula  Previous Charge  \
# 0              C31H60O5                  0         C31H60O5                0
# 1              C31H60O5                  0         C31H60O5                0
# 2              C19H38O4                  0         C19H38O4                0
# 3              C21H42O4                  0         C21H42O4                0
# 4              C21H40O4                  0         C21H40O4                0
# ...                 ...                ...              ...              ...
# 1014      C10H12N5O20P5                 -6    C10H11N5O20P5                0
# 1015          C14H3N2O8                 -3        C14H2N2O8                0
# 1016         C17H19N4O6                 -1       C17H22N4O6                0
# 1017         C17H19N4O6                 -1       C17H22N4O6                0
# 1018     C86H140N7O21P2                 -3   C86H142N7O21P2                0
#
#      Inferrence Type                                          Reasoning  \
# 0           Inferred                                             Target
# 1           Inferred                                             Target
# 2           Inferred                                             Target
# 3           Inferred                                             Target
# 4           Inferred                                             Target
# ...              ...                                                ...
# 1014           Clean  seed.compound:cpd02740, biocyc:META:GDP-TP, me...
# 1015           Clean  seed.compound:cpd00097, metanetx.chemical:MNXM...
# 1016           Clean  metanetx.chemical:MNXM270, seed.compound:cpd00...
# 1017           Clean  metanetx.chemical:MNXM270, seed.compound:cpd00...
# 1018           Clean  seed.compound:cpd02948, seed.compound:cpd22489...
#
#                                          Used Databases Previous Databases  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...                ...
# 1014  seed.compound:cpd02740, biocyc:META:GDP-TP, me...
# 1015  seed.compound:cpd00097, metanetx.chemical:MNXM...
# 1016  metanetx.chemical:MNXM270, seed.compound:cpd00...
# 1017  metanetx.chemical:MNXM270, seed.compound:cpd00...
# 1018  seed.compound:cpd02948, seed.compound:cpd22489...
#
#      Similarity
# 0          Same
# 1          Same
# 2          Same
# 3          Same
# 4          Same
# ...         ...
# 1014       Diff
# 1015       Diff
# 1016       Diff
# 1017       Diff
# 1018       Diff
#
# [1019 rows x 11 columns]

# %%
from MCC import Formula

# %%
f1 = Formula("CCcFe2FoMS6")
f2 = Formula("Fe2S6")
f1 == f2
# Out:
# False

# %%
"growth".upper()
# Out:
# 'GROWTH'

# %%
balancer.generate_reaction_report(f"{model.id}_reactions")
# Out:
#             Id                                Unbalanced Reaction  \
# 0      CMCBTFL  Reaction(id='CMCBTFL', name='CMCBTFL', metabol...
# 1      CMCBTFU  Reaction(id='CMCBTFU', name='CMCBTFU', metabol...
# 2      CYO1_KT  Reaction(id='CYO1_KT', name='Ubiquinol   cytoc...
# 3        CYO1b  Reaction(id='CYO1b', name='CYO1b', metabolites...
# 4        FCLT2  Reaction(id='FCLT2', name='FCLT2', metabolites...
# 5   FE3DCITabc  Reaction(id='FE3DCITabc', name='Iron transport...
# 6      FETRANS  Reaction(id='FETRANS', name='FETRANS', metabol...
# 7        CREAT  Reaction(id='CREAT', name='Creatinase', metabo...
# 8       MCBTS3  Reaction(id='MCBTS3', name='MCBTS3', metabolit...
# 9        MYCTR  Reaction(id='MYCTR', name='MYCTR', metabolites...
# 10      MYCTR2  Reaction(id='MYCTR2', name='MYCTR2', metabolit...
# 11   AMPTASEPG  Reaction(id='AMPTASEPG', name='Aminopeptidase ...
# 12        FPRA  Reaction(id='FPRA', name='R01195', metabolites...
# 13      AMMQT8  Reaction(id='AMMQT8', name='S-adenosylmethione...
# 14     BMNMSHS  Reaction(id='BMNMSHS', name='BMNMSHS', metabol...
# 15        BTS2  Reaction(id='BTS2', name='Biotin synthase (ala...
# 16      DHNAOT  Reaction(id='DHNAOT', name='1,4-dihydroxy-2-na...
# 17      DTBTST  Reaction(id='DTBTST', name='', metabolites={Me...
# 18         NMO  Reaction(id='NMO', name='Nitronate Monooxygena...
# 19     MECDPDH  Reaction(id='MECDPDH', name='2C-methyl-D-eryth...
#
#    Unbalanced Type                 Reason  \
# 0     Mass, Charge                CMCBTFL
# 1     Mass, Charge                CMCBTFU
# 2     Mass, Charge                CYO1_KT
# 3     Mass, Charge                  CYO1b
# 4     Mass, Charge                  FCLT2
# 5     Mass, Charge             FE3DCITabc
# 6     Mass, Charge                FETRANS
# 7             Mass                  CREAT
# 8             Mass                 MCBTS3
# 9             Mass                  MYCTR
# 10            Mass                 MYCTR2
# 11            Mass        ANS2, AMPTASEPG
# 12            Mass     HMEDS, HMEDR, FPRA
# 13          Charge                 AMMQT8
# 14          Charge                BMNMSHS
# 15          Charge                   BTS2
# 16          Charge                 DHNAOT
# 17          Charge                 DTBTST
# 18          Charge                    NMO
# 19          Charge  MECDPDH, HMPPtr, ASAD
#
#                                    Shared Metabolites  \
# 0                          cmcbtt_c, fcmcbtt_c, fe3_e
# 1                     h_c, cmcbtt_c, fcmcbtt_c, fe3_c
# 2          h_c, q8h2_c, focytc_c, ficytc_c, q8_c, h_p
# 3                     h2o_c, ficytc_c, focytc_c, o2_c
# 4             h_c, ppp9_c, fmcbtt_c, pheme_c, mcbtt_c
# 5   h2o_c, fe3dcit_e, cit_c, h_c, pi_c, adp_c, fe3...
# 6                            mcbtt_c, fmcbtt_c, fe2_c
# 7                     h2o_c, creat_c, urea_c, sarcs_c
# 8   h2o_c, nadp_c, o2_c, lys__L_c, cmcbtt_c, co2_c...
# 9                 h_c, nadp_c, msh_c, nadph_c, mssg_c
# 10               h_c, msh_c, gthrd_c, mssg_c, gthox_c
# 11                                              h2o_c
# 12                                                h_c
# 13             h_c, 2dmmq8_c, mql8_c, ahcys_c, amet_c
# 14                        h_c, bmn_c, msh_c, bmnmsh_c
# 15             h_c, btn_c, cys__L_c, ala__L_c, dtbt_c
# 16       h_c, octdp_c, 2dmmq8_c, dhna_c, ppi_c, co2_c
# 17      btn_c, s_c, met__L_c, dtbt_c, dad_5_c, amet_c
# 18  h_c, fmn_c, etha_c, acald_c, no2_c, fmnh2_c, o2_c
# 19                                                h_c
#
#                            Mass Difference  Charge Difference
# 0                        H: -2.0, Fe: -1.0               -3.0
# 1                          Fe: 1.0, H: 3.0                4.0
# 2   C: -18.0, H: -22.0, N: -8.0, O: -156.0                6.0
# 3       C: 18.0, H: 22.0, N: 8.0, O: 156.0               -6.0
# 4                           C: 4.0, H: 6.0               -2.0
# 5                                 H: -12.0               -3.0
# 6                           C: 4.0, H: 6.0               -2.0
# 7                           H: 2.0, O: 1.0                0.0
# 8                                  O: -1.0                0.0
# 9                                  S: -1.0                0.0
# 10                                 S: -1.0                0.0
# 11                                 H: -2.0                0.0
# 12                                  H: 1.0                0.0
# 13                                                       -2.0
# 14                                                        2.0
# 15                                                        2.0
# 16                                                        2.0
# 17                                                       -2.0
# 18                                                        4.0
# 19                                                       -2.0

# %%
balancer.generate_visual_report().show()
# Out:
# <ipython-input-12-45868f457808>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   balancer.generate_visual_report().show()

# %%
model.reactions.get_by_id("ACYP_2").annotation
# Out:
# {'sbo': 'SBO:0000176',
#  'ec-code': '3.6.1.7',
#  'metanetx.reaction': 'MNXR95427',
#  'kegg.reaction': 'R00317',
#  'seed.reaction': 'rxn00227'}

# %%
balancer.model_interface.write_model("new_model.xml")

# %%
reaction = balancer.model_interface.reactions["R_ACYP_2"]
type(reaction.sbo)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-bda4266e9469> in <module>
# ----> 1 reaction = balancer.model_interface.reactions["R_ACYP_2"]
#       2 type(reaction.sbo)
#
# KeyError: 'R_ACYP_2'

# %%
for metabolite in balancer.model_interface.reactions["R_CYO1b"].metabolites:
    print(metabolite.id, metabolite.formula, metabolite.charge)
    print((balancer.data_collector.assignments[metabolite.id]))

# %%
print(balancer.data_collector.assignments["M_o2_c"])

# %%
print(balancer.data_collector.assignments["M_ficytc_c"])

# %%
print(balancer.data_collector.assignments["M_focytc_c"])

# %%
balancer.generate_metabolite_report(f"{model.id}_metabolites")

# %%
libsbml.writeSBMLToFile(document, "model_MCC_libsbml.xml")

# %% [markdown]
# If you have access (currently requires an explicit academic license or a subscription) and downloaded the BioCyc flat files, you can pass the corresponding directory as well. Assuming we have already updated all the ids in the last step, we can set _update_ids_ to _False_.
#
# The additional argument is:
# * **biocyc_path**: Directory containing BioCyc flat files.

# %% [markdown]
# ## Evaluating the result
# To see the results at a first glance, we can generate a quick visual report, which tells us how many reactions are balanced now, and how many assignments were changed.

# %% [markdown]
# ### Metabolite Report
# The algorithm should be able to give a reason for every assignment that it chooses. We can have a look at these reasons in the metabolite report of the balancer.
#
# The report holds valuable information how the algorithm decided which assignment to choose and can be useful during further manual curation. The entries of the resulting DataFrame are the following:
# * **Id**: Id of the metabolite in the model.
# * **Name**: Name of the metabolite in the model.
# * **Determined Formula**: Formula that was assigned by the algorithm.
# * **Determined Charge**: Charge that was assigned by the algorithm.
# * **Previous Formula**: Formula that was assigned before the algorithm.
# * **Previous Charge**: Charge that was assigned before the algorithm.
# * **Inferrence Type**: Category of how the assignment was determined.
#     - Unconstrained: No information about the metabolite was found or only incomplete (wildcard containing) formulae were found and we could not find a concrete formula either. Should contain a wildcard.
#     - Inferred: No information about the metabolite was found or only incomplete (wildcard containing formulae were found, however we arrived at a concrete formula. Should not contain a wildcard.
#     - Clean: Information about the metabolite was found and used.
# * **Reasoning**: Reasoning how the assignment was determined. Can contain:
#     - database name:database identifier: The formula could be found in this database under this identifier.
#     - (unconstrained) Target: This assignment was chosen because it is the same as in the original (target) model. Unconstrained means that the original (target) model seemed to be missing a wildcard symbol that was thus added.
#     - Reaction_id (metabolite id -> Reasoning...): The assignment for this metabolite must follow from other reasons. The given reaction id and metabolite reasons make it so that if the model must be balanced, this metabolite must have the determined assignment.
#     - Used Databases: The databases which back up the determined assignment.
#     - Previous Databases: The databases which back up the previous assignment.

# %%
import libsbml
reader = libsbml.SBMLReader()
document = reader.readSBML("model.xml")
model = document.getModel()

# %%
model.id

# %%
metabolite_report_df = balancer.generate_metabolite_report()
metabolite_report_df[::200]

# %% [markdown]
# Usually we are interested in the assignments which differ from the original report. We can do this by indexing the Dataframe accordingly.

# %%
# If you like to see the entire report, uncomment the following line
#pandas.set_option("display.max_row", None)
metabolite_report_df[metabolite_report_df["Similarity"] != "Same"]

# %% [markdown]
# We might also be interested in all assignments which are not backed by a database:

# %%
metabolite_report_df[metabolite_report_df["Used Databases"] == ""]

# %% [markdown]
# ### Reaction Report
# Finally, especially for further curation, we might be interested in the remaining imbalanced reactions. For this the algorithm can also provide a report.
#
# The report also includes reactions which are technically balanced but where many protons had to be added to arrive at that result.
#
# The fields are as follows:
# * **Id**: Id of the reaction in the model.
# * **Unbalanced Reaction**: Name of the reaction in the model and corresponding equation.
# * **Unbalanced Type**: Type of imbalance. Can be both Mass and charge, only mass, only charge or high proton count.
# * **Reason**: Set of reactions which caused the reaction to be imbalanced. This effectively means that these reactions could not be balanced together. The sets are minimal, but for example for BTS2, it would not help to remove HCYSMT, as BTS2 would require protons to have no charge and HCYSMT is only one of many reactions which then would not be balanced.
# * **Shared Metabolites**: Metabolites which are shared between the reactions which are listed in Reason. Can give an indication where the problem might lie.
# * **Mass Difference**: Mass imbalance.
# * **Charge Difference**: Charge imbalance.

# %% [markdown]
# ### Writing Files
# The mass charge curation writes directly to the model that was given to it. Thus, if we want to write our model, we can just pass the model to cobrapy. If you want to keep your old model, you should make sure to not overwrite it here.

# %%
cobra.io.write_sbml_model(model, f"{model.id}_MCC.xml")

# %%
cobra.io.write_sbml_model??

# %% [markdown]
# For the reports, we can add filenames to the functions to write the visual report to a .png file and the metabolite and reaction DataFrames to .csv files.

# %%
balancer.generate_visual_report(f"{model.id}_visual")
balancer.generate_metabolite_report(f"{model.id}_metabolites")
balancer.generate_reaction_report(f"{model.id}_reactions")
pass

# %%
from MCC import DataCollector
import cobra

# %%
import libsbml

# %%
import libsbml
filename = "model.xml"
reader = libsbml.SBMLReader()
document = reader.readSBML(filename)
model = document.getModel()

# %%
dc = DataCollector(model)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~/Systems Biology HiWi/MassChargeCuration/MCC/DataCollection/DataCollection.py in __init__(self, model, data_path, update_ids, gather_information, used_annotations, no_local, biocyc_path)
#      48         try:
# ---> 49             os.makedirs(self.data_path)
#      50         except PermissionError:
#
# ~/miniconda3/envs/MCC/lib/python3.8/os.py in makedirs(name, mode, exist_ok)
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#
# PermissionError: [Errno 13] Permission denied: '/data'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-7f172a19e84d> in <module>
# ----> 1 dc = DataCollector(model)
#
# ~/Systems Biology HiWi/MassChargeCuration/MCC/DataCollection/DataCollection.py in __init__(self, model, data_path, update_ids, gather_information, used_annotations, no_local, biocyc_path)
#      49             os.makedirs(self.data_path)
#      50         except PermissionError:
# ---> 51             raise PermissionError
#      52         except OSError:
#      53             pass
#
# PermissionError:

# %%
dir(model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__parent_ref__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__weakref__',
#  'addCVTerm',
#  'addCompartment',
#  'addCompartmentType',
#  'addConstantAttribute',
#  'addConstraint',
#  'addDefinitionsForDefaultUnits',
#  'addEvent',
#  'addFunctionDefinition',
#  'addInitialAssignment',
#  'addModifiers',
#  'addParameter',
#  'addReaction',
#  'addRule',
#  'addSpecies',
#  'addSpeciesType',
#  'addUnitDefinition',
#  'all_element_id_list',
#  'all_element_meta_id_list',
#  'all_elements',
#  'all_elements_from_plugins',
#  'annotation',
#  'annotation_string',
#  'appendAnnotation',
#  'appendFrom',
#  'appendNotes',
#  'area_units',
#  'assignRequiredValues',
#  'checkCompatibility',
#  'checkMathMLNamespace',
#  'clearAllElementIdList',
#  'clearAllElementMetaIdList',
#  'clone',
#  'column',
#  'compartment_types',
#  'compartments',
#  'connectToChild',
#  'connectToParent',
#  'constraints',
#  'containsUndeclaredUnits',
#  'conversion_factor',
#  'convertFromL3V2',
#  'convertL1ToL2',
#  'convertL1ToL3',
#  'convertL2ToL1',
#  'convertL2ToL3',
#  'convertL3ToL1',
#  'convertL3ToL2',
#  'convertParametersToLocals',
#  'convertStoichiometryMath',
#  'createAlgebraicRule',
#  'createAssignmentRule',
#  'createCompartment',
#  'createCompartmentType',
#  'createConstraint',
#  'createDelay',
#  'createEvent',
#  'createEventAssignment',
#  'createFunctionDefinition',
#  'createInitialAssignment',
#  'createKineticLaw',
#  'createKineticLawLocalParameter',
#  'createKineticLawParameter',
#  'createModifier',
#  'createParameter',
#  'createProduct',
#  'createRateRule',
#  'createReactant',
#  'createReaction',
#  'createSpecies',
#  'createSpeciesType',
#  'createTrigger',
#  'createUnit',
#  'createUnitDefinition',
#  'cv_terms',
#  'dealWithDefaultValues',
#  'dealWithEvents',
#  'dealWithFast',
#  'dealWithL3Fast',
#  'dealWithModelUnits',
#  'dealWithStoichiometry',
#  'deleteDisabledPlugins',
#  'derived_unit_definition',
#  'disablePackage',
#  'divideAssignmentsToSIdByFunction',
#  'element_name',
#  'enablePackage',
#  'enablePackageInternal',
#  'events',
#  'extent_units',
#  'function_definitions',
#  'getAllElementIdList',
#  'getAllElementMetaIdList',
#  'getAncestorOfType',
#  'getAnnotation',
#  'getAnnotationString',
#  'getAreaUnits',
#  'getAssignmentRule',
#  'getAssignmentRuleByVariable',
#  'getCVTerm',
#  'getCVTerms',
#  'getColumn',
#  'getCompartment',
#  'getCompartmentType',
#  'getConstraint',
#  'getConversionFactor',
#  'getDerivedUnitDefinition',
#  'getDisabledPlugin',
#  'getElementByMetaId',
#  'getElementBySId',
#  'getElementFromPluginsByMetaId',
#  'getElementFromPluginsBySId',
#  'getElementName',
#  'getEvent',
#  'getExtentUnits',
#  'getFormulaUnitsDataForAssignment',
#  'getFormulaUnitsDataForVariable',
#  'getFunctionDefinition',
#  'getId',
#  'getIdAttribute',
#  'getInitialAssignment',
#  'getInitialAssignmentBySymbol',
#  'getLengthUnits',
#  'getLevel',
#  'getLine',
#  'getListOfAllElements',
#  'getListOfAllElementsFromPlugins',
#  'getListOfCompartmentTypes',
#  'getListOfCompartments',
#  'getListOfConstraints',
#  'getListOfEvents',
#  'getListOfFunctionDefinitions',
#  'getListOfInitialAssignments',
#  'getListOfParameters',
#  'getListOfReactions',
#  'getListOfRules',
#  'getListOfSpecies',
#  'getListOfSpeciesTypes',
#  'getListOfUnitDefinitions',
#  'getMetaId',
#  'getModel',
#  'getModelHistory',
#  'getModifierSpeciesReference',
#  'getName',
#  'getNamespaces',
#  'getNotes',
#  'getNotesString',
#  'getNumCVTerms',
#  'getNumCompartmentTypes',
#  'getNumCompartments',
#  'getNumConstraints',
#  'getNumDisabledPlugins',
#  'getNumEvents',
#  'getNumFunctionDefinitions',
#  'getNumInitialAssignments',
#  'getNumParameters',
#  'getNumPlugins',
#  'getNumReactions',
#  'getNumRules',
#  'getNumSpecies',
#  'getNumSpeciesTypes',
#  'getNumSpeciesWithBoundaryCondition',
#  'getNumUnitDefinitions',
#  'getPackageCoreVersion',
#  'getPackageName',
#  'getPackageVersion',
#  'getParameter',
#  'getParentSBMLObject',
#  'getPlugin',
#  'getPrefix',
#  'getRateRule',
#  'getRateRuleByVariable',
#  'getReaction',
#  'getResourceBiologicalQualifier',
#  'getResourceModelQualifier',
#  'getRule',
#  'getRuleByVariable',
#  'getSBMLDocument',
#  'getSBMLNamespaces',
#  'getSBOTerm',
#  'getSBOTermAsURL',
#  'getSBOTermID',
#  'getSpecies',
#  'getSpeciesReference',
#  'getSpeciesType',
#  'getSubstanceUnits',
#  'getTimeUnits',
#  'getTypeCode',
#  'getURI',
#  'getUnitDefinition',
#  'getVersion',
#  'getVolumeUnits',
#  'hasNonstandardIdentifierBeginningWith',
#  'hasOptionalAttributes',
#  'hasOptionalElements',
#  'hasRequiredAttributes',
#  'hasRequiredElements',
#  'hasValidLevelVersionNamespaceCombination',
#  'id',
#  'id_attribute',
#  'initial_assignments',
#  'isPackageEnabled',
#  'isPackageURIEnabled',
#  'isPkgEnabled',
#  'isPkgURIEnabled',
#  'isPopulatedAllElementIdList',
#  'isPopulatedAllElementMetaIdList',
#  'isPopulatedListFormulaUnitsData',
#  'isSetAnnotation',
#  'isSetAreaUnits',
#  'isSetConversionFactor',
#  'isSetExtentUnits',
#  'isSetId',
#  'isSetIdAttribute',
#  'isSetLengthUnits',
#  'isSetMetaId',
#  'isSetModelHistory',
#  'isSetName',
#  'isSetNotes',
#  'isSetSBOTerm',
#  'isSetSubstanceUnits',
#  'isSetTimeUnits',
#  'isSetUserData',
#  'isSetVolumeUnits',
#  'length_units',
#  'level',
#  'line',
#  'matchesRequiredSBMLNamespacesForAddition',
#  'matchesSBMLNamespaces',
#  'meta_id',
#  'model',
#  'multiplyAssignmentsToSIdByFunction',
#  'name',
#  'namespaces',
#  'notes',
#  'notes_string',
#  'num_compartment_types',
#  'num_compartments',
#  'num_constraints',
#  'num_cv_terms',
#  'num_disabled_plugins',
#  'num_events',
#  'num_function_definitions',
#  'num_initial_assignments',
#  'num_parameters',
#  'num_plugins',
#  'num_reactions',
#  'num_rules',
#  'num_species',
#  'num_species_types',
#  'num_species_with_boundary_condition',
#  'num_unit_definitions',
#  'package_core_version',
#  'package_name',
#  'package_version',
#  'parameters',
#  'populateAllElementIdList',
#  'populateAllElementMetaIdList',
#  'populateListFormulaUnitsData',
#  'prefix',
#  'prependStringToAllIdentifiers',
#  'reactions',
#  'read',
#  'removeCompartment',
#  'removeCompartmentType',
#  'removeCompartmentTypes',
#  'removeConstraint',
#  'removeDuplicateAnnotations',
#  'removeEvent',
#  'removeFromParentAndDelete',
#  'removeFunctionDefinition',
#  'removeInitialAssignment',
#  'removeParameter',
#  'removeParameterRuleUnits',
#  'removeReaction',
#  'removeRule',
#  'removeRuleByVariable',
#  'removeSpecies',
#  'removeSpeciesType',
#  'removeSpeciesTypes',
#  'removeTopLevelAnnotationElement',
#  'removeUnitDefinition',
#  'renameAllIds',
#  'renameIDs',
#  'renameMetaIdRefs',
#  'renameSIdRefs',
#  'renameUnitSIdRefs',
#  'replaceSIDWithFunction',
#  'replaceTopLevelAnnotationElement',
#  'rules',
#  'sbml_namespaces',
#  'sbml_namespaces_and_own',
#  'sbo_term',
#  'sbo_term_as_url',
#  'sbo_term_id',
#  'setAnnotation',
#  'setAreaUnits',
#  'setConversionFactor',
#  'setExtentUnits',
#  'setId',
#  'setIdAttribute',
#  'setLengthUnits',
#  'setMetaId',
#  'setModelHistory',
#  'setName',
#  'setNamespaces',
#  'setNotes',
#  'setSBMLNamespacesAndOwn',
#  'setSBOTerm',
#  'setSpatialDimensions',
#  'setSpeciesReferenceConstantValueAndStoichiometry',
#  'setSubstanceUnits',
#  'setTimeUnits',
#  'setVolumeUnits',
#  'spatial_dimensions',
#  'species',
#  'species_reference_constant_value_and_stoichiometry',
#  'species_types',
#  'substance_units',
#  'this',
#  'thisown',
#  'time_units',
#  'toSBML',
#  'toXMLNode',
#  'transformIdentifiers',
#  'type_code',
#  'unit_definitions',
#  'unsetAnnotation',
#  'unsetAreaUnits',
#  'unsetCVTerms',
#  'unsetConversionFactor',
#  'unsetExtentUnits',
#  'unsetId',
#  'unsetIdAttribute',
#  'unsetLengthUnits',
#  'unsetMetaId',
#  'unsetModelHistory',
#  'unsetName',
#  'unsetNotes',
#  'unsetSBOTerm',
#  'unsetSubstanceUnits',
#  'unsetTimeUnits',
#  'unsetUserData',
#  'unsetVolumeUnits',
#  'updateSBMLNamespace',
#  'uri',
#  'version',
#  'volume_units',
#  'write',
#  'writeExtensionElements']

# %%
def get_annotations(annotations_node):
    identifiers = {}
    for i in range(annotations_node.getNumChildren()):
        child_rdf = annotations_node.getChild(i)
        if child_rdf.getName() == "RDF":
            for i in range(child_rdf.getNumChildren()):
                child_dscr = child_rdf.getChild(i)
                if child_dscr.getName() == "Description":
                    for i in range(child_dscr.getNumChildren()):
                        child_is = child_dscr.getChild(i)
                        if child_is.getName() == "is":
                            for i in range(child_is.getNumChildren()):
                                child_bag = child_is.getChild(i)
                                if child_bag.getName() == "Bag":
                                    for i in range(child_bag.getNumChildren()):
                                        child_anno = child_bag.getChild(i)
                                        attributes = child_anno.getAttributes()
                                        for i in range(attributes.getNumAttributes()):
                                            if attributes.getName(i) == "resource":
                                                attribute = attributes.getValue(i)
                                                splitted = attribute.split("/")
                                                identifier = splitted[-1]
                                                db_id = splitted[-2]
                                                identifiers[db_id] = identifier
    return identifiers
def get_fbc_plugin(sbml_object):
    for i in range(sbml_object.num_plugins):
        plugin = sbml_object.getPlugin(i)
        if plugin.package_name == "fbc":
            return plugin
        
def get_sbml_notes(sbml_object):
    notes_dict = {}
    notes = meta.getNotes()
    for i in range(notes.getNumChildren()):
        html = notes.getChild(i)
        if html.getName() == "html":
            for i in range(html.getNumChildren()):
                note = html.getChild(i)
                if (note.getName() == "p") and (note.getNumChildren() >= 1) and (note.getChild(0).isText()):
                    base_text = note.getChild(0).getCharacters()
                    splitted = base_text.split(":")
                    identifier = splitted[0]
                    value = "".join(splitted[1:]).strip()
                    notes_dict[identifier] = value
    return notes_dict

# %%
print(get_notes(meta))
dir(get_notes(meta))
# Out:
# {'FORMULA': 'C6H12O6', 'CHARGE': '0', 'SBOTerm': 'SBO0000247'}
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
import MCC

# %%
for metabolite in model.getListOfSpecies():
    plugIn = get_fbc_plugin(metabolite)
    print(plugIn.package_name)
    print(dir(metabolite))
    break
# Out:
# fbc
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__metaclass__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__weakref__', 'addCVTerm', 'all_elements', 'all_elements_from_plugins', 'annotation', 'annotation_string', 'appendAnnotation', 'appendNotes', 'boundary_condition', 'charge', 'checkCompatibility', 'checkMathMLNamespace', 'clone', 'column', 'compartment', 'connectToChild', 'connectToParent', 'constant', 'containsUndeclaredUnits', 'conversion_factor', 'cv_terms', 'deleteDisabledPlugins', 'derived_unit_definition', 'disablePackage', 'divideAssignmentsToSIdByFunction', 'element_name', 'enablePackage', 'enablePackageInternal', 'getAncestorOfType', 'getAnnotation', 'getAnnotationString', 'getBoundaryCondition', 'getCVTerm', 'getCVTerms', 'getCharge', 'getColumn', 'getCompartment', 'getConstant', 'getConversionFactor', 'getDerivedUnitDefinition', 'getDisabledPlugin', 'getElementByMetaId', 'getElementBySId', 'getElementFromPluginsByMetaId', 'getElementFromPluginsBySId', 'getElementName', 'getHasOnlySubstanceUnits', 'getId', 'getIdAttribute', 'getInitialAmount', 'getInitialConcentration', 'getLevel', 'getLine', 'getListOfAllElements', 'getListOfAllElementsFromPlugins', 'getMetaId', 'getModel', 'getModelHistory', 'getName', 'getNamespaces', 'getNotes', 'getNotesString', 'getNumCVTerms', 'getNumDisabledPlugins', 'getNumPlugins', 'getPackageCoreVersion', 'getPackageName', 'getPackageVersion', 'getParentSBMLObject', 'getPlugin', 'getPrefix', 'getResourceBiologicalQualifier', 'getResourceModelQualifier', 'getSBMLDocument', 'getSBMLNamespaces', 'getSBOTerm', 'getSBOTermAsURL', 'getSBOTermID', 'getSpatialSizeUnits', 'getSpeciesType', 'getSubstanceUnits', 'getTypeCode', 'getURI', 'getUnits', 'getVersion', 'hasNonstandardIdentifierBeginningWith', 'hasOptionalAttributes', 'hasOptionalElements', 'hasRequiredAttributes', 'hasRequiredElements', 'hasValidLevelVersionNamespaceCombination', 'has_only_substance_units', 'id', 'id_attribute', 'initDefaults', 'initial_amount', 'initial_concentration', 'isPackageEnabled', 'isPackageURIEnabled', 'isPkgEnabled', 'isPkgURIEnabled', 'isSetAnnotation', 'isSetBoundaryCondition', 'isSetCharge', 'isSetCompartment', 'isSetConstant', 'isSetConversionFactor', 'isSetHasOnlySubstanceUnits', 'isSetId', 'isSetIdAttribute', 'isSetInitialAmount', 'isSetInitialConcentration', 'isSetMetaId', 'isSetModelHistory', 'isSetName', 'isSetNotes', 'isSetSBOTerm', 'isSetSpatialSizeUnits', 'isSetSpeciesType', 'isSetSubstanceUnits', 'isSetUnits', 'isSetUserData', 'level', 'line', 'matchesRequiredSBMLNamespacesForAddition', 'matchesSBMLNamespaces', 'meta_id', 'model', 'multiplyAssignmentsToSIdByFunction', 'name', 'namespaces', 'notes', 'notes_string', 'num_cv_terms', 'num_disabled_plugins', 'num_plugins', 'package_core_version', 'package_name', 'package_version', 'prefix', 'prependStringToAllIdentifiers', 'read', 'removeDuplicateAnnotations', 'removeFromParentAndDelete', 'removeTopLevelAnnotationElement', 'renameMetaIdRefs', 'renameSIdRefs', 'renameUnitSIdRefs', 'replaceSIDWithFunction', 'replaceTopLevelAnnotationElement', 'sbml_namespaces', 'sbml_namespaces_and_own', 'sbo_term', 'sbo_term_as_url', 'sbo_term_id', 'setAnnotation', 'setBoundaryCondition', 'setCharge', 'setCompartment', 'setConstant', 'setConversionFactor', 'setHasOnlySubstanceUnits', 'setId', 'setIdAttribute', 'setInitialAmount', 'setInitialConcentration', 'setMetaId', 'setModelHistory', 'setName', 'setNamespaces', 'setNotes', 'setSBMLNamespacesAndOwn', 'setSBOTerm', 'setSpatialSizeUnits', 'setSpeciesType', 'setSubstanceUnits', 'setUnits', 'spatial_size_units', 'species_type', 'substance_units', 'this', 'thisown', 'toSBML', 'toXMLNode', 'transformIdentifiers', 'type_code', 'units', 'unsetAnnotation', 'unsetBounda ...

# %%
dir(model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__parent_ref__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__weakref__',
#  'addCVTerm',
#  'addCompartment',
#  'addCompartmentType',
#  'addConstantAttribute',
#  'addConstraint',
#  'addDefinitionsForDefaultUnits',
#  'addEvent',
#  'addFunctionDefinition',
#  'addInitialAssignment',
#  'addModifiers',
#  'addParameter',
#  'addReaction',
#  'addRule',
#  'addSpecies',
#  'addSpeciesType',
#  'addUnitDefinition',
#  'all_element_id_list',
#  'all_element_meta_id_list',
#  'all_elements',
#  'all_elements_from_plugins',
#  'annotation',
#  'annotation_string',
#  'appendAnnotation',
#  'appendFrom',
#  'appendNotes',
#  'area_units',
#  'assignRequiredValues',
#  'checkCompatibility',
#  'checkMathMLNamespace',
#  'clearAllElementIdList',
#  'clearAllElementMetaIdList',
#  'clone',
#  'column',
#  'compartment_types',
#  'compartments',
#  'connectToChild',
#  'connectToParent',
#  'constraints',
#  'containsUndeclaredUnits',
#  'conversion_factor',
#  'convertFromL3V2',
#  'convertL1ToL2',
#  'convertL1ToL3',
#  'convertL2ToL1',
#  'convertL2ToL3',
#  'convertL3ToL1',
#  'convertL3ToL2',
#  'convertParametersToLocals',
#  'convertStoichiometryMath',
#  'createAlgebraicRule',
#  'createAssignmentRule',
#  'createCompartment',
#  'createCompartmentType',
#  'createConstraint',
#  'createDelay',
#  'createEvent',
#  'createEventAssignment',
#  'createFunctionDefinition',
#  'createInitialAssignment',
#  'createKineticLaw',
#  'createKineticLawLocalParameter',
#  'createKineticLawParameter',
#  'createModifier',
#  'createParameter',
#  'createProduct',
#  'createRateRule',
#  'createReactant',
#  'createReaction',
#  'createSpecies',
#  'createSpeciesType',
#  'createTrigger',
#  'createUnit',
#  'createUnitDefinition',
#  'cv_terms',
#  'dealWithDefaultValues',
#  'dealWithEvents',
#  'dealWithFast',
#  'dealWithL3Fast',
#  'dealWithModelUnits',
#  'dealWithStoichiometry',
#  'deleteDisabledPlugins',
#  'derived_unit_definition',
#  'disablePackage',
#  'divideAssignmentsToSIdByFunction',
#  'element_name',
#  'enablePackage',
#  'enablePackageInternal',
#  'events',
#  'extent_units',
#  'function_definitions',
#  'getAllElementIdList',
#  'getAllElementMetaIdList',
#  'getAncestorOfType',
#  'getAnnotation',
#  'getAnnotationString',
#  'getAreaUnits',
#  'getAssignmentRule',
#  'getAssignmentRuleByVariable',
#  'getCVTerm',
#  'getCVTerms',
#  'getColumn',
#  'getCompartment',
#  'getCompartmentType',
#  'getConstraint',
#  'getConversionFactor',
#  'getDerivedUnitDefinition',
#  'getDisabledPlugin',
#  'getElementByMetaId',
#  'getElementBySId',
#  'getElementFromPluginsByMetaId',
#  'getElementFromPluginsBySId',
#  'getElementName',
#  'getEvent',
#  'getExtentUnits',
#  'getFormulaUnitsDataForAssignment',
#  'getFormulaUnitsDataForVariable',
#  'getFunctionDefinition',
#  'getId',
#  'getIdAttribute',
#  'getInitialAssignment',
#  'getInitialAssignmentBySymbol',
#  'getLengthUnits',
#  'getLevel',
#  'getLine',
#  'getListOfAllElements',
#  'getListOfAllElementsFromPlugins',
#  'getListOfCompartmentTypes',
#  'getListOfCompartments',
#  'getListOfConstraints',
#  'getListOfEvents',
#  'getListOfFunctionDefinitions',
#  'getListOfInitialAssignments',
#  'getListOfParameters',
#  'getListOfReactions',
#  'getListOfRules',
#  'getListOfSpecies',
#  'getListOfSpeciesTypes',
#  'getListOfUnitDefinitions',
#  'getMetaId',
#  'getModel',
#  'getModelHistory',
#  'getModifierSpeciesReference',
#  'getName',
#  'getNamespaces',
#  'getNotes',
#  'getNotesString',
#  'getNumCVTerms',
#  'getNumCompartmentTypes',
#  'getNumCompartments',
#  'getNumConstraints',
#  'getNumDisabledPlugins',
#  'getNumEvents',
#  'getNumFunctionDefinitions',
#  'getNumInitialAssignments',
#  'getNumParameters',
#  'getNumPlugins',
#  'getNumReactions',
#  'getNumRules',
#  'getNumSpecies',
#  'getNumSpeciesTypes',
#  'getNumSpeciesWithBoundaryCondition',
#  'getNumUnitDefinitions',
#  'getPackageCoreVersion',
#  'getPackageName',
#  'getPackageVersion',
#  'getParameter',
#  'getParentSBMLObject',
#  'getPlugin',
#  'getPrefix',
#  'getRateRule',
#  'getRateRuleByVariable',
#  'getReaction',
#  'getResourceBiologicalQualifier',
#  'getResourceModelQualifier',
#  'getRule',
#  'getRuleByVariable',
#  'getSBMLDocument',
#  'getSBMLNamespaces',
#  'getSBOTerm',
#  'getSBOTermAsURL',
#  'getSBOTermID',
#  'getSpecies',
#  'getSpeciesReference',
#  'getSpeciesType',
#  'getSubstanceUnits',
#  'getTimeUnits',
#  'getTypeCode',
#  'getURI',
#  'getUnitDefinition',
#  'getVersion',
#  'getVolumeUnits',
#  'hasNonstandardIdentifierBeginningWith',
#  'hasOptionalAttributes',
#  'hasOptionalElements',
#  'hasRequiredAttributes',
#  'hasRequiredElements',
#  'hasValidLevelVersionNamespaceCombination',
#  'id',
#  'id_attribute',
#  'initial_assignments',
#  'isPackageEnabled',
#  'isPackageURIEnabled',
#  'isPkgEnabled',
#  'isPkgURIEnabled',
#  'isPopulatedAllElementIdList',
#  'isPopulatedAllElementMetaIdList',
#  'isPopulatedListFormulaUnitsData',
#  'isSetAnnotation',
#  'isSetAreaUnits',
#  'isSetConversionFactor',
#  'isSetExtentUnits',
#  'isSetId',
#  'isSetIdAttribute',
#  'isSetLengthUnits',
#  'isSetMetaId',
#  'isSetModelHistory',
#  'isSetName',
#  'isSetNotes',
#  'isSetSBOTerm',
#  'isSetSubstanceUnits',
#  'isSetTimeUnits',
#  'isSetUserData',
#  'isSetVolumeUnits',
#  'length_units',
#  'level',
#  'line',
#  'matchesRequiredSBMLNamespacesForAddition',
#  'matchesSBMLNamespaces',
#  'meta_id',
#  'model',
#  'multiplyAssignmentsToSIdByFunction',
#  'name',
#  'namespaces',
#  'notes',
#  'notes_string',
#  'num_compartment_types',
#  'num_compartments',
#  'num_constraints',
#  'num_cv_terms',
#  'num_disabled_plugins',
#  'num_events',
#  'num_function_definitions',
#  'num_initial_assignments',
#  'num_parameters',
#  'num_plugins',
#  'num_reactions',
#  'num_rules',
#  'num_species',
#  'num_species_types',
#  'num_species_with_boundary_condition',
#  'num_unit_definitions',
#  'package_core_version',
#  'package_name',
#  'package_version',
#  'parameters',
#  'populateAllElementIdList',
#  'populateAllElementMetaIdList',
#  'populateListFormulaUnitsData',
#  'prefix',
#  'prependStringToAllIdentifiers',
#  'reactions',
#  'read',
#  'removeCompartment',
#  'removeCompartmentType',
#  'removeCompartmentTypes',
#  'removeConstraint',
#  'removeDuplicateAnnotations',
#  'removeEvent',
#  'removeFromParentAndDelete',
#  'removeFunctionDefinition',
#  'removeInitialAssignment',
#  'removeParameter',
#  'removeParameterRuleUnits',
#  'removeReaction',
#  'removeRule',
#  'removeRuleByVariable',
#  'removeSpecies',
#  'removeSpeciesType',
#  'removeSpeciesTypes',
#  'removeTopLevelAnnotationElement',
#  'removeUnitDefinition',
#  'renameAllIds',
#  'renameIDs',
#  'renameMetaIdRefs',
#  'renameSIdRefs',
#  'renameUnitSIdRefs',
#  'replaceSIDWithFunction',
#  'replaceTopLevelAnnotationElement',
#  'rules',
#  'sbml_namespaces',
#  'sbml_namespaces_and_own',
#  'sbo_term',
#  'sbo_term_as_url',
#  'sbo_term_id',
#  'setAnnotation',
#  'setAreaUnits',
#  'setConversionFactor',
#  'setExtentUnits',
#  'setId',
#  'setIdAttribute',
#  'setLengthUnits',
#  'setMetaId',
#  'setModelHistory',
#  'setName',
#  'setNamespaces',
#  'setNotes',
#  'setSBMLNamespacesAndOwn',
#  'setSBOTerm',
#  'setSpatialDimensions',
#  'setSpeciesReferenceConstantValueAndStoichiometry',
#  'setSubstanceUnits',
#  'setTimeUnits',
#  'setVolumeUnits',
#  'spatial_dimensions',
#  'species',
#  'species_reference_constant_value_and_stoichiometry',
#  'species_types',
#  'substance_units',
#  'this',
#  'thisown',
#  'time_units',
#  'toSBML',
#  'toXMLNode',
#  'transformIdentifiers',
#  'type_code',
#  'unit_definitions',
#  'unsetAnnotation',
#  'unsetAreaUnits',
#  'unsetCVTerms',
#  'unsetConversionFactor',
#  'unsetExtentUnits',
#  'unsetId',
#  'unsetIdAttribute',
#  'unsetLengthUnits',
#  'unsetMetaId',
#  'unsetModelHistory',
#  'unsetName',
#  'unsetNotes',
#  'unsetSBOTerm',
#  'unsetSubstanceUnits',
#  'unsetTimeUnits',
#  'unsetUserData',
#  'unsetVolumeUnits',
#  'updateSBMLNamespace',
#  'uri',
#  'version',
#  'volume_units',
#  'write',
#  'writeExtensionElements']

# %%
meta = model.getSpecies("M_fru_p")

# %%
print(meta.getNotes().getNumChildren())
dir(meta.getNotes())
# Out:
# 1
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__weakref__',
#  'addAttr',
#  'addChild',
#  'addNamespace',
#  'append',
#  'clearAttributes',
#  'clearNamespaces',
#  'clone',
#  'convertStringToXMLNode',
#  'convertXMLNodeToString',
#  'equals',
#  'getAttrIndex',
#  'getAttrName',
#  'getAttrPrefix',
#  'getAttrPrefixedName',
#  'getAttrURI',
#  'getAttrValue',
#  'getAttributes',
#  'getAttributesLength',
#  'getCharacters',
#  'getChild',
#  'getColumn',
#  'getIndex',
#  'getLine',
#  'getName',
#  'getNamespaceIndex',
#  'getNamespaceIndexByPrefix',
#  'getNamespacePrefix',
#  'getNamespaceURI',
#  'getNamespaces',
#  'getNamespacesLength',
#  'getNumChildren',
#  'getPrefix',
#  'getURI',
#  'hasAttr',
#  'hasChild',
#  'hasNamespaceNS',
#  'hasNamespacePrefix',
#  'hasNamespaceURI',
#  'insertChild',
#  'isAttributesEmpty',
#  'isEOF',
#  'isElement',
#  'isEnd',
#  'isEndFor',
#  'isNamespacesEmpty',
#  'isStart',
#  'isText',
#  'removeAttr',
#  'removeChild',
#  'removeChildren',
#  'removeNamespace',
#  'setAttributes',
#  'setCharacters',
#  'setEOF',
#  'setEnd',
#  'setNamespaces',
#  'setTriple',
#  'this',
#  'thisown',
#  'toString',
#  'toXMLString',
#  'unsetEnd',
#  'writeToStream']

# %% [markdown]
# # Usage example on model of _Corynebacterium tuberculostearicum (high GC Gram+)_.
# In this notebook we show how to use the Mass Charge Curation python package. As an example model we use a model of [_Corynebacterium tuberculostearicum (high GC Gram+)_, strain DSM 44922](https://www.ncbi.nlm.nih.gov/assembly/GCF_013408445.1/) created with [CarveMe Version 1.5.1](https://carveme.readthedocs.io/en/latest/index.html), which here is simply called _model.xml_.

# %% [markdown]
# If you are interested in a more verbose output you can uncomment the following line:

# %%
import logging; logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# ## Dependencies
# First we will check if all dependencies of the curation package are fullfilled.

# %%
try: import numpy
except Exception as e: print("You seem to be missing numpy. You can usually install it via 'pip install numpy'"); raise e
try: import pandas
except Exception as e: print("You seem to be missing pandas. You can usually install it via 'pip install pandas'"); raise e
try: import cobra
except Exception as e: print("You seem to be missing cobrapy. See https://github.com/opencobra/cobrapy on how to install it."); raise e
try: import z3
except Exception as e: print("You seem to be missing z3 or the corresponding python bindings. See https://github.com/Z3Prover/z3 on how to install it."); raise e
# Out:
# DEBUG:optlang.util:Gurobi python bindings not available.
# DEBUG:optlang.util:GLPK python bindings found at /home/finnem/miniconda3/envs/MCC/lib/python3.8/site-packages/swiglpk
# DEBUG:optlang.util:Mosek python bindings not available.
# DEBUG:optlang.util:CPLEX python bindings found at /home/finnem/miniconda3/envs/MCC/lib/python3.8/site-packages/cplex
# DEBUG:optlang.util:OSQP python bindings not available.
# DEBUG:optlang.util:COINOR_CBC python bindings not available.
# DEBUG:optlang.util:Scipy linprog function found at /home/finnem/miniconda3/envs/MCC/lib/python3.8/site-packages/scipy/optimize/__init__.py

# %% [markdown]
# Next we see if the Mass Charge Curation package is installed properly.

# %%
try: import MCC
except Exception as e: print("The mass charge curation package does not seem to be installed correctly. Make sure you have the correct python version installed and try running pip install -e ./.. in the folder of this notebook."); raise e
# Out:
# DEBUG:matplotlib:matplotlib data path: /home/finnem/miniconda3/envs/MCC/lib/python3.8/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/home/finnem/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# DEBUG:matplotlib:loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_warnings', '_io', 'marshal', 'posix', '_frozen_importlib_external', '_thread', '_weakref', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', '_abc', 'abc', 'io', '_stat', 'stat', '_collections_abc', 'genericpath', 'posixpath', 'os.path', 'os', '_sitebuiltins', '_locale', '_bootlocale', 'types', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib', 'importlib.machinery', 'importlib.abc', '_operator', 'operator', 'keyword', '_heapq', 'heapq', 'itertools', 'reprlib', '_collections', 'collections', '_functools', 'functools', 'contextlib', 'importlib.util', 'mpl_toolkits', 'ruamel', 'site', '_weakrefset', 'weakref', 'pkgutil', 'runpy', 'ipykernel._version', 'enum', '_sre', 'sre_constants', 'sre_parse', 'sre_compile', 'copyreg', 're', '_json', 'json.scanner', 'json.decoder', 'json.encoder', 'json', 'errno', 'signal', 'threading', '_posixsubprocess', 'select', 'collections.abc', 'math', 'selectors', 'subprocess', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'atexit', 'copy', 'fnmatch', 'glob', 'token', 'tokenize', 'linecache', 'traceback', '_string', 'string', 'logging', 'zlib', '_compression', '_bz2', 'bz2', '_lzma', 'lzma', 'pwd', 'grp', 'shutil', '_ast', 'ast', '_opcode', 'opcode', 'dis', 'inspect', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.traitlets', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets', 'pprint', 'locale', 'gettext', 'argparse', 'traitlets.config.loader', 'textwrap', 'traitlets.utils.text', 'traitlets.config.configurable', 'traitlets.config.application', 'traitlets.config', 'platform', 'sysconfig', 'urllib', 'urllib.parse', '_sysconfigdata__linux_x86_64-linux-gnu', 'pydoc', 'bdb', 'IPython.utils', 'IPython.utils.ipstruct', 'IPython.utils.coloransi', 'pygments', 'IPython.utils.colorable', 'IPython.utils.PyColorize', 'IPython.utils.encoding', 'IPython.utils.py3compat', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'cmd', '__future__', 'codeop', 'code', 'pdb', 'IPython.core.debugger', 'IPython.core.display_trap', '_bisect', 'bisect', '_sha512', '_random', 'random', 'pexpect.exceptions', 'pexpect.utils', 'pexpect.expect', 'termios', 'tty', 'pty', 'fcntl', 'resource', '_struct', 'struct', 'ptyprocess.util', 'ptyprocess.ptyprocess', 'ptyprocess', 'pexpect.spawnbase', 'pexpect.pty_spawn', 'pexpect.run', 'pexpect', 'shlex', 'IPython.utils._process_common', 'IPython.utils._process_posix', 'IPython.utils.process', 'IPython.utils.decorators', 'IPython.utils.path', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.core.ultratb', 'IPython.utils._sysinfo', 'IPython.utils.sysinfo', 'IPython.core.crashhandler', 'tempfile', 'IPython.utils.importstring', 'IPython.paths', 'IPython.core.profiledir', 'IPython.core.application', 'IPython.terminal', '_hashlib', '_blake2', '_sha3', 'hashlib', 'IPython.core.compilerop', 'IPython.core.error', 'ntpath', 'pathlib', 'IPython.utils.text', 'IPython.core.magic_arguments', 'getopt', 'typing.io', 'typing.re', 'typing', 'binascii', 'mimetypes', 'IPython.core.display', 'IPython.core.page', 'getpass', 'IPython.lib.security', 'IPython.lib', '_datetime', 'datetime', 'IPython.lib.pretty', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.util', 'pygments.lexers', 'pygments.filter', 'pygments.token', 'pygments.filters', 'pygments.regexopt', 'pygments.lexer', 'pygments.unistring', 'pygments.lexers.python', 'pygments.formatters._mapping', 'pygments.formatters', 'pygments.styles', 'pygments.formatter', 'pygments.formatters.html', 'IPython.core.oinspect', 'IPython.core.inputtransformer2', 'decorator', 'IPython. ...
# DEBUG:matplotlib:CACHEDIR=/home/finnem/.cache/matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from /home/finnem/.cache/matplotlib/fontlist-v330.json
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %% [markdown]
# ## Loading the model
# Once all dependencies are installed, we can take a look at our example model.

# %% [markdown]
# First we will read in our model using cobrapy.

# %%
model = cobra.io.read_sbml_model("model.xml")
print(f"The model has {len(model.metabolites)} metabolites and {len(model.reactions)} reactions.")
# Out:
# The model has 1019 metabolites and 1481 reactions.

# %% [markdown]
# We can first take a look at how many reactions in our model are unbalanced.

# %% [markdown]
# ## Curating Mass and Charge
# We can now instantiate a curation class. There are different ways to use the package, depending how data should be gathered, how much curation has already been done and how much data is available offline.
#
# We will first give an example of the most simple usage, downloading as many databases as possible and updating all [identifiers.org](https://identifiers.org/) identifiers we need for the package to work optimally. This will take significantly longer (~ 15 Minutes) than running the algorithm on an already annotated model, however it is important to use the most up-to-date identifiers if we want to include as much information as possible.
#
# This will create a folder _/data_ in the current directory where all database information is downloaded to.
#
# The arguments are as follows:
# * **model**: Model we want to curate.
# * **data_path**: Path to the directory containing database files. Defaults to _/data_. If the directory does not exist, it will be created. If a file cannot be found, we will try to download it.
# * **update_ids**: If this is set to _True_, we will first try to update all [identifiers.org](https://identifiers.org/) ids. This will take a while but is important to properly index the different databases. Defaults to _False_.
#
# **Note**: It is expected to see _No objective coefficients in model. Unclear what should be optimized_ warnings here, this poses no problem for this package.

# %%
balancer = MCC.MassChargeCuration(model = "model.xml", data_path = "./data", update_ids = False)
balancer.generate_metabolite_report(f"{model.id}_metabolites")
# Out:
# INFO:root:1/1019: Getting information for M_10fthf_c
# DEBUG:root:metanetx.chemical, MNXM237
# DEBUG:root:seed.compound, cpd00201
# DEBUG:root:biocyc, META:10-FORMYL-THF
# INFO:root:2/1019: Getting information for M_12dgr140_c
# DEBUG:root:metanetx.chemical, MNXM146479
# INFO:root:3/1019: Getting information for M_12dgr140_p
# DEBUG:root:metanetx.chemical, MNXM146479
# INFO:root:4/1019: Getting information for M_12dgr141_c
# DEBUG:root:metanetx.chemical, MNXM4940
# INFO:root:5/1019: Getting information for M_12dgr141_p
# DEBUG:root:metanetx.chemical, MNXM4940
# INFO:root:6/1019: Getting information for M_12dgr160_c
# DEBUG:root:metanetx.chemical, MNXM3132
# INFO:root:7/1019: Getting information for M_12dgr160_e
# DEBUG:root:metanetx.chemical, MNXM3132
# INFO:root:8/1019: Getting information for M_12dgr160_p
# DEBUG:root:metanetx.chemical, MNXM3132
# INFO:root:9/1019: Getting information for M_12dgr180_c
# DEBUG:root:metanetx.chemical, MNXM4217
# INFO:root:10/1019: Getting information for M_12dgr180_e
# DEBUG:root:metanetx.chemical, MNXM4217
# INFO:root:11/1019: Getting information for M_12dgr180_p
# DEBUG:root:metanetx.chemical, MNXM4217
# INFO:root:12/1019: Getting information for M_12dgr181_c
# DEBUG:root:metanetx.chemical, MNXM3775
# INFO:root:13/1019: Getting information for M_12dgr181_p
# DEBUG:root:metanetx.chemical, MNXM3775
# INFO:root:14/1019: Getting information for M_12ppd__S_c
# DEBUG:root:metanetx.chemical, MNXM1255
# DEBUG:root:seed.compound, cpd19024
# DEBUG:root:biocyc, META:PROPANE-1-2-DIOL
# INFO:root:15/1019: Getting information for M_12ppd__S_e
# DEBUG:root:metanetx.chemical, MNXM1255
# DEBUG:root:seed.compound, cpd19024
# DEBUG:root:biocyc, META:PROPANE-1-2-DIOL
# INFO:root:16/1019: Getting information for M_13dpg_c
# DEBUG:root:metanetx.chemical, MNXM261
# DEBUG:root:seed.compound, cpd00203
# DEBUG:root:biocyc, META:DPG
# INFO:root:17/1019: Getting information for M_15dap_c
# DEBUG:root:metanetx.chemical, MNXM943
# DEBUG:root:seed.compound, cpd01155
# DEBUG:root:biocyc, META:CADAVERINE
# INFO:root:18/1019: Getting information for M_1ag160_e
# DEBUG:root:metanetx.chemical, MNXM789
# DEBUG:root:seed.compound, cpd00509
# DEBUG:root:seed.compound, cpd26845
# DEBUG:root:biocyc, META:DEOXY-D-RIBOSE-1-PHOSPHATE
# INFO:root:54/1019: Getting information for M_2dr5p_c
# DEBUG:root:metanetx.chemical, MNXM2179
# DEBUG:root:seed.compound, cpd00510
# DEBUG:root:seed.compound, cpd26846
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:DEOXY-RIBOSE-5P&detail=low HTTP/1.1" 200 904
# DEBUG:root:Could not find entry META:DEOXY-RIBOSE-5P in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:DEOXY-RIBOSE-5P&detail=low
# DEBUG:root:biocyc, META:DEOXY-RIBOSE-5P
# INFO:root:55/1019: Getting information for M_2hadnt_c
# INFO:root:56/1019: Getting information for M_2ippm_c
# DEBUG:root:metanetx.chemical, MNXM1706
# DEBUG:root:seed.compound, cpd01710
# DEBUG:root:biocyc, META:CPD-9451
# INFO:root:57/1019: Getting information for M_2m35mdntha_c
# INFO:root:58/1019: Getting information for M_2m35mdntha_e
# INFO:root:59/1019: Getting information for M_2mahmp_c
# DEBUG:root:metanetx.chemical, MNXM1135
# DEBUG:root:seed.compound, cpd02894
# DEBUG:root:biocyc, META:AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP
# INFO:root:60/1019: Getting information for M_2mcacn_c
# DEBUG:root:metanetx.chemical, MNXM1792
# DEBUG:root:seed.compound, cpd02597
# DEBUG:root:biocyc, META:CPD-1136
# INFO:root:61/1019: Getting information for M_2mcit_c
# DEBUG:root:metanetx.chemical, MNXM90279
# DEBUG:root:seed.compound, cpd01501
# DEBUG:root:seed.compound, cpd24620
# DEBUG:root:biocyc, META:CPD-622
# INFO:root:62/1019: Getting information for M_2me4p_c
# DEBUG:root:metanetx.chemical, MNXM1626
# DEBUG:root:seed.compound, cpd08286
# DEBUG:root:biocyc, META:2-C-METHYL-D-ERYTHRITOL-4-PHOSPHATE
# INFO:root:63/1019: Getting information for M_2mecdp_c
# DEBUG:root:metanetx.chemical, MNXM1168
# DEBUG:root:seed.compound, cpd08301
# DEBUG:root:biocyc, META:2C-METH-D-ERYTHRITOL-CYCLODIPHOSPHATE
# INFO:root:64/1019: Getting information for M_2obut_c
# DEBUG:root:metanetx.chemical, MNXM159
# DEBUG:root:seed.compound, cpd00094
# DEBUG:root:biocyc, META:2-OXOBUTANOATE
# INFO:root:65/1019: Getting information for M_2p4c2me_c
# DEBUG:root:metanetx.chemical, MNXM1641
# DEBUG:root:seed.compound, cpd08288
# DEBUG:root:biocyc, META:2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET
# INFO:root:66/1019: Getting information for M_2pg_c
# DEBUG:root:metanetx.chemical, MNXM275
# DEBUG:root:seed.compound, cpd00482
# DEBUG:root:biocyc, META:2-PG
# INFO:root:67/1019: Getting information for M_2sephchc_c
# DEBUG:root:metanetx.chemical, MNXM1861
# DEBUG:root:seed.compound, cpd16335
# INFO:root:68/1019: Getting information for M_2shchc_c
# DEBUG:root:metanetx.chemical, MNXM1249
# DEBUG:root:seed.compound, cpd03451
# DEBUG:root:biocyc, META:CPD-9923
# INFO:root:69/1019: Getting information for M_34hpp_c
# DEBUG:root:metanetx.chemical, MNXM153
# DEBUG:root:seed.compound, cpd00868
# DEBUG:root:biocyc, META:P-HYDROXY-PHENYLPYRUVATE
# INFO:root:70/1019: Getting information for M_35dnta_c
# INFO:root:71/1019: Getting information for M_35dnta_e
# INFO:root:72/1019: Getting information for M_3c2hmp_c
# DEBUG:root:metanetx.chemical, MNXM891
# DEBUG:root:seed.compound, cpd02693
# DEBUG:root:biocyc, META:2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE
# INFO:root:73/1019: Getting information for M_3c3hmp_c
# DEBUG:root:metanetx.chemical, MNXM985
# DEBUG:root:seed.compound, cpd01646
# DEBUG:root:biocyc, META:3-CARBOXY-3-HYDROXY-ISOCAPROATE
# INFO:root:74/1019: Getting information for M_3c4mop_c
# DEBUG:root:metanetx.chemical, MNXM1602
# DEBUG:root:seed.compound, cpd02605
# DEBUG:root:biocyc, META:CPD-7100
# INFO:root:75/1019: Getting information for M_3dhq_c
# DEBUG:root:metanetx.chemical, MNXM478
# DEBUG:root:seed.compound, cpd00699
# DEBUG:root:biocyc, META:DEHYDROQUINATE
# INFO:root:76/1019: Getting information for M_3dhsk_c
# DEBUG:root:metanetx.chemical, MNXM611
# DEBUG:root:seed.compound, cpd01716
# DEBUG:root:biocyc, META:3-DEHYDRO-SHIKIMATE
# INFO:root:77/1019: Getting information for M_3hbcoa__R_c
# DEBUG:root:metanetx.chemical, MNXM162788
# INFO:root:78/1019: Getting information for M_3hbcoa_c
# DEBUG:root:metanetx.chemical, MNXM446
# DEBUG:root:seed.compound, cpd00842
# DEBUG:root:biocyc, META:S-3-HYDROXYBUTANOYL-COA
# INFO:root:79/1019: Getting information for M_3hpcoa_c
# DEBUG:root:metanetx.chemical, MNXM1263
# DEBUG:root:seed.compound, cpd03375
# DEBUG:root:biocyc, META:3-HYDROXY-PROPIONYL-COA
# INFO:root:80/1019: Getting information for M_3hptcoa_c
# DEBUG:root:metanetx.chemical, MNXM147789
# INFO:root:81/1019: Getting information for M_3ig3p_c
# DEBUG:root:metanetx.chemical, MNXM866
# DEBUG:root:seed.compound, cpd02210
# DEBUG:root:seed.compound, cpd29667
# DEBUG:root:biocyc, META:INDOLE-3-GLYCEROL-P
# INFO:root:82/1019: Getting information for M_3mb_c
# DEBUG:root:metanetx.chemical, MNXM7454
# DEBUG:root:seed.compound, cpd05178
# DEBUG:root:biocyc, META:ISOVALERATE
# INFO:root:83/1019: Getting information for M_3mb_e
# DEBUG:root:metanetx.chemical, MNXM7454
# DEBUG:root:seed.compound, cpd05178
# DEBUG:root:biocyc, META:ISOVALERATE
# INFO:root:84/1019: Getting information for M_3mb_p
# DEBUG:root:metanetx.chemical, MNXM7454
# DEBUG:root:seed.compound, cpd05178
# DEBUG:root:biocyc, META:ISOVALERATE
# INFO:root:85/1019: Getting information for M_3mob_c
# INFO:root:102/1019: Getting information for M_4hba_c
# DEBUG:root:metanetx.chemical, MNXM107505
# DEBUG:root:seed.compound, cpd15378
# DEBUG:root:seed.compound, cpd17595
# DEBUG:root:biocyc, META:4-HYDROXY-BENZYL-ALCOHOL
# INFO:root:103/1019: Getting information for M_4hba_e
# DEBUG:root:metanetx.chemical, MNXM107505
# DEBUG:root:seed.compound, cpd15378
# DEBUG:root:seed.compound, cpd17595
# DEBUG:root:biocyc, META:4-HYDROXY-BENZYL-ALCOHOL
# INFO:root:104/1019: Getting information for M_4hglusa_c
# DEBUG:root:metanetx.chemical, MNXM2687
# DEBUG:root:seed.compound, cpd03530
# DEBUG:root:biocyc, META:L-4-HYDROXYGLUTAMATE_SEMIALDEHYDE
# INFO:root:105/1019: Getting information for M_4hpro_LT_c
# DEBUG:root:metanetx.chemical, MNXM87584
# DEBUG:root:seed.compound, cpd00851
# DEBUG:root:seed.compound, cpd02291
# DEBUG:root:seed.compound, cpd29317
# DEBUG:root:biocyc, META:4-HYDROXY-L-PROLINE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:CPD-17742&detail=low HTTP/1.1" 404 1773
# DEBUG:root:Could not find entry META:CPD-17742 in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:CPD-17742&detail=low
# INFO:root:106/1019: Getting information for M_4izp_c
# DEBUG:root:metanetx.chemical, MNXM90394
# DEBUG:root:seed.compound, cpd02311
# DEBUG:root:biocyc, META:4-IMIDAZOLONE-5-PROPIONATE
# INFO:root:107/1019: Getting information for M_4mhetz_c
# DEBUG:root:metanetx.chemical, MNXM962
# DEBUG:root:seed.compound, cpd02636
# DEBUG:root:biocyc, META:THZ
# INFO:root:108/1019: Getting information for M_4mop_c
# DEBUG:root:metanetx.chemical, MNXM404
# DEBUG:root:seed.compound, cpd00200
# DEBUG:root:biocyc, META:2K-4CH3-PENTANOATE
# INFO:root:109/1019: Getting information for M_4mpetz_c
# DEBUG:root:metanetx.chemical, MNXM960
# DEBUG:root:seed.compound, cpd02654
# DEBUG:root:biocyc, META:THZ-P
# INFO:root:110/1019: Getting information for M_4pasp_c
# DEBUG:root:metanetx.chemical, MNXM1177
# DEBUG:root:seed.compound, cpd01977
# DEBUG:root:biocyc, META:L-BETA-ASPARTYL-P
# INFO:root:111/1019: Getting information for M_4ppan_c
# DEBUG:root:metanetx.chemical, MNXM415
# DEBUG:root:seed.compound, cpd02201
# DEBUG:root:biocyc, META:4-P-PANTOTHENATE
# INFO:root:112/1019: Getting information for M_4ppcys_c
# DEBUG:root:metanetx.chemical, MNXM483
# DEBUG:root:seed.compound, cpd02666
# DEBUG:root:biocyc, META:R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE
# INFO:root:113/1019: Getting information for M_4r5au_c
# DEBUG:root:metanetx.chemical, MNXM791
# DEBUG:root:seed.compound, cpd02882
# DEBUG:root:seed.compound, cpd29668
# DEBUG:root:biocyc, META:AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE
# DEBUG:root:biocyc, META:ACET
# INFO:root:193/1019: Getting information for M_acald_c
# DEBUG:root:metanetx.chemical, MNXM75
# DEBUG:root:seed.compound, cpd00071
# DEBUG:root:biocyc, META:ACETALD
# INFO:root:194/1019: Getting information for M_acald_e
# DEBUG:root:metanetx.chemical, MNXM75
# DEBUG:root:seed.compound, cpd00071
# DEBUG:root:biocyc, META:ACETALD
# INFO:root:195/1019: Getting information for M_acald_p
# DEBUG:root:metanetx.chemical, MNXM75
# DEBUG:root:seed.compound, cpd00071
# DEBUG:root:biocyc, META:ACETALD
# INFO:root:196/1019: Getting information for M_accoa_c
# DEBUG:root:metanetx.chemical, MNXM21
# DEBUG:root:seed.compound, cpd00022
# DEBUG:root:biocyc, META:ACETYL-COA
# INFO:root:197/1019: Getting information for M_acetol_c
# DEBUG:root:metanetx.chemical, MNXM1744
# DEBUG:root:seed.compound, cpd03105
# DEBUG:root:biocyc, META:ACETOL
# INFO:root:198/1019: Getting information for M_acg5p_c
# DEBUG:root:metanetx.chemical, MNXM1384
# DEBUG:root:seed.compound, cpd02552
# DEBUG:root:biocyc, META:N-ACETYL-GLUTAMYL-P
# INFO:root:199/1019: Getting information for M_acg5sa_c
# DEBUG:root:metanetx.chemical, MNXM1062
# DEBUG:root:seed.compound, cpd00918
# DEBUG:root:biocyc, META:CPD-469
# INFO:root:200/1019: Getting information for M_acgam1p_c
# DEBUG:root:metanetx.chemical, MNXM91871
# DEBUG:root:seed.compound, cpd02611
# INFO:root:201/1019: Getting information for M_acgam6p_c
# DEBUG:root:metanetx.chemical, MNXM63556
# DEBUG:root:seed.compound, cpd00293
# DEBUG:root:biocyc, META:CPD-16168
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:N-ACETYL-D-GLUCOSAMINE-6-P&detail=low HTTP/1.1" 200 1083
# DEBUG:root:Could not find entry META:N-ACETYL-D-GLUCOSAMINE-6-P in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:N-ACETYL-D-GLUCOSAMINE-6-P&detail=low
# DEBUG:root:biocyc, META:N-ACETYL-D-GLUCOSAMINE-6-P
# INFO:root:202/1019: Getting information for M_acgam_e
# DEBUG:root:metanetx.chemical, MNXM143
# DEBUG:root:seed.compound, cpd00122
# DEBUG:root:seed.compound, cpd27608
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:N-acetyl-D-glucosamine&detail=low HTTP/1.1" 200 971
# DEBUG:root:Could not find entry META:N-acetyl-D-glucosamine in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:N-acetyl-D-glucosamine&detail=low
# DEBUG:root:biocyc, META:N-acetyl-D-glucosamine
# INFO:root:203/1019: Getting information for M_acglu_c
# DEBUG:root:metanetx.chemical, MNXM730
# DEBUG:root:seed.compound, cpd00477
# DEBUG:root:biocyc, META:ACETYL-GLU
# INFO:root:204/1019: Getting information for M_acglu_e
# DEBUG:root:metanetx.chemical, MNXM730
# DEBUG:root:seed.compound, cpd00477
# DEBUG:root:biocyc, META:ACETYL-GLU
# INFO:root:205/1019: Getting information for M_achms_c
# DEBUG:root:metanetx.chemical, MNXM699
# DEBUG:root:seed.compound, cpd00790
# DEBUG:root:biocyc, META:CPD-667
# INFO:root:206/1019: Getting information for M_acmana_c
# DEBUG:root:metanetx.chemical, MNXM2403
# DEBUG:root:seed.compound, cpd00492
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:N-acetyl-D-mannosamine&detail=low HTTP/1.1" 200 965
# DEBUG:root:Could not find entry META:N-acetyl-D-mannosamine in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:N-acetyl-D-mannosamine&detail=low
# DEBUG:root:biocyc, META:N-acetyl-D-mannosamine
# INFO:root:207/1019: Getting information for M_acmanap_c
# DEBUG:root:metanetx.chemical, MNXM4708
# DEBUG:root:seed.compound, cpd02612
# DEBUG:root:biocyc, META:N-ACETYL-D-MANNOSAMINE-6P
# INFO:root:208/1019: Getting information for M_acorn_c
# DEBUG:root:metanetx.chemical, MNXM817
# DEBUG:root:seed.compound, cpd00342
# DEBUG:root:biocyc, META:N-ALPHA-ACETYLORNITHINE
# INFO:root:209/1019: Getting information for M_acser_c
# DEBUG:root:metanetx.chemical, MNXM418
# DEBUG:root:seed.compound, cpd00722
# DEBUG:root:biocyc, META:ACETYLSERINE
# INFO:root:210/1019: Getting information for M_actn__R_c
# DEBUG:root:metanetx.chemical, MNXM664
# DEBUG:root:seed.compound, cpd19008
# DEBUG:root:biocyc, META:CPD-10353
# INFO:root:211/1019: Getting information for M_actn__R_e
# DEBUG:root:metanetx.chemical, MNXM664
# DEBUG:root:seed.compound, cpd19008
# DEBUG:root:biocyc, META:CPD-10353
# INFO:root:212/1019: Getting information for M_actp_c
# DEBUG:root:metanetx.chemical, MNXM280
# DEBUG:root:seed.compound, cpd00196
# DEBUG:root:biocyc, META:ACETYL-P
# INFO:root:213/1019: Getting information for M_acysbmn_c
# DEBUG:root:metanetx.chemical, MNXM7016
# DEBUG:root:seed.compound, cpd15926
# INFO:root:214/1019: Getting information for M_acysbmn_e
# DEBUG:root:metanetx.chemical, MNXM7016
# DEBUG:root:seed.compound, cpd15926
# INFO:root:215/1019: Getting information for M_ade_c
# DEBUG:root:metanetx.chemical, MNXM168
# DEBUG:root:seed.compound, cpd00128
# DEBUG:root:seed.compound, cpd22238
# DEBUG:root:biocyc, META:ADENINE
# DEBUG:root:biocyc, META:ADENINE-RING
# INFO:root:216/1019: Getting information for M_adhlam_c
# DEBUG:root:metanetx.chemical, MNXM4815
# DEBUG:root:seed.compound, cpd00836
# DEBUG:root:biocyc, META:S-ACETYLDIHYDROLIPOAMIDE
# INFO:root:217/1019: Getting information for M_adn_c
# DEBUG:root:metanetx.chemical, MNXM212
# DEBUG:root:seed.compound, cpd00182
# DEBUG:root:biocyc, META:ADENOSINE
# INFO:root:218/1019: Getting information for M_adp_c
# DEBUG:root:metanetx.chemical, MNXM7
# DEBUG:root:seed.compound, cpd00008
# DEBUG:root:seed.compound, cpd00924
# DEBUG:root:biocyc, META:ADENOSYL-P4
# INFO:root:267/1019: Getting information for M_aps_c
# DEBUG:root:metanetx.chemical, MNXM287
# DEBUG:root:seed.compound, cpd00193
# DEBUG:root:biocyc, META:APS
# INFO:root:268/1019: Getting information for M_arab__D_c
# DEBUG:root:metanetx.chemical, MNXM544
# DEBUG:root:seed.compound, cpd00185
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:D-arabinopyranose&detail=low HTTP/1.1" 200 785
# DEBUG:root:Could not find entry META:D-arabinopyranose in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:D-arabinopyranose&detail=low
# DEBUG:root:biocyc, META:D-arabinopyranose
# INFO:root:269/1019: Getting information for M_arab__D_p
# DEBUG:root:metanetx.chemical, MNXM544
# DEBUG:root:seed.compound, cpd00185
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:D-arabinopyranose&detail=low HTTP/1.1" 200 785
# DEBUG:root:Could not find entry META:D-arabinopyranose in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:D-arabinopyranose&detail=low
# DEBUG:root:biocyc, META:D-arabinopyranose
# INFO:root:270/1019: Getting information for M_arab__L_c
# DEBUG:root:metanetx.chemical, MNXM91126
# DEBUG:root:seed.compound, cpd19109
# DEBUG:root:seed.compound, cpd27351
# DEBUG:root:biocyc, META:CPD-15699
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:L-ARABINOSE&detail=low HTTP/1.1" 200 844
# DEBUG:root:Could not find entry META:L-ARABINOSE in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:L-ARABINOSE&detail=low
# DEBUG:root:biocyc, META:L-ARABINOSE
# INFO:root:271/1019: Getting information for M_arab__L_p
# DEBUG:root:metanetx.chemical, MNXM91126
# DEBUG:root:seed.compound, cpd19109
# DEBUG:root:seed.compound, cpd27351
# DEBUG:root:biocyc, META:CPD-15699
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): websvc.biocyc.org:443
# DEBUG:urllib3.connectionpool:https://websvc.biocyc.org:443 "GET /getxml?META:L-ARABINOSE&detail=low HTTP/1.1" 200 844
# DEBUG:root:Could not find entry META:L-ARABINOSE in local BioCyc file. Trying to fetch from https://websvc.biocyc.org/getxml?META:L-ARABINOSE&detail=low
# DEBUG:root:biocyc, META:L-ARABINOSE
# INFO:root:272/1019: Getting information for M_arbt6p_c
# DEBUG:root:metanetx.chemical, MNXM2806
# DEBUG:root:seed.compound, cpd03697
# DEBUG:root:biocyc, META:CPD-1162
# INFO:root:273/1019: Getting information for M_arbt6p_e
# DEBUG:root:metanetx.chemical, MNXM2806
# DEBUG:root:seed.compound, cpd03697
# DEBUG:root:biocyc, META:CPD-1162
# INFO:root:274/1019: Getting information for M_arbt_e
# DEBUG:root:metanetx.chemical, MNXM2683
# DEBUG:root:seed.compound, cpd03696
# INFO:root:288/1019: Getting information for M_asp__L_e
# DEBUG:root:metanetx.chemical, MNXM42
# DEBUG:root:seed.compound, cpd00041
# DEBUG:root:seed.compound, cpd19181
# DEBUG:root:biocyc, META:L-ASPARTATE
# INFO:root:289/1019: Getting information for M_asp__L_p
# DEBUG:root:metanetx.chemical, MNXM42
# DEBUG:root:seed.compound, cpd00041
# DEBUG:root:seed.compound, cpd19181
# DEBUG:root:biocyc, META:L-ASPARTATE
# INFO:root:290/1019: Getting information for M_aspsa_c
# DEBUG:root:metanetx.chemical, MNXM361
# DEBUG:root:seed.compound, cpd00346
# DEBUG:root:biocyc, META:L-ASPARTATE-SEMIALDEHYDE
# INFO:root:291/1019: Getting information for M_atp_c
# DEBUG:root:metanetx.chemical, MNXM3
# DEBUG:root:seed.compound, cpd00002
# DEBUG:root:biocyc, META:ATP
# INFO:root:292/1019: Getting information for M_b2coa_c
# DEBUG:root:metanetx.chemical, MNXM214
# DEBUG:root:seed.compound, cpd00650
# DEBUG:root:biocyc, META:CROTONYL-COA
# INFO:root:293/1019: Getting information for M_betald_c
# DEBUG:root:metanetx.chemical, MNXM457
# DEBUG:root:seed.compound, cpd00447
# DEBUG:root:biocyc, META:BETAINE_ALDEHYDE
# INFO:root:294/1019: Getting information for M_bhb_c
# DEBUG:root:metanetx.chemical, MNXM663
# DEBUG:root:seed.compound, cpd00797
# DEBUG:root:biocyc, META:CPD-335
# INFO:root:295/1019: Getting information for M_bmn_c
# DEBUG:root:metanetx.chemical, MNXM61843
# DEBUG:root:seed.compound, cpd15933
# INFO:root:296/1019: Getting information for M_bmn_e
# DEBUG:root:metanetx.chemical, MNXM61843
# DEBUG:root:seed.compound, cpd15933
# INFO:root:297/1019: Getting information for M_bmnmsh_c
# DEBUG:root:metanetx.chemical, MNXM7133
# DEBUG:root:seed.compound, cpd15934
# INFO:root:298/1019: Getting information for M_btcoa_c
# DEBUG:root:metanetx.chemical, MNXM233
# DEBUG:root:seed.compound, cpd00120
# DEBUG:root:biocyc, META:BUTYRYL-COA
# INFO:root:299/1019: Getting information for M_btn_c
# DEBUG:root:metanetx.chemical, MNXM304
# DEBUG:root:seed.compound, cpd00104
# DEBUG:root:biocyc, META:BIOTIN
# INFO:root:300/1019: Getting information for M_but_c
# DEBUG:root:metanetx.chemical, MNXM162281
# INFO:root:301/1019: Getting information for M_but_e
# DEBUG:root:metanetx.chemical, MNXM162281
# INFO:root:302/1019: Getting information for M_but_p
# DEBUG:root:metanetx.chemical, MNXM162281
# INFO:root:303/1019: Getting information for M_ca2_c
# DEBUG:root:metanetx.chemical, MNXM128
# DEBUG:root:seed.compound, cpd00063
# DEBUG:root:seed.compound, cpd29674
# DEBUG:root:biocyc, META:CA+2
# INFO:root:304/1019: Getting information for M_ca2_e
# DEBUG:root:metanetx.chemical, MNXM128
# DEBUG:root:seed.compound, cpd00063
# DEBUG:root:seed.compound, cpd29674
# DEBUG:root:biocyc, META:CA+2
# INFO:root:305/1019: Getting information for M_camp_c
# DEBUG:root:metanetx.chemical, MNXM243
# DEBUG:root:seed.compound, cpd00446
# DEBUG:root:biocyc, META:CAMP
# INFO:root:306/1019: Getting information for M_cbasp_c
# DEBUG:root:metanetx.chemical, MNXM465
# DEBUG:root:seed.compound, cpd00343
# DEBUG:root:biocyc, META:CARBAMYUL-L-ASPARTATE
# INFO:root:307/1019: Getting information for M_cbp_c
# DEBUG:root:metanetx.chemical, MNXM138
# DEBUG:root:seed.compound, cpd00146
# DEBUG:root:biocyc, META:CARBAMOYL-P
# INFO:root:308/1019: Getting information for M_cd2_c
# DEBUG:root:metanetx.chemical, MNXM4505
# DEBUG:root:seed.compound, cpd01012
# DEBUG:root:biocyc, META:CD+2
# INFO:root:309/1019: Getting information for M_cd2_e
# DEBUG:root:metanetx.chemical, MNXM4505
# DEBUG:root:seed.compound, cpd01012
# DEBUG:root:biocyc, META:CD+2
# INFO:root:310/1019: Getting information for M_cd2_p
# DEBUG:root:metanetx.chemical, MNXM4505
# DEBUG:root:seed.compound, cpd01012
# DEBUG:root:biocyc, META:CD+2
# INFO:root:311/1019: Getting information for M_cdp_c
# DEBUG:root:metanetx.chemical, MNXM220
# DEBUG:root:seed.compound, cpd00096
# DEBUG:root:biocyc, META:CDP
# INFO:root:312/1019: Getting information for M_cdpc16c19g_c
# DEBUG:root:metanetx.chemical, MNXM3560
# DEBUG:root:seed.compound, cpd15935
# INFO:root:313/1019: Getting information for M_cdpc19c19g_c
# DEBUG:root:metanetx.chemical, MNXM4506
# DEBUG:root:seed.compound, cpd15936
# INFO:root:314/1019: Getting information for M_cdpdhdecg_c
# DEBUG:root:metanetx.chemical, MNXM3232
# DEBUG:root:seed.compound, cpd15419
# INFO:root:315/1019: Getting information for M_cdpdodec11eg_c
# DEBUG:root:metanetx.chemical, MNXM4509
# DEBUG:root:seed.compound, cpd15420
# INFO:root:316/1019: Getting information for M_cdpdtdec7eg_c
# DEBUG:root:metanetx.chemical, MNXM4511
# DEBUG:root:seed.compound, cpd15422
# INFO:root:317/1019: Getting information for M_cgly_c
# DEBUG:root:metanetx.chemical, MNXM683
# DEBUG:root:seed.compound, cpd01017
# DEBUG:root:biocyc, META:CYS-GLY
# INFO:root:318/1019: Getting information for M_cgly_e
# DEBUG:root:metanetx.chemical, MNXM683
# DEBUG:root:seed.compound, cpd01017
# DEBUG:root:biocyc, META:CYS-GLY
# INFO:root:319/1019: Getting information for M_cgly_p
# DEBUG:root:metanetx.chemical, MNXM683
# DEBUG:root:seed.compound, cpd01017
# DEBUG:root:biocyc, META:CYS-GLY
# INFO:root:320/1019: Getting information for M_chol_c
# DEBUG:root:metanetx.chemical, MNXM90
# DEBUG:root:seed.compound, cpd00098
# DEBUG:root:biocyc, META:CHOLINE
# INFO:root:321/1019: Getting information for M_chol_e
# DEBUG:root:metanetx.chemical, MNXM90
# DEBUG:root:seed.compound, cpd00098
# DEBUG:root:biocyc, META:CHOLINE
# INFO:root:322/1019: Getting information for M_chol_p
# DEBUG:root:metanetx.chemical, MNXM90
# DEBUG:root:seed.compound, cpd00098
# DEBUG:root:biocyc, META:CHOLINE
# INFO:root:323/1019: Getting information for M_chor_c
# DEBUG:root:metanetx.chemical, MNXM337
# DEBUG:root:seed.compound, cpd00216
# DEBUG:root:biocyc, META:CHORISMATE
# INFO:root:324/1019: Getting information for M_cigam_c
# DEBUG:root:metanetx.chemical, MNXM92226
# DEBUG:root:seed.compound, cpd15938
# INFO:root:325/1019: Getting information for M_cit_c
# DEBUG:root:metanetx.chemical, MNXM131
# ...
# DEBUG:root:[0.553 s] unsat cores were: [[R_FE3DCITabc]]
# finished with unsat core: []
# unsat with R_FE3DCITabc True
# sat_core {R_ALPHNH, R_NTRIR3pp, R_AMPEP10, R_PROt2r, R_ACLS, R_CATpp, R_APSR, R_AMPEP4, R_SPMDt3pp, R_SUCBZL, R_LACZpp, R_RNTR2, R_TALA, R_ENO, R_NO2t3, R_UAMAGS, R_NI2t3pp, R_CD2abc1, R_GLUR, R_FACOAL120t2pp, R_DAPE, R_CAT, R_D_LACtex, R_NNAM, R_PAPSR, R_ADPRDP, R_PUNP4_1, R_FORAMD, R_MANpts, R_PPK, R_ATPS4rpp, R_DHDPRy, R_HSERTA, R_GLYPHEtex, R_GAPD, R_SPODM, R_LYSabcpp, R_ABUTt2pp, R_GLYPHEHYc, R_H2Ot, R_G3PD1ir, R_ASNtex, R_RHACOAE60, R_SERAT, R_NNATr, R_RHACOAET40, R_GLUPRT, R_UDPDPS2, R_UPP3S, R_ASPabcpp, R_IPDPS, R_ACHBS, R_GAMpts, R_SERt2rpp, R_THFOR1, R_ATPPRT, R_AMALT4, R_FACOAL50i, R_PPPGO, R_CHOLD, R_PPBNGS, R_PROt4, R_PLIPA1E141pp, R_FE2abc, R_NDPK3, R_MDH3_1, R_DDCAt2pp, R_GLYabc, R_PG140abcpp, R_GLYCYSAP, R_MALt2_2, R_SHCHF, R_MALTabc, R_DHPS2, R_GTPCII, R_GUAt2r, R_OXGDC, R_RHACOAEP100, R_PYRt2rpp, R_THRt2r, R_HMPPtr, R_DRBK, R_NADPHXD, R_RHCCE, R_FOLD3, R_AMANAPEr, R_FALDtpp2, R_HXPRT, R_FACOAL141, R_AMPTASEGGLU, R_2AGPE161tipp, R_2AGPEAT120, R_GLYK1, R_SADT, R_CYTK1, R_FACOAE120, R_FE2Gabcpp, R_PROabc, R_CPPPGO, R_FFSD, R_DHPt, R_FCOAH2, R_FACOAL_70_c, R_NTPP5, R_UAGDP, R_NMNDA, R_GLYCS_II, R_COBALT2abcpp, R_PSERT, R_METtex, R_UPP3MT, R_FORMCOAL, R_ASNS1, R_SUCASPtpp, R_CD2tex, R_FRUK, R_PLPS, R_AI2tpp, R_DB4PS, R_PANTS, R_PA140abcpp, R_ALATHRtr, R_VALTA, R_PTAtex, R_FCLT, R_FE3abcpp, R_DALAt2r, R_AMPEP3, R_GLYGLYCNc, R_ZNabcpp, R_HVCD, R_ALALEUabcpp, R_DAGK141, R_CLPNS160pp, R_NAt, R_CMCBTFtex, R_PG141abcpp, R_PPRDNDH, R_NDPK6, R_TRPS2, R_METRR, R_PRAIi, R_THIORDXi, R_PGP160abcpp, R_RIBtex, R_CU2abcpp, R_MDNTHAep, R_KARA2, R_NADHPO, R_4HGLSD, R_DPR, R_FDH4pp, R_ACSPHAC60, R_NH3c, R_OMPDC, R_ASPK, R_ASNt2r, R_SERGLUGLNtr, R_GLUTRS_2, R_MOBDabc_rev, R_MHPGLUT, R_GTHRDt2_1, R_FAO11, R_NO2tex, R_CU2t4pp, R_HMR_0188, R_VECOAH, R_PGL, R_PA180abcpp, R_IGPDH, R_KGD2, R_PNP_1, R_GLYCLTDy, R_RHACOAEP50, R_PGAMT, R_ORNTA, R_FACOAE60, R_DHAD1, R_FORtppi, R_RHACOAE100, R_FMNRx, R_HMEDS, R_DTBTST, R_PYRtex, R_FACOAL50t2pp, R_GLCS3_1, R_METS, R_NAabc, R_THYMt, R_ADSK, R_PYK, R_UAMAS, R_PPNCL3, R_GLUTRS_3, R_FDH4pp_1, R_AMPTASEGGLN, R_ARBt3ipp, R_DACL, R_LEULEULAPc, R_GNP, R_MAGLIPA180ex, R_DHFR, R_DHFS, R_UGMDDS, R_ALCDpp, R_RNDR3b, R_PRPPS, R_PNTOt2, R_FACOAL161t2pp, R_ADK1, R_ACSPHAC50, R_RECOAH2, R_CAt6, R_BUTt4pp, R_NADPHXE, R_ACSPHACP60, R_ASAD, R_TAGLIPA160ex, R_GRTT, R_BMNt, R_MCITD, R_TREabc, R_FRUptspp, R_PNCDC, R_GCALDt, R_PDXPP, R_TAGLIPA180ex, R_GLYOX, R_GLYGLYGLNtr, R_GLYGLNtr, R_SERabc, R_MTHFR3, R_HSDy, R_ASPabc, R_THZPSN, R_TMDPK, R_PRASCSi, R_FALDtpp, R_DAGLIPA181d9ex, R_GALUi, R_MALt2_3pp, R_CO2t, R_ADCL, R_ACSPHAC142, R_PPCOAC, R_ARBT6Pt, R_ALCD2y, R_FAS140, R_GLYCL, R_2AGPE141tipp, R_GLYGLYtex, R_St, R_PIt2rpp, R_PGPP181, R_MSHAMID, R_SSALy, R_G1PP, R_SUCCt2_3pp, R_SDPDS, R_ACSPHACP80, R_GLCpts, R_CREAT, R_GLCURt2r, R_HG2abcpp, R_NO2t2r, R_AMPEP16, R_ICDHyr, R_HPROx, R_PItex, R_SMIA2abc, R_AMMQLT8, R_RHACOAEP60, R_Clt, R_MTAM_1, R_DARBt3ipp, R_CRO4t3pp, R_BALAt2pp, R_MTHFR2, R_RNTR1, R_LALGP, R_GLYCt, R_Cuabc, R_AGPR, R_GLYCK2, R_PG160abcpp, R_MAN1PT2, R_PUNP1_1, R_2AGPG140tipp, R_H2CO3D, R_Kabcpp, R_L_LACt2r, R_ALATRPtex, R_GLYBt2r, R_PGSA181, R_PPCSCT, R_MI3PS, R_L_LACD3_1, R_MAGLIPA181d9ex, R_FACOAE70, R_ALALEUt, R_GF6PTA, R_GLCabc, R_IPDPUDCT, R_GLUN, R_GLUt4, R_METSOX1abc, R_3MBt4pp, R_MOBDabc, R_RNDR3, R_GLYTYRabc, R_FACOAE160, R_OCDOR, R_ABG4t2, R_PPAt4pp, R_PROabcpp, R_AMPTASEHH, R_NDPK2, R_PPAtex, R_ALATHRabcpp, R_TNTR4, R_CMCBTFL, R_SERt2r, R_TNTHAC1, R_12DGR160tipp, R_FE3PYOVDL2, R_URAt2pp, R_ABUTtex, R_H2SO, R_H2St1, R_DCAtex, R_DCTPD, R_NMNAT, R_RHACOAEP40, R_METabc, R_URIH, R_FACOAE180, R_LTHRK, R_NTPP8, R_MALt5, R_TDP, R_GLYSERabcpp, R_VALt2r, R_ALAHISabcpp, R_NTPTP2, R_ACSPHAC101, R_PHCD, R_AICART, R_PUNP3_1, R_CMCBTFU, R_CD2abcpp, R_DAGLIPA180ex, R_CYTK2, R_PGPP160pp, R_AMPEP12, R_MOTH3, R_5DKGR, R_PUNP5_1, R_CDAPPA160190, R_MAN1PT, R_NTPP7, R_TMDS, R_ILEabc, R_HBCHLR, R_ACLDC, R_OAADCS, R_ACOAD2f, R_FUMt2_3pp, R_CYStex, R_FACOAE80, R_TAURabc, R_GLYALDt, R_ADCS, R_NTPP3, R_TNTR2x, R_NTP ...
# DEBUG:root:[0.552 s] unsat cores were: [[R_FE3DCITabc]]
# finished with unsat core: []
# unsat with R_FE3DCITabc True
# sat_core {R_ALPHNH, R_NTRIR3pp, R_AMPEP10, R_PROt2r, R_ACLS, R_CATpp, R_APSR, R_AMPEP4, R_SPMDt3pp, R_SUCBZL, R_LACZpp, R_RNTR2, R_TALA, R_ENO, R_NO2t3, R_UAMAGS, R_NI2t3pp, R_CD2abc1, R_GLUR, R_FACOAL120t2pp, R_DAPE, R_CAT, R_D_LACtex, R_NNAM, R_PAPSR, R_ADPRDP, R_PUNP4_1, R_FORAMD, R_MANpts, R_PPK, R_ATPS4rpp, R_DHDPRy, R_HSERTA, R_GLYPHEtex, R_GAPD, R_SPODM, R_LYSabcpp, R_ABUTt2pp, R_GLYPHEHYc, R_H2Ot, R_G3PD1ir, R_ASNtex, R_RHACOAE60, R_SERAT, R_NNATr, R_RHACOAET40, R_GLUPRT, R_UDPDPS2, R_UPP3S, R_ASPabcpp, R_IPDPS, R_ACHBS, R_GAMpts, R_SERt2rpp, R_THFOR1, R_ATPPRT, R_AMALT4, R_FACOAL50i, R_PPPGO, R_CHOLD, R_PPBNGS, R_PROt4, R_PLIPA1E141pp, R_FE2abc, R_NDPK3, R_MDH3_1, R_DDCAt2pp, R_GLYabc, R_PG140abcpp, R_GLYCYSAP, R_MALt2_2, R_SHCHF, R_MALTabc, R_DHPS2, R_GTPCII, R_GUAt2r, R_OXGDC, R_RHACOAEP100, R_PYRt2rpp, R_THRt2r, R_HMPPtr, R_DRBK, R_NADPHXD, R_RHCCE, R_FOLD3, R_AMANAPEr, R_FALDtpp2, R_HXPRT, R_FACOAL141, R_AMPTASEGGLU, R_2AGPE161tipp, R_2AGPEAT120, R_GLYK1, R_SADT, R_CYTK1, R_FACOAE120, R_FE2Gabcpp, R_PROabc, R_CPPPGO, R_FFSD, R_DHPt, R_FCOAH2, R_FACOAL_70_c, R_NTPP5, R_UAGDP, R_NMNDA, R_GLYCS_II, R_COBALT2abcpp, R_PSERT, R_METtex, R_UPP3MT, R_FORMCOAL, R_ASNS1, R_SUCASPtpp, R_CD2tex, R_FRUK, R_PLPS, R_AI2tpp, R_DB4PS, R_PANTS, R_PA140abcpp, R_ALATHRtr, R_VALTA, R_PTAtex, R_FCLT, R_FE3abcpp, R_DALAt2r, R_AMPEP3, R_GLYGLYCNc, R_ZNabcpp, R_HVCD, R_ALALEUabcpp, R_DAGK141, R_CLPNS160pp, R_NAt, R_CMCBTFtex, R_PG141abcpp, R_PPRDNDH, R_NDPK6, R_TRPS2, R_METRR, R_PRAIi, R_THIORDXi, R_PGP160abcpp, R_RIBtex, R_CU2abcpp, R_MDNTHAep, R_KARA2, R_NADHPO, R_4HGLSD, R_DPR, R_FDH4pp, R_ACSPHAC60, R_NH3c, R_OMPDC, R_ASPK, R_ASNt2r, R_SERGLUGLNtr, R_GLUTRS_2, R_MOBDabc_rev, R_MHPGLUT, R_GTHRDt2_1, R_FAO11, R_NO2tex, R_CU2t4pp, R_HMR_0188, R_VECOAH, R_PGL, R_PA180abcpp, R_IGPDH, R_KGD2, R_PNP_1, R_GLYCLTDy, R_RHACOAEP50, R_PGAMT, R_ORNTA, R_FACOAE60, R_DHAD1, R_FORtppi, R_RHACOAE100, R_FMNRx, R_HMEDS, R_DTBTST, R_PYRtex, R_FACOAL50t2pp, R_GLCS3_1, R_METS, R_NAabc, R_THYMt, R_ADSK, R_PYK, R_UAMAS, R_PPNCL3, R_GLUTRS_3, R_FDH4pp_1, R_AMPTASEGGLN, R_ARBt3ipp, R_DACL, R_LEULEULAPc, R_GNP, R_MAGLIPA180ex, R_DHFR, R_DHFS, R_UGMDDS, R_ALCDpp, R_RNDR3b, R_PRPPS, R_PNTOt2, R_FACOAL161t2pp, R_ADK1, R_ACSPHAC50, R_RECOAH2, R_CAt6, R_BUTt4pp, R_NADPHXE, R_ACSPHACP60, R_ASAD, R_TAGLIPA160ex, R_GRTT, R_BMNt, R_MCITD, R_TREabc, R_FRUptspp, R_PNCDC, R_GCALDt, R_PDXPP, R_TAGLIPA180ex, R_GLYOX, R_GLYGLYGLNtr, R_GLYGLNtr, R_SERabc, R_MTHFR3, R_HSDy, R_ASPabc, R_THZPSN, R_TMDPK, R_PRASCSi, R_FALDtpp, R_DAGLIPA181d9ex, R_GALUi, R_MALt2_3pp, R_CO2t, R_ADCL, R_ACSPHAC142, R_PPCOAC, R_ARBT6Pt, R_ALCD2y, R_FAS140, R_GLYCL, R_2AGPE141tipp, R_GLYGLYtex, R_St, R_PIt2rpp, R_PGPP181, R_MSHAMID, R_SSALy, R_G1PP, R_SUCCt2_3pp, R_SDPDS, R_ACSPHACP80, R_GLCpts, R_CREAT, R_GLCURt2r, R_HG2abcpp, R_NO2t2r, R_AMPEP16, R_ICDHyr, R_HPROx, R_PItex, R_SMIA2abc, R_AMMQLT8, R_RHACOAEP60, R_Clt, R_MTAM_1, R_DARBt3ipp, R_CRO4t3pp, R_BALAt2pp, R_MTHFR2, R_RNTR1, R_LALGP, R_GLYCt, R_Cuabc, R_AGPR, R_GLYCK2, R_PG160abcpp, R_MAN1PT2, R_PUNP1_1, R_2AGPG140tipp, R_H2CO3D, R_Kabcpp, R_L_LACt2r, R_ALATRPtex, R_GLYBt2r, R_PGSA181, R_PPCSCT, R_MI3PS, R_L_LACD3_1, R_MAGLIPA181d9ex, R_FACOAE70, R_ALALEUt, R_GF6PTA, R_GLCabc, R_IPDPUDCT, R_GLUN, R_GLUt4, R_METSOX1abc, R_3MBt4pp, R_MOBDabc, R_RNDR3, R_GLYTYRabc, R_FACOAE160, R_OCDOR, R_ABG4t2, R_PPAt4pp, R_PROabcpp, R_AMPTASEHH, R_NDPK2, R_PPAtex, R_ALATHRabcpp, R_TNTR4, R_CMCBTFL, R_SERt2r, R_TNTHAC1, R_12DGR160tipp, R_FE3PYOVDL2, R_URAt2pp, R_ABUTtex, R_H2SO, R_H2St1, R_DCAtex, R_DCTPD, R_NMNAT, R_RHACOAEP40, R_METabc, R_URIH, R_FACOAE180, R_LTHRK, R_NTPP8, R_MALt5, R_TDP, R_GLYSERabcpp, R_VALt2r, R_ALAHISabcpp, R_NTPTP2, R_ACSPHAC101, R_PHCD, R_AICART, R_PUNP3_1, R_CMCBTFU, R_CD2abcpp, R_DAGLIPA180ex, R_CYTK2, R_PGPP160pp, R_AMPEP12, R_MOTH3, R_5DKGR, R_PUNP5_1, R_CDAPPA160190, R_MAN1PT, R_NTPP7, R_TMDS, R_ILEabc, R_HBCHLR, R_ACLDC, R_OAADCS, R_ACOAD2f, R_FUMt2_3pp, R_CYStex, R_FACOAE80, R_TAURabc, R_GLYALDt, R_ADCS, R_NTPP3, R_TNTR2x, R_NTP ...
# DEBUG:root:[0.552 s] unsat cores were: [[R_FE3DCITabc]]
# finished with unsat core: []
# unsat with R_FE3DCITabc True
# sat_core {R_ALPHNH, R_NTRIR3pp, R_AMPEP10, R_PROt2r, R_ACLS, R_CATpp, R_APSR, R_AMPEP4, R_SPMDt3pp, R_SUCBZL, R_LACZpp, R_RNTR2, R_TALA, R_ENO, R_NO2t3, R_UAMAGS, R_NI2t3pp, R_CD2abc1, R_GLUR, R_FACOAL120t2pp, R_DAPE, R_CAT, R_D_LACtex, R_NNAM, R_PAPSR, R_ADPRDP, R_PUNP4_1, R_FORAMD, R_MANpts, R_PPK, R_ATPS4rpp, R_DHDPRy, R_HSERTA, R_GLYPHEtex, R_GAPD, R_SPODM, R_LYSabcpp, R_ABUTt2pp, R_GLYPHEHYc, R_H2Ot, R_G3PD1ir, R_ASNtex, R_RHACOAE60, R_SERAT, R_NNATr, R_RHACOAET40, R_GLUPRT, R_UDPDPS2, R_UPP3S, R_ASPabcpp, R_IPDPS, R_ACHBS, R_GAMpts, R_SERt2rpp, R_THFOR1, R_ATPPRT, R_AMALT4, R_FACOAL50i, R_PPPGO, R_CHOLD, R_PPBNGS, R_PROt4, R_PLIPA1E141pp, R_FE2abc, R_NDPK3, R_MDH3_1, R_DDCAt2pp, R_GLYabc, R_PG140abcpp, R_GLYCYSAP, R_MALt2_2, R_SHCHF, R_MALTabc, R_DHPS2, R_GTPCII, R_GUAt2r, R_OXGDC, R_RHACOAEP100, R_PYRt2rpp, R_THRt2r, R_HMPPtr, R_DRBK, R_NADPHXD, R_RHCCE, R_FOLD3, R_AMANAPEr, R_FALDtpp2, R_HXPRT, R_FACOAL141, R_AMPTASEGGLU, R_2AGPE161tipp, R_2AGPEAT120, R_GLYK1, R_SADT, R_CYTK1, R_FACOAE120, R_FE2Gabcpp, R_PROabc, R_CPPPGO, R_FFSD, R_DHPt, R_FCOAH2, R_FACOAL_70_c, R_NTPP5, R_UAGDP, R_NMNDA, R_GLYCS_II, R_COBALT2abcpp, R_PSERT, R_METtex, R_UPP3MT, R_FORMCOAL, R_ASNS1, R_SUCASPtpp, R_CD2tex, R_FRUK, R_PLPS, R_AI2tpp, R_DB4PS, R_PANTS, R_PA140abcpp, R_ALATHRtr, R_VALTA, R_PTAtex, R_FCLT, R_FE3abcpp, R_DALAt2r, R_AMPEP3, R_GLYGLYCNc, R_ZNabcpp, R_HVCD, R_ALALEUabcpp, R_DAGK141, R_CLPNS160pp, R_NAt, R_CMCBTFtex, R_PG141abcpp, R_PPRDNDH, R_NDPK6, R_TRPS2, R_METRR, R_PRAIi, R_THIORDXi, R_PGP160abcpp, R_RIBtex, R_CU2abcpp, R_MDNTHAep, R_KARA2, R_NADHPO, R_4HGLSD, R_DPR, R_FDH4pp, R_ACSPHAC60, R_NH3c, R_OMPDC, R_ASPK, R_ASNt2r, R_SERGLUGLNtr, R_GLUTRS_2, R_MOBDabc_rev, R_MHPGLUT, R_GTHRDt2_1, R_FAO11, R_NO2tex, R_CU2t4pp, R_HMR_0188, R_VECOAH, R_PGL, R_PA180abcpp, R_IGPDH, R_KGD2, R_PNP_1, R_GLYCLTDy, R_RHACOAEP50, R_PGAMT, R_ORNTA, R_FACOAE60, R_DHAD1, R_FORtppi, R_RHACOAE100, R_FMNRx, R_HMEDS, R_DTBTST, R_PYRtex, R_FACOAL50t2pp, R_GLCS3_1, R_METS, R_NAabc, R_THYMt, R_ADSK, R_PYK, R_UAMAS, R_PPNCL3, R_GLUTRS_3, R_FDH4pp_1, R_AMPTASEGGLN, R_ARBt3ipp, R_DACL, R_LEULEULAPc, R_GNP, R_MAGLIPA180ex, R_DHFR, R_DHFS, R_UGMDDS, R_ALCDpp, R_RNDR3b, R_PRPPS, R_PNTOt2, R_FACOAL161t2pp, R_ADK1, R_ACSPHAC50, R_RECOAH2, R_CAt6, R_BUTt4pp, R_NADPHXE, R_ACSPHACP60, R_ASAD, R_TAGLIPA160ex, R_GRTT, R_BMNt, R_MCITD, R_TREabc, R_FRUptspp, R_PNCDC, R_GCALDt, R_PDXPP, R_TAGLIPA180ex, R_GLYOX, R_GLYGLYGLNtr, R_GLYGLNtr, R_SERabc, R_MTHFR3, R_HSDy, R_ASPabc, R_THZPSN, R_TMDPK, R_PRASCSi, R_FALDtpp, R_DAGLIPA181d9ex, R_GALUi, R_MALt2_3pp, R_CO2t, R_ADCL, R_ACSPHAC142, R_PPCOAC, R_ARBT6Pt, R_ALCD2y, R_FAS140, R_GLYCL, R_2AGPE141tipp, R_GLYGLYtex, R_St, R_PIt2rpp, R_PGPP181, R_MSHAMID, R_SSALy, R_G1PP, R_SUCCt2_3pp, R_SDPDS, R_ACSPHACP80, R_GLCpts, R_CREAT, R_GLCURt2r, R_HG2abcpp, R_NO2t2r, R_AMPEP16, R_ICDHyr, R_HPROx, R_PItex, R_SMIA2abc, R_AMMQLT8, R_RHACOAEP60, R_Clt, R_MTAM_1, R_DARBt3ipp, R_CRO4t3pp, R_BALAt2pp, R_MTHFR2, R_RNTR1, R_LALGP, R_GLYCt, R_Cuabc, R_AGPR, R_GLYCK2, R_PG160abcpp, R_MAN1PT2, R_PUNP1_1, R_2AGPG140tipp, R_H2CO3D, R_Kabcpp, R_L_LACt2r, R_ALATRPtex, R_GLYBt2r, R_PGSA181, R_PPCSCT, R_MI3PS, R_L_LACD3_1, R_MAGLIPA181d9ex, R_FACOAE70, R_ALALEUt, R_GF6PTA, R_GLCabc, R_IPDPUDCT, R_GLUN, R_GLUt4, R_METSOX1abc, R_3MBt4pp, R_MOBDabc, R_RNDR3, R_GLYTYRabc, R_FACOAE160, R_OCDOR, R_ABG4t2, R_PPAt4pp, R_PROabcpp, R_AMPTASEHH, R_NDPK2, R_PPAtex, R_ALATHRabcpp, R_TNTR4, R_CMCBTFL, R_SERt2r, R_TNTHAC1, R_12DGR160tipp, R_FE3PYOVDL2, R_URAt2pp, R_ABUTtex, R_H2SO, R_H2St1, R_DCAtex, R_DCTPD, R_NMNAT, R_RHACOAEP40, R_METabc, R_URIH, R_FACOAE180, R_LTHRK, R_NTPP8, R_MALt5, R_TDP, R_GLYSERabcpp, R_VALt2r, R_ALAHISabcpp, R_NTPTP2, R_ACSPHAC101, R_PHCD, R_AICART, R_PUNP3_1, R_CMCBTFU, R_CD2abcpp, R_DAGLIPA180ex, R_CYTK2, R_PGPP160pp, R_AMPEP12, R_MOTH3, R_5DKGR, R_PUNP5_1, R_CDAPPA160190, R_MAN1PT, R_NTPP7, R_TMDS, R_ILEabc, R_HBCHLR, R_ACLDC, R_OAADCS, R_ACOAD2f, R_FUMt2_3pp, R_CYStex, R_FACOAE80, R_TAURabc, R_GLYALDt, R_ADCS, R_NTPP3, R_TNTR2x, R_NTP ...
# DEBUG:root:[0.544 s] unsat cores were: [[R_FE3DCITabc]]

# %%
import re
test = re.compile(r"[*\.]\d*")
test.sub("", "hallo.h")

# %%
libsbml.writeSBMLToFile(document, "model_MCC_libsbml.xml")

# %% [markdown]
# If you have access (currently requires an explicit academic license or a subscription) and downloaded the BioCyc flat files, you can pass the corresponding directory as well. Assuming we have already updated all the ids in the last step, we can set _update_ids_ to _False_.
#
# The additional argument is:
# * **biocyc_path**: Directory containing BioCyc flat files.

# %% [markdown]
# ## Evaluating the result
# To see the results at a first glance, we can generate a quick visual report, which tells us how many reactions are balanced now, and how many assignments were changed.

# %%
#balancer.generate_visual_report().show()

# %% [markdown]
# ### Metabolite Report
# The algorithm should be able to give a reason for every assignment that it chooses. We can have a look at these reasons in the metabolite report of the balancer.
#
# The report holds valuable information how the algorithm decided which assignment to choose and can be useful during further manual curation. The entries of the resulting DataFrame are the following:
# * **Id**: Id of the metabolite in the model.
# * **Name**: Name of the metabolite in the model.
# * **Determined Formula**: Formula that was assigned by the algorithm.
# * **Determined Charge**: Charge that was assigned by the algorithm.
# * **Previous Formula**: Formula that was assigned before the algorithm.
# * **Previous Charge**: Charge that was assigned before the algorithm.
# * **Inferrence Type**: Category of how the assignment was determined.
#     - Unconstrained: No information about the metabolite was found or only incomplete (wildcard containing) formulae were found and we could not find a concrete formula either. Should contain a wildcard.
#     - Inferred: No information about the metabolite was found or only incomplete (wildcard containing formulae were found, however we arrived at a concrete formula. Should not contain a wildcard.
#     - Clean: Information about the metabolite was found and used.
# * **Reasoning**: Reasoning how the assignment was determined. Can contain:
#     - database name:database identifier: The formula could be found in this database under this identifier.
#     - (unconstrained) Target: This assignment was chosen because it is the same as in the original (target) model. Unconstrained means that the original (target) model seemed to be missing a wildcard symbol that was thus added.
#     - Reaction_id (metabolite id -> Reasoning...): The assignment for this metabolite must follow from other reasons. The given reaction id and metabolite reasons make it so that if the model must be balanced, this metabolite must have the determined assignment.
#     - Used Databases: The databases which back up the determined assignment.
#     - Previous Databases: The databases which back up the previous assignment.

# %%
metabolite_report_df = balancer.generate_metabolite_report()
metabolite_report_df[::200]

# %% [markdown]
# Usually we are interested in the assignments which differ from the original report. We can do this by indexing the Dataframe accordingly.

# %%
# If you like to see the entire report, uncomment the following line
#pandas.set_option("display.max_row", None)
metabolite_report_df[metabolite_report_df["Similarity"] != "Same"]

# %% [markdown]
# We might also be interested in all assignments which are not backed by a database:

# %%
metabolite_report_df[metabolite_report_df["Used Databases"] == ""]

# %% [markdown]
# ### Reaction Report
# Finally, especially for further curation, we might be interested in the remaining imbalanced reactions. For this the algorithm can also provide a report.
#
# The report also includes reactions which are technically balanced but where many protons had to be added to arrive at that result.
#
# The fields are as follows:
# * **Id**: Id of the reaction in the model.
# * **Unbalanced Reaction**: Name of the reaction in the model and corresponding equation.
# * **Unbalanced Type**: Type of imbalance. Can be both Mass and charge, only mass, only charge or high proton count.
# * **Reason**: Set of reactions which caused the reaction to be imbalanced. This effectively means that these reactions could not be balanced together. The sets are minimal, but for example for BTS2, it would not help to remove HCYSMT, as BTS2 would require protons to have no charge and HCYSMT is only one of many reactions which then would not be balanced.
# * **Shared Metabolites**: Metabolites which are shared between the reactions which are listed in Reason. Can give an indication where the problem might lie.
# * **Mass Difference**: Mass imbalance.
# * **Charge Difference**: Charge imbalance.

# %%
balancer.generate_reaction_report()

# %% [markdown]
# ### Writing Files
# The mass charge curation writes directly to the model that was given to it. Thus, if we want to write our model, we can just pass the model to cobrapy. If you want to keep your old model, you should make sure to not overwrite it here.

# %%
cobra.io.write_sbml_model(model, f"{model.id}_MCC.xml")

# %% [markdown]
# For the reports, we can add filenames to the functions to write the visual report to a .png file and the metabolite and reaction DataFrames to .csv files.

# %%
balancer.generate_visual_report(f"{model.id}_visual")
balancer.generate_metabolite_report(f"{model.id}_metabolites")
balancer.generate_reaction_report(f"{model.id}_reactions")
pass

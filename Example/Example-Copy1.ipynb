# %% [markdown]
# # Usage example on model of _Corynebacterium tuberculostearicum (high GC Gram+)_.
# In this notebook we show how to use the Mass Charge Curation python package. As an example model we use a model of [_Corynebacterium tuberculostearicum (high GC Gram+)_, strain DSM 44922](https://www.ncbi.nlm.nih.gov/assembly/GCF_013408445.1/) created with [CarveMe Version 1.5.1](https://carveme.readthedocs.io/en/latest/index.html), which here is simply called _model.xml_.

# %% [markdown]
# If you are interested in a more verbose output you can uncomment the following line:

# %%
import logging; logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## Dependencies
# First we will check if all dependencies of the curation package are fullfilled.

# %%
try: import numpy
except Exception as e: print("You seem to be missing numpy. You can usually install it via 'pip install numpy'"); raise e
try: import pandas
except Exception as e: print("You seem to be missing pandas. You can usually install it via 'pip install pandas'"); raise e
try: import cobra
except Exception as e: print("You seem to be missing cobrapy. See https://github.com/opencobra/cobrapy on how to install it."); raise e
try: import z3
except Exception as e: print("You seem to be missing z3 or the corresponding python bindings. See https://github.com/Z3Prover/z3 on how to install it."); raise e

# %% [markdown]
# Next we see if the Mass Charge Curation package is installed properly.

# %%
try: import MCC
except Exception as e: print("The mass charge curation package does not seem to be installed correctly. Make sure you have the correct python version installed and try running pip install -e ./.. in the folder of this notebook."); raise e

# %% [markdown]
# ## Loading the model
# Once all dependencies are installed, we can take a look at our example model.

# %% [markdown]
# First we will read in our model using cobrapy.

# %%
model = cobra.io.read_sbml_model("model.xml")
print(f"The model has {len(model.metabolites)} metabolites and {len(model.reactions)} reactions.")
# Out:
# The model has 1019 metabolites and 1481 reactions.

# %% [markdown]
# We can first take a look at how many reactions in our model are unbalanced.

# %% [markdown]
# ## Curating Mass and Charge
# We can now instantiate a curation class. There are different ways to use the package, depending how data should be gathered, how much curation has already been done and how much data is available offline.
#
# We will first give an example of the most simple usage, downloading as many databases as possible and updating all [identifiers.org](https://identifiers.org/) identifiers we need for the package to work optimally. This will take significantly longer (~ 15 Minutes) than running the algorithm on an already annotated model, however it is important to use the most up-to-date identifiers if we want to include as much information as possible.
#
# This will create a folder _/data_ in the current directory where all database information is downloaded to.
#
# The arguments are as follows:
# * **model**: Model we want to curate.
# * **data_path**: Path to the directory containing database files. Defaults to _/data_. If the directory does not exist, it will be created. If a file cannot be found, we will try to download it.
# * **update_ids**: If this is set to _True_, we will first try to update all [identifiers.org](https://identifiers.org/) ids. This will take a while but is important to properly index the different databases. Defaults to _False_.
#
# **Note**: It is expected to see _No objective coefficients in model. Unclear what should be optimized_ warnings here, this poses no problem for this package.

# %%
import libsbml
filename = "model.xml"
reader = libsbml.SBMLReader()
document = reader.readSBML(filename)
model = document.getModel()

# %%
balancer = MCC.MassChargeCuration(model = model, data_path = "./data", update_ids = False)
# Out:
# INFO:root:1/1019: Getting information for 10fthf_c
# INFO:root:2/1019: Getting information for 12dgr140_c
# INFO:root:3/1019: Getting information for 12dgr140_p
# INFO:root:4/1019: Getting information for 12dgr141_c
# INFO:root:5/1019: Getting information for 12dgr141_p
# INFO:root:6/1019: Getting information for 12dgr160_c
# INFO:root:7/1019: Getting information for 12dgr160_e
# INFO:root:8/1019: Getting information for 12dgr160_p
# INFO:root:9/1019: Getting information for 12dgr180_c
# INFO:root:10/1019: Getting information for 12dgr180_e
# INFO:root:11/1019: Getting information for 12dgr180_p
# INFO:root:12/1019: Getting information for 12dgr181_c
# INFO:root:13/1019: Getting information for 12dgr181_p
# INFO:root:14/1019: Getting information for 12ppd__S_c
# INFO:root:15/1019: Getting information for 12ppd__S_e
# INFO:root:16/1019: Getting information for 13dpg_c
# INFO:root:17/1019: Getting information for 15dap_c
# INFO:root:18/1019: Getting information for 1ag160_e
# INFO:root:19/1019: Getting information for 1ag180_e
# INFO:root:20/1019: Getting information for 1ag181d9_e
# INFO:root:21/1019: Getting information for 1ag182d9d12_e
# INFO:root:22/1019: Getting information for 1p3h5c_c
# INFO:root:23/1019: Getting information for 1pyr5c_c
# INFO:root:24/1019: Getting information for 23dhdp_c
# INFO:root:25/1019: Getting information for 23dhmb_c
# INFO:root:26/1019: Getting information for 23dhmp_c
# INFO:root:27/1019: Getting information for 25aics_c
# INFO:root:28/1019: Getting information for 25dhpp_c
# INFO:root:29/1019: Getting information for 25drapp_c
# INFO:root:30/1019: Getting information for 26dap_LL_c
# INFO:root:31/1019: Getting information for 26dap__M_c
# INFO:root:32/1019: Getting information for 2agpe120_c
# INFO:root:33/1019: Getting information for 2agpe120_p
# INFO:root:34/1019: Getting information for 2agpe141_c
# INFO:root:35/1019: Getting information for 2agpe141_p
# INFO:root:36/1019: Getting information for 2agpe160_c
# INFO:root:37/1019: Getting information for 2agpe160_p
# INFO:root:38/1019: Getting information for 2agpe161_c
# INFO:root:39/1019: Getting information for 2agpe161_p
# INFO:root:40/1019: Getting information for 2agpg140_c
# INFO:root:41/1019: Getting information for 2agpg140_p
# INFO:root:42/1019: Getting information for 2agpg180_c
# INFO:root:43/1019: Getting information for 2agpg180_p
# INFO:root:44/1019: Getting information for 2ahbut_c
# INFO:root:45/1019: Getting information for 2ahhmd_c
# INFO:root:46/1019: Getting information for 2ahhmp_c
# INFO:root:47/1019: Getting information for 2aobut_c
# INFO:root:48/1019: Getting information for 2cpr5p_c
# INFO:root:49/1019: Getting information for 2dda7p_c
# INFO:root:50/1019: Getting information for 2dhp_c
# INFO:root:51/1019: Getting information for 2dmmq8_c
# INFO:root:52/1019: Getting information for 2dmmql8_c
# INFO:root:53/1019: Getting information for 2dr1p_c
# INFO:root:54/1019: Getting information for 2dr5p_c
# INFO:root:55/1019: Getting information for 2hadnt_c
# INFO:root:56/1019: Getting information for 2ippm_c
# INFO:root:57/1019: Getting information for 2m35mdntha_c
# INFO:root:58/1019: Getting information for 2m35mdntha_e
# INFO:root:59/1019: Getting information for 2mahmp_c
# INFO:root:60/1019: Getting information for 2mcacn_c
# INFO:root:61/1019: Getting information for 2mcit_c
# INFO:root:62/1019: Getting information for 2me4p_c
# INFO:root:63/1019: Getting information for 2mecdp_c
# INFO:root:64/1019: Getting information for 2obut_c
# INFO:root:65/1019: Getting information for 2p4c2me_c
# INFO:root:66/1019: Getting information for 2pg_c
# INFO:root:67/1019: Getting information for 2sephchc_c
# INFO:root:68/1019: Getting information for 2shchc_c
# INFO:root:69/1019: Getting information for 34hpp_c
# INFO:root:70/1019: Getting information for 35dnta_c
# INFO:root:71/1019: Getting information for 35dnta_e
# INFO:root:72/1019: Getting information for 3c2hmp_c
# INFO:root:73/1019: Getting information for 3c3hmp_c
# INFO:root:74/1019: Getting information for 3c4mop_c
# INFO:root:75/1019: Getting information for 3dhq_c
# INFO:root:76/1019: Getting information for 3dhsk_c
# INFO:root:77/1019: Getting information for 3hbcoa__R_c
# INFO:root:78/1019: Getting information for 3hbcoa_c
# INFO:root:79/1019: Getting information for 3hpcoa_c
# INFO:root:80/1019: Getting information for 3hptcoa_c
# INFO:root:81/1019: Getting information for 3ig3p_c
# INFO:root:82/1019: Getting information for 3mb_c
# INFO:root:83/1019: Getting information for 3mb_e
# INFO:root:84/1019: Getting information for 3mb_p
# INFO:root:85/1019: Getting information for 3mob_c
# INFO:root:86/1019: Getting information for 3mop_c
# INFO:root:87/1019: Getting information for 3opcoa_c
# INFO:root:88/1019: Getting information for 3optcoa_c
# INFO:root:89/1019: Getting information for 3pg_c
# INFO:root:90/1019: Getting information for 3php_c
# INFO:root:91/1019: Getting information for 3psme_c
# INFO:root:92/1019: Getting information for 4abut_c
# INFO:root:93/1019: Getting information for 4abut_e
# INFO:root:94/1019: Getting information for 4abut_p
# INFO:root:95/1019: Getting information for 4abz_c
# INFO:root:96/1019: Getting information for 4adcho_c
# INFO:root:97/1019: Getting information for 4ahmmp_c
# INFO:root:98/1019: Getting information for 4ahmmp_e
# INFO:root:99/1019: Getting information for 4ampm_c
# INFO:root:100/1019: Getting information for 4c2me_c
# INFO:root:101/1019: Getting information for 4hadnt_c
# INFO:root:102/1019: Getting information for 4hba_c
# INFO:root:103/1019: Getting information for 4hba_e
# INFO:root:104/1019: Getting information for 4hglusa_c
# INFO:root:105/1019: Getting information for 4hpro_LT_c
# INFO:root:106/1019: Getting information for 4izp_c
# INFO:root:107/1019: Getting information for 4mhetz_c
# INFO:root:108/1019: Getting information for 4mop_c
# INFO:root:109/1019: Getting information for 4mpetz_c
# INFO:root:110/1019: Getting information for 4pasp_c
# INFO:root:111/1019: Getting information for 4ppan_c
# INFO:root:112/1019: Getting information for 4ppcys_c
# INFO:root:113/1019: Getting information for 4r5au_c
# INFO:root:114/1019: Getting information for 5aizc_c
# INFO:root:115/1019: Getting information for 5aop_c
# INFO:root:116/1019: Getting information for 5aprbu_c
# INFO:root:117/1019: Getting information for 5apru_c
# INFO:root:118/1019: Getting information for 5aptn_c
# INFO:root:119/1019: Getting information for 5dglcn_c
# INFO:root:120/1019: Getting information for 5dglcn_e
# INFO:root:121/1019: Getting information for 5dglcn_p
# INFO:root:122/1019: Getting information for 5drib_c
# INFO:root:123/1019: Getting information for 5drib_e
# INFO:root:124/1019: Getting information for 5fthf_c
# INFO:root:125/1019: Getting information for 5mcsn_c
# INFO:root:126/1019: Getting information for 5mthf_c
# INFO:root:127/1019: Getting information for 6hmhpt_c
# INFO:root:128/1019: Getting information for 6hmhptpp_c
# INFO:root:129/1019: Getting information for 6pgc_c
# INFO:root:130/1019: Getting information for 6pgl_c
# INFO:root:131/1019: Getting information for LalaLglu_c
# INFO:root:132/1019: Getting information for LalaLglu_e
# INFO:root:133/1019: Getting information for LalaLglu_p
# INFO:root:134/1019: Getting information for R3hdec4coa_c
# INFO:root:135/1019: Getting information for R3hdec4e_c
# INFO:root:136/1019: Getting information for R_3h4atba_c
# INFO:root:137/1019: Getting information for R_3h4atbcoa_c
# INFO:root:138/1019: Getting information for R_3h6atha_c
# INFO:root:139/1019: Getting information for R_3h6athcoa_c
# INFO:root:140/1019: Getting information for R_3hcddec5ecoa_c
# INFO:root:141/1019: Getting information for R_3hcmrs7e_c
# INFO:root:142/1019: Getting information for R_3hcmrs7ecoa_c
# INFO:root:143/1019: Getting information for R_3hdcaa_c
# INFO:root:144/1019: Getting information for R_3hdcoa_c
# INFO:root:145/1019: Getting information for R_3hdd5ea_c
# INFO:root:146/1019: Getting information for R_3hdd6coa_c
# INFO:root:147/1019: Getting information for R_3hdd6e_c
# INFO:root:148/1019: Getting information for R_3hdda_c
# INFO:root:149/1019: Getting information for R_3hddcoa_c
# INFO:root:150/1019: Getting information for R_3hhcoa_c
# INFO:root:151/1019: Getting information for R_3hhdca_c
# INFO:root:152/1019: Getting information for R_3hhdcoa_c
# INFO:root:153/1019: Getting information for R_3hhpa_c
# INFO:root:154/1019: Getting information for R_3hhpcoa_c
# INFO:root:155/1019: Getting information for R_3hhxa_c
# INFO:root:156/1019: Getting information for R_3hhxa_e
# INFO:root:157/1019: Getting information for R_3hhxa_p
# INFO:root:158/1019: Getting information for R_3hmrscoa_c
# INFO:root:159/1019: Getting information for R_3hnonaa_c
# INFO:root:160/1019: Getting information for R_3hnonacoa_c
# INFO:root:161/1019: Getting information for R_3hocoa_c
# INFO:root:162/1019: Getting information for R_3hocta_c
# INFO:root:163/1019: Getting information for R_3hpba_c
# INFO:root:164/1019: Getting information for R_3hpbcoa_c
# INFO:root:165/1019: Getting information for R_3hpdeca_c
# INFO:root:166/1019: Getting information for R_3hpdecacoa_c
# INFO:root:167/1019: Getting information for R_3hphpa_c
# INFO:root:168/1019: Getting information for R_3hphpcoa_c
# INFO:root:169/1019: Getting information for R_3hphxa_c
# INFO:root:170/1019: Getting information for R_3hphxacoa_c
# INFO:root:171/1019: Getting information for R_3hpnona_c
# INFO:root:172/1019: Getting information for R_3hpnonacoa_c
# INFO:root:173/1019: Getting information for R_3hpocta_c
# INFO:root:174/1019: Getting information for R_3hpoctacoa_c
# INFO:root:175/1019: Getting information for R_3hppta_c
# INFO:root:176/1019: Getting information for R_3hpptcoa_c
# INFO:root:177/1019: Getting information for R_3hpt_c
# INFO:root:178/1019: Getting information for R_3hptcoa_c
# INFO:root:179/1019: Getting information for R_3htd58coa_c
# INFO:root:180/1019: Getting information for R_3htd58e_c
# INFO:root:181/1019: Getting information for R_3htd5coa_c
# INFO:root:182/1019: Getting information for R_3htd5e_c
# INFO:root:183/1019: Getting information for R_3httdca_c
# INFO:root:184/1019: Getting information for S2hglut_c
# INFO:root:185/1019: Getting information for aacald_c
# INFO:root:186/1019: Getting information for aacoa_c
# INFO:root:187/1019: Getting information for aact_c
# INFO:root:188/1019: Getting information for abg4_c
# INFO:root:189/1019: Getting information for abg4_e
# INFO:root:190/1019: Getting information for ac_c
# INFO:root:191/1019: Getting information for ac_e
# INFO:root:192/1019: Getting information for ac_p
# INFO:root:193/1019: Getting information for acald_c
# INFO:root:194/1019: Getting information for acald_e
# INFO:root:195/1019: Getting information for acald_p
# INFO:root:196/1019: Getting information for accoa_c
# INFO:root:197/1019: Getting information for acetol_c
# INFO:root:198/1019: Getting information for acg5p_c
# INFO:root:199/1019: Getting information for acg5sa_c
# INFO:root:200/1019: Getting information for acgam1p_c
# INFO:root:201/1019: Getting information for acgam6p_c
# INFO:root:202/1019: Getting information for acgam_e
# INFO:root:203/1019: Getting information for acglu_c
# INFO:root:204/1019: Getting information for acglu_e
# INFO:root:205/1019: Getting information for achms_c
# INFO:root:206/1019: Getting information for acmana_c
# INFO:root:207/1019: Getting information for acmanap_c
# INFO:root:208/1019: Getting information for acorn_c
# INFO:root:209/1019: Getting information for acser_c
# INFO:root:210/1019: Getting information for actn__R_c
# INFO:root:211/1019: Getting information for actn__R_e
# INFO:root:212/1019: Getting information for actp_c
# INFO:root:213/1019: Getting information for acysbmn_c
# INFO:root:214/1019: Getting information for acysbmn_e
# INFO:root:215/1019: Getting information for ade_c
# INFO:root:216/1019: Getting information for adhlam_c
# INFO:root:217/1019: Getting information for adn_c
# INFO:root:218/1019: Getting information for adp_c
# INFO:root:219/1019: Getting information for adpglc_c
# INFO:root:220/1019: Getting information for adprib_c
# INFO:root:221/1019: Getting information for ahcys_c
# INFO:root:222/1019: Getting information for ahdt_c
# INFO:root:223/1019: Getting information for aicar_c
# INFO:root:224/1019: Getting information for air_c
# INFO:root:225/1019: Getting information for akg_c
# INFO:root:226/1019: Getting information for ala_B_c
# INFO:root:227/1019: Getting information for ala_B_e
# INFO:root:228/1019: Getting information for ala_B_p
# INFO:root:229/1019: Getting information for ala_L_asp__L_c
# INFO:root:230/1019: Getting information for ala_L_asp__L_e
# INFO:root:231/1019: Getting information for ala_L_glu__L_c
# INFO:root:232/1019: Getting information for ala_L_glu__L_e
# INFO:root:233/1019: Getting information for ala_L_thr__L_c
# INFO:root:234/1019: Getting information for ala_L_thr__L_e
# INFO:root:235/1019: Getting information for ala__D_c
# INFO:root:236/1019: Getting information for ala__D_e
# INFO:root:237/1019: Getting information for ala__L_c
# INFO:root:238/1019: Getting information for ala__L_e
# INFO:root:239/1019: Getting information for ala_gln_c
# INFO:root:240/1019: Getting information for ala_gln_e
# INFO:root:241/1019: Getting information for ala_his_c
# INFO:root:242/1019: Getting information for ala_his_e
# INFO:root:243/1019: Getting information for ala_leu_c
# INFO:root:244/1019: Getting information for ala_leu_e
# INFO:root:245/1019: Getting information for alaala_c
# INFO:root:246/1019: Getting information for alac__S_c
# INFO:root:247/1019: Getting information for alagly_c
# INFO:root:248/1019: Getting information for alagly_e
# INFO:root:249/1019: Getting information for alahis_c
# INFO:root:250/1019: Getting information for alahis_e
# INFO:root:251/1019: Getting information for alahis_p
# INFO:root:252/1019: Getting information for alaleu_c
# INFO:root:253/1019: Getting information for alaleu_e
# INFO:root:254/1019: Getting information for alaleu_p
# INFO:root:255/1019: Getting information for alathr_c
# INFO:root:256/1019: Getting information for alathr_e
# INFO:root:257/1019: Getting information for alathr_p
# INFO:root:258/1019: Getting information for alatrp_c
# INFO:root:259/1019: Getting information for alatrp_e
# INFO:root:260/1019: Getting information for alatrp_p
# INFO:root:261/1019: Getting information for allphn_c
# INFO:root:262/1019: Getting information for alpro_c
# INFO:root:263/1019: Getting information for amet_c
# INFO:root:264/1019: Getting information for amp_c
# INFO:root:265/1019: Getting information for anth_c
# INFO:root:266/1019: Getting information for ap4a_c
# INFO:root:267/1019: Getting information for aps_c
# INFO:root:268/1019: Getting information for arab__D_c
# INFO:root:269/1019: Getting information for arab__D_p
# INFO:root:270/1019: Getting information for arab__L_c
# INFO:root:271/1019: Getting information for arab__L_p
# INFO:root:272/1019: Getting information for arbt6p_c
# INFO:root:273/1019: Getting information for arbt6p_e
# INFO:root:274/1019: Getting information for arbt_e
# INFO:root:275/1019: Getting information for arg__L_c
# INFO:root:276/1019: Getting information for arg__L_e
# INFO:root:277/1019: Getting information for arg__L_p
# INFO:root:278/1019: Getting information for argsuc_c
# INFO:root:279/1019: Getting information for asn__L_c
# INFO:root:280/1019: Getting information for asn__L_e
# INFO:root:281/1019: Getting information for asn__L_p
# INFO:root:282/1019: Getting information for aso3_c
# INFO:root:283/1019: Getting information for aso3_e
# INFO:root:284/1019: Getting information for aso3_p
# INFO:root:285/1019: Getting information for aso4_c
# INFO:root:286/1019: Getting information for aso4_p
# INFO:root:287/1019: Getting information for asp__L_c
# INFO:root:288/1019: Getting information for asp__L_e
# INFO:root:289/1019: Getting information for asp__L_p
# INFO:root:290/1019: Getting information for aspsa_c
# INFO:root:291/1019: Getting information for atp_c
# INFO:root:292/1019: Getting information for b2coa_c
# INFO:root:293/1019: Getting information for betald_c
# INFO:root:294/1019: Getting information for bhb_c
# INFO:root:295/1019: Getting information for bmn_c
# INFO:root:296/1019: Getting information for bmn_e
# INFO:root:297/1019: Getting information for bmnmsh_c
# INFO:root:298/1019: Getting information for btcoa_c
# INFO:root:299/1019: Getting information for btn_c
# INFO:root:300/1019: Getting information for but_c
# INFO:root:301/1019: Getting information for but_e
# INFO:root:302/1019: Getting information for but_p
# INFO:root:303/1019: Getting information for ca2_c
# INFO:root:304/1019: Getting information for ca2_e
# INFO:root:305/1019: Getting information for camp_c
# INFO:root:306/1019: Getting information for cbasp_c
# INFO:root:307/1019: Getting information for cbp_c
# INFO:root:308/1019: Getting information for cd2_c
# INFO:root:309/1019: Getting information for cd2_e
# INFO:root:310/1019: Getting information for cd2_p
# INFO:root:311/1019: Getting information for cdp_c
# INFO:root:312/1019: Getting information for cdpc16c19g_c
# INFO:root:313/1019: Getting information for cdpc19c19g_c
# INFO:root:314/1019: Getting information for cdpdhdecg_c
# INFO:root:315/1019: Getting information for cdpdodec11eg_c
# INFO:root:316/1019: Getting information for cdpdtdec7eg_c
# INFO:root:317/1019: Getting information for cgly_c
# INFO:root:318/1019: Getting information for cgly_e
# INFO:root:319/1019: Getting information for cgly_p
# INFO:root:320/1019: Getting information for chol_c
# INFO:root:321/1019: Getting information for chol_e
# INFO:root:322/1019: Getting information for chol_p
# INFO:root:323/1019: Getting information for chor_c
# INFO:root:324/1019: Getting information for cigam_c
# INFO:root:325/1019: Getting information for cit_c
# INFO:root:326/1019: Getting information for cit_e
# INFO:root:327/1019: Getting information for citr__L_c
# INFO:root:328/1019: Getting information for cl_c
# INFO:root:329/1019: Getting information for cl_e
# INFO:root:330/1019: Getting information for clpn141_p
# INFO:root:331/1019: Getting information for clpn160_p
# INFO:root:332/1019: Getting information for clpn181_p
# INFO:root:333/1019: Getting information for cmcbtt_c
# INFO:root:334/1019: Getting information for cmcbtt_e
# INFO:root:335/1019: Getting information for cmcbtt_p
# INFO:root:336/1019: Getting information for cmp_c
# INFO:root:337/1019: Getting information for cmp_e
# INFO:root:338/1019: Getting information for co2_c
# INFO:root:339/1019: Getting information for co2_e
# INFO:root:340/1019: Getting information for co2_p
# INFO:root:341/1019: Getting information for coa_c
# INFO:root:342/1019: Getting information for cobalt2_c
# INFO:root:343/1019: Getting information for cobalt2_e
# INFO:root:344/1019: Getting information for cobalt2_p
# INFO:root:345/1019: Getting information for cpppg3_c
# INFO:root:346/1019: Getting information for creat_c
# INFO:root:347/1019: Getting information for creat_e
# INFO:root:348/1019: Getting information for creat_p
# INFO:root:349/1019: Getting information for cro4_c
# INFO:root:350/1019: Getting information for cro4_p
# INFO:root:351/1019: Getting information for csn_c
# INFO:root:352/1019: Getting information for ctp_c
# INFO:root:353/1019: Getting information for cu2_c
# INFO:root:354/1019: Getting information for cu2_e
# INFO:root:355/1019: Getting information for cu2_p
# INFO:root:356/1019: Getting information for cys__L_c
# INFO:root:357/1019: Getting information for cys__L_e
# INFO:root:358/1019: Getting information for cys__L_p
# INFO:root:359/1019: Getting information for cyst__L_c
# INFO:root:360/1019: Getting information for cytd_c
# INFO:root:361/1019: Getting information for dad_2_c
# INFO:root:362/1019: Getting information for dad_5_c
# INFO:root:363/1019: Getting information for dadp_c
# INFO:root:364/1019: Getting information for dag181d9_e
# INFO:root:365/1019: Getting information for dag182d9d12_e
# INFO:root:366/1019: Getting information for damp_c
# INFO:root:367/1019: Getting information for datp_c
# INFO:root:368/1019: Getting information for db4p_c
# INFO:root:369/1019: Getting information for dca_c
# INFO:root:370/1019: Getting information for dca_e
# INFO:root:371/1019: Getting information for dca_p
# INFO:root:372/1019: Getting information for dcacoa_c
# INFO:root:373/1019: Getting information for dcamp_c
# INFO:root:374/1019: Getting information for dcdp_c
# INFO:root:375/1019: Getting information for dcmp_c
# INFO:root:376/1019: Getting information for dctp_c
# INFO:root:377/1019: Getting information for ddca_c
# INFO:root:378/1019: Getting information for ddca_e
# INFO:root:379/1019: Getting information for ddca_p
# INFO:root:380/1019: Getting information for ddcacoa_c
# INFO:root:381/1019: Getting information for decdp_c
# INFO:root:382/1019: Getting information for decdp_tb_c
# INFO:root:383/1019: Getting information for dgdp_c
# INFO:root:384/1019: Getting information for dgmp_c
# INFO:root:385/1019: Getting information for dgsn_c
# INFO:root:386/1019: Getting information for dgtp_c
# INFO:root:387/1019: Getting information for dha_c
# INFO:root:388/1019: Getting information for dhap_c
# INFO:root:389/1019: Getting information for dhf_c
# INFO:root:390/1019: Getting information for dhlam_c
# INFO:root:391/1019: Getting information for dhlpro_c
# INFO:root:392/1019: Getting information for dhna_c
# INFO:root:393/1019: Getting information for dhnpt_c
# INFO:root:394/1019: Getting information for dhor__S_c
# INFO:root:395/1019: Getting information for dhpmp_c
# INFO:root:396/1019: Getting information for dhpt_c
# INFO:root:397/1019: Getting information for dhptd_c
# INFO:root:398/1019: Getting information for dhptd_e
# INFO:root:399/1019: Getting information for din_c
# INFO:root:400/1019: Getting information for dmlz_c
# INFO:root:401/1019: Getting information for dmpp_c
# INFO:root:402/1019: Getting information for dnad_c
# INFO:root:403/1019: Getting information for dpcoa_c
# INFO:root:404/1019: Getting information for drib_c
# INFO:root:405/1019: Getting information for drib_e
# INFO:root:406/1019: Getting information for dscl_c
# INFO:root:407/1019: Getting information for dtbt_c
# INFO:root:408/1019: Getting information for dtdp_c
# INFO:root:409/1019: Getting information for dtmp_c
# INFO:root:410/1019: Getting information for dttp_c
# INFO:root:411/1019: Getting information for dudp_c
# INFO:root:412/1019: Getting information for dump_c
# INFO:root:413/1019: Getting information for duri_c
# INFO:root:414/1019: Getting information for dutp_c
# INFO:root:415/1019: Getting information for dxyl5p_c
# INFO:root:416/1019: Getting information for e4hglu_c
# INFO:root:417/1019: Getting information for e4p_c
# INFO:root:418/1019: Getting information for eig3p_c
# INFO:root:419/1019: Getting information for etha_c
# INFO:root:420/1019: Getting information for etha_e
# INFO:root:421/1019: Getting information for etoh_c
# INFO:root:422/1019: Getting information for etoh_p
# INFO:root:423/1019: Getting information for f1p_c
# INFO:root:424/1019: Getting information for f6p_c
# INFO:root:425/1019: Getting information for fad_c
# INFO:root:426/1019: Getting information for fadh2_c
# INFO:root:427/1019: Getting information for fald_c
# INFO:root:428/1019: Getting information for fald_p
# INFO:root:429/1019: Getting information for fcmcbtt_c
# INFO:root:430/1019: Getting information for fdp_c
# INFO:root:431/1019: Getting information for fdxox_c
# INFO:root:432/1019: Getting information for fdxrd_c
# INFO:root:433/1019: Getting information for fe2_c
# INFO:root:434/1019: Getting information for fe2_e
# INFO:root:435/1019: Getting information for fe2_p
# INFO:root:436/1019: Getting information for fe3_c
# INFO:root:437/1019: Getting information for fe3_e
# INFO:root:438/1019: Getting information for fe3_p
# INFO:root:439/1019: Getting information for fe3dcit_e
# INFO:root:440/1019: Getting information for fe3pyovd_kt_e
# INFO:root:441/1019: Getting information for fe3pyovd_kt_p
# INFO:root:442/1019: Getting information for fgam_c
# INFO:root:443/1019: Getting information for ficytc_c
# INFO:root:444/1019: Getting information for fmcbtt_c
# INFO:root:445/1019: Getting information for fmn_c
# INFO:root:446/1019: Getting information for fmnh2_c
# INFO:root:447/1019: Getting information for focytc_c
# INFO:root:448/1019: Getting information for fol_c
# INFO:root:449/1019: Getting information for fol_e
# INFO:root:450/1019: Getting information for for_c
# INFO:root:451/1019: Getting information for for_p
# INFO:root:452/1019: Getting information for forcoa_c
# INFO:root:453/1019: Getting information for forglu_c
# INFO:root:454/1019: Getting information for fpram_c
# INFO:root:455/1019: Getting information for fprica_c
# INFO:root:456/1019: Getting information for frdp_c
# INFO:root:457/1019: Getting information for frmd_c
# INFO:root:458/1019: Getting information for fru_c
# INFO:root:459/1019: Getting information for fru_e
# INFO:root:460/1019: Getting information for fru_p
# INFO:root:461/1019: Getting information for fum_c
# INFO:root:462/1019: Getting information for fum_e
# INFO:root:463/1019: Getting information for fum_p
# INFO:root:464/1019: Getting information for g1p_c
# INFO:root:465/1019: Getting information for g3p_c
# INFO:root:466/1019: Getting information for g6p_c
# INFO:root:467/1019: Getting information for gal1p_c
# INFO:root:468/1019: Getting information for gal_c
# INFO:root:469/1019: Getting information for gal_p
# INFO:root:470/1019: Getting information for gam1p_c
# INFO:root:471/1019: Getting information for gam6p_c
# INFO:root:472/1019: Getting information for gam_e
# INFO:root:473/1019: Getting information for gar_c
# INFO:root:474/1019: Getting information for gcald_c
# INFO:root:475/1019: Getting information for gcald_e
# INFO:root:476/1019: Getting information for gdp_c
# INFO:root:477/1019: Getting information for gdpmann_c
# INFO:root:478/1019: Getting information for gdptp_c
# INFO:root:479/1019: Getting information for ggdp_c
# INFO:root:480/1019: Getting information for glc__D_c
# INFO:root:481/1019: Getting information for glc__D_e
# INFO:root:482/1019: Getting information for glc__D_p
# INFO:root:483/1019: Getting information for glcn__D_c
# INFO:root:484/1019: Getting information for glcn__D_e
# INFO:root:485/1019: Getting information for glcn_c
# INFO:root:486/1019: Getting information for glcn_e
# INFO:root:487/1019: Getting information for glcn_p
# INFO:root:488/1019: Getting information for glcur_c
# INFO:root:489/1019: Getting information for glcur_e
# INFO:root:490/1019: Getting information for glcur_p
# INFO:root:491/1019: Getting information for gln__L_c
# INFO:root:492/1019: Getting information for gln__L_e
# INFO:root:493/1019: Getting information for glu1sa_c
# INFO:root:494/1019: Getting information for glu5p_c
# INFO:root:495/1019: Getting information for glu5sa_c
# INFO:root:496/1019: Getting information for glu__D_c
# INFO:root:497/1019: Getting information for glu__L_c
# INFO:root:498/1019: Getting information for glu__L_e
# INFO:root:499/1019: Getting information for glu__L_p
# INFO:root:500/1019: Getting information for glutar_c
# INFO:root:501/1019: Getting information for glutrna_c
# INFO:root:502/1019: Getting information for glx_c
# INFO:root:503/1019: Getting information for gly_asn__L_c
# INFO:root:504/1019: Getting information for gly_asn__L_e
# INFO:root:505/1019: Getting information for gly_asp__L_c
# INFO:root:506/1019: Getting information for gly_asp__L_e
# INFO:root:507/1019: Getting information for gly_c
# INFO:root:508/1019: Getting information for gly_cys_c
# INFO:root:509/1019: Getting information for gly_cys_e
# INFO:root:510/1019: Getting information for gly_e
# INFO:root:511/1019: Getting information for gly_gln_c
# INFO:root:512/1019: Getting information for gly_gln_e
# INFO:root:513/1019: Getting information for gly_glu__L_c
# INFO:root:514/1019: Getting information for gly_glu__L_e
# INFO:root:515/1019: Getting information for gly_leu_c
# INFO:root:516/1019: Getting information for gly_leu_e
# INFO:root:517/1019: Getting information for gly_met_c
# INFO:root:518/1019: Getting information for gly_met_e
# INFO:root:519/1019: Getting information for gly_phe_c
# INFO:root:520/1019: Getting information for gly_phe_e
# INFO:root:521/1019: Getting information for gly_pro__L_c
# INFO:root:522/1019: Getting information for gly_pro__L_e
# INFO:root:523/1019: Getting information for gly_tyr_c
# INFO:root:524/1019: Getting information for gly_tyr_e
# INFO:root:525/1019: Getting information for glyald_c
# INFO:root:526/1019: Getting information for glyald_e
# INFO:root:527/1019: Getting information for glyb_c
# INFO:root:528/1019: Getting information for glyb_e
# INFO:root:529/1019: Getting information for glyb_p
# INFO:root:530/1019: Getting information for glyc3p_c
# INFO:root:531/1019: Getting information for glyc3p_e
# INFO:root:532/1019: Getting information for glyc__R_c
# INFO:root:533/1019: Getting information for glyc_c
# INFO:root:534/1019: Getting information for glyc_e
# INFO:root:535/1019: Getting information for glyc_p
# INFO:root:536/1019: Getting information for glyclt_c
# INFO:root:537/1019: Getting information for glyclt_e
# INFO:root:538/1019: Getting information for glyclt_p
# INFO:root:539/1019: Getting information for glyg4n_c
# INFO:root:540/1019: Getting information for glygln_c
# INFO:root:541/1019: Getting information for glygln_e
# INFO:root:542/1019: Getting information for glygln_p
# INFO:root:543/1019: Getting information for glyglu_c
# INFO:root:544/1019: Getting information for glyglu_e
# INFO:root:545/1019: Getting information for glyglu_p
# INFO:root:546/1019: Getting information for glygly_c
# INFO:root:547/1019: Getting information for glygly_e
# INFO:root:548/1019: Getting information for glygly_p
# INFO:root:549/1019: Getting information for glyglygln_c
# INFO:root:550/1019: Getting information for glyglygln_e
# INFO:root:551/1019: Getting information for glymet_c
# INFO:root:552/1019: Getting information for glymet_e
# INFO:root:553/1019: Getting information for glymet_p
# INFO:root:554/1019: Getting information for glyphe_c
# INFO:root:555/1019: Getting information for glyphe_e
# INFO:root:556/1019: Getting information for glyphe_p
# INFO:root:557/1019: Getting information for glyser_c
# INFO:root:558/1019: Getting information for glyser_e
# INFO:root:559/1019: Getting information for glyser_p
# INFO:root:560/1019: Getting information for gmp_c
# INFO:root:561/1019: Getting information for grdp_c
# INFO:root:562/1019: Getting information for grxox_c
# INFO:root:563/1019: Getting information for grxrd_c
# INFO:root:564/1019: Getting information for gsn_c
# INFO:root:565/1019: Getting information for gthox_c
# INFO:root:566/1019: Getting information for gthrd_c
# INFO:root:567/1019: Getting information for gthrd_e
# INFO:root:568/1019: Getting information for gthrd_p
# INFO:root:569/1019: Getting information for gtp_c
# INFO:root:570/1019: Getting information for gua_c
# INFO:root:571/1019: Getting information for gua_e
# INFO:root:572/1019: Getting information for h2co3_c
# INFO:root:573/1019: Getting information for h2mb4p_c
# INFO:root:574/1019: Getting information for h2o2_c
# INFO:root:575/1019: Getting information for h2o2_e
# INFO:root:576/1019: Getting information for h2o2_p
# INFO:root:577/1019: Getting information for h2o_c
# INFO:root:578/1019: Getting information for h2o_e
# INFO:root:579/1019: Getting information for h2o_p
# INFO:root:580/1019: Getting information for h2s_c
# INFO:root:581/1019: Getting information for h2s_e
# INFO:root:582/1019: Getting information for h_c
# INFO:root:583/1019: Getting information for h_e
# INFO:root:584/1019: Getting information for h_p
# INFO:root:585/1019: Getting information for hco3_c
# INFO:root:586/1019: Getting information for hcys__L_c
# INFO:root:587/1019: Getting information for hdca_c
# INFO:root:588/1019: Getting information for hdca_e
# INFO:root:589/1019: Getting information for hdca_p
# INFO:root:590/1019: Getting information for hdcea_c
# INFO:root:591/1019: Getting information for hdcea_p
# INFO:root:592/1019: Getting information for hdcoa_c
# INFO:root:593/1019: Getting information for hemeO_c
# INFO:root:594/1019: Getting information for hg2_c
# INFO:root:595/1019: Getting information for hg2_p
# INFO:root:596/1019: Getting information for his__L_c
# INFO:root:597/1019: Getting information for his__L_e
# INFO:root:598/1019: Getting information for hisgly_c
# INFO:root:599/1019: Getting information for hisgly_e
# INFO:root:600/1019: Getting information for hisgly_p
# INFO:root:601/1019: Getting information for hishis_c
# INFO:root:602/1019: Getting information for hishis_e
# INFO:root:603/1019: Getting information for hishis_p
# INFO:root:604/1019: Getting information for hisp_c
# INFO:root:605/1019: Getting information for histd_c
# INFO:root:606/1019: Getting information for hmbil_c
# INFO:root:607/1019: Getting information for hmbpp_c
# INFO:root:608/1019: Getting information for hom__L_c
# INFO:root:609/1019: Getting information for hpglu_c
# INFO:root:610/1019: Getting information for hpta_c
# INFO:root:611/1019: Getting information for hptcoa_c
# INFO:root:612/1019: Getting information for hpyr_c
# INFO:root:613/1019: Getting information for hx2coa_c
# INFO:root:614/1019: Getting information for hxa_c
# INFO:root:615/1019: Getting information for hxa_e
# INFO:root:616/1019: Getting information for hxa_p
# INFO:root:617/1019: Getting information for hxan_c
# INFO:root:618/1019: Getting information for hxan_e
# INFO:root:619/1019: Getting information for hxcoa_c
# INFO:root:620/1019: Getting information for ichor_c
# INFO:root:621/1019: Getting information for icit_c
# INFO:root:622/1019: Getting information for idp_c
# INFO:root:623/1019: Getting information for igam_c
# INFO:root:624/1019: Getting information for ile__L_c
# INFO:root:625/1019: Getting information for ile__L_e
# INFO:root:626/1019: Getting information for imacp_c
# INFO:root:627/1019: Getting information for imp_c
# INFO:root:628/1019: Getting information for indole_c
# INFO:root:629/1019: Getting information for inost_c
# INFO:root:630/1019: Getting information for inost_e
# INFO:root:631/1019: Getting information for ins_c
# INFO:root:632/1019: Getting information for ipdp_c
# INFO:root:633/1019: Getting information for istfrnA_e
# INFO:root:634/1019: Getting information for istfrnB_e
# INFO:root:635/1019: Getting information for itp_c
# INFO:root:636/1019: Getting information for ivcoa_c
# INFO:root:637/1019: Getting information for k_c
# INFO:root:638/1019: Getting information for k_e
# INFO:root:639/1019: Getting information for k_p
# INFO:root:640/1019: Getting information for lac__D_c
# INFO:root:641/1019: Getting information for lac__D_e
# INFO:root:642/1019: Getting information for lac__D_p
# INFO:root:643/1019: Getting information for lac__L_c
# INFO:root:644/1019: Getting information for lac__L_e
# INFO:root:645/1019: Getting information for lac__L_p
# INFO:root:646/1019: Getting information for lcts_c
# INFO:root:647/1019: Getting information for lcts_e
# INFO:root:648/1019: Getting information for lcts_p
# INFO:root:649/1019: Getting information for leu__L_c
# INFO:root:650/1019: Getting information for leu__L_e
# INFO:root:651/1019: Getting information for leuleu_c
# INFO:root:652/1019: Getting information for leuleu_e
# INFO:root:653/1019: Getting information for leuleu_p
# INFO:root:654/1019: Getting information for lgt__S_c
# INFO:root:655/1019: Getting information for lgt_s_c
# INFO:root:656/1019: Getting information for lnlc_c
# INFO:root:657/1019: Getting information for lnlc_e
# INFO:root:658/1019: Getting information for lnlccoa_c
# INFO:root:659/1019: Getting information for lpam_c
# INFO:root:660/1019: Getting information for lpro_c
# INFO:root:661/1019: Getting information for lys__L_c
# INFO:root:662/1019: Getting information for lys__L_e
# INFO:root:663/1019: Getting information for lys__L_p
# INFO:root:664/1019: Getting information for lysglugly_c
# INFO:root:665/1019: Getting information for lysglugly_e
# INFO:root:666/1019: Getting information for mal__L_c
# INFO:root:667/1019: Getting information for mal__L_e
# INFO:root:668/1019: Getting information for mal__L_p
# INFO:root:669/1019: Getting information for malcoa_c
# INFO:root:670/1019: Getting information for malt1p_c
# INFO:root:671/1019: Getting information for malt_c
# INFO:root:672/1019: Getting information for malt_e
# INFO:root:673/1019: Getting information for malthp_c
# INFO:root:674/1019: Getting information for malthx_c
# INFO:root:675/1019: Getting information for maltpt_c
# INFO:root:676/1019: Getting information for malttr_c
# INFO:root:677/1019: Getting information for maltttr_c
# INFO:root:678/1019: Getting information for maltttrtre_c
# INFO:root:679/1019: Getting information for man1p_c
# INFO:root:680/1019: Getting information for man6p_c
# INFO:root:681/1019: Getting information for man_c
# INFO:root:682/1019: Getting information for man_e
# INFO:root:683/1019: Getting information for mcbtt_c
# INFO:root:684/1019: Getting information for melib_c
# INFO:root:685/1019: Getting information for melib_p
# INFO:root:686/1019: Getting information for met_L_ala__L_c
# INFO:root:687/1019: Getting information for met_L_ala__L_e
# INFO:root:688/1019: Getting information for met__D_c
# INFO:root:689/1019: Getting information for met__D_e
# INFO:root:690/1019: Getting information for met__L_c
# INFO:root:691/1019: Getting information for met__L_e
# INFO:root:692/1019: Getting information for met__L_p
# INFO:root:693/1019: Getting information for methf_c
# INFO:root:694/1019: Getting information for metsox_R__L_c
# INFO:root:695/1019: Getting information for metsox_R__L_e
# INFO:root:696/1019: Getting information for metsox_S__L_c
# INFO:root:697/1019: Getting information for metsox_S__L_e
# INFO:root:698/1019: Getting information for mg2_c
# INFO:root:699/1019: Getting information for mg2_e
# INFO:root:700/1019: Getting information for mg2_p
# INFO:root:701/1019: Getting information for mhpglu_c
# INFO:root:702/1019: Getting information for mi1p__D_c
# INFO:root:703/1019: Getting information for mi3p__D_c
# INFO:root:704/1019: Getting information for micit_c
# INFO:root:705/1019: Getting information for mlthf_c
# INFO:root:706/1019: Getting information for mmcoa__S_c
# INFO:root:707/1019: Getting information for mn2_c
# INFO:root:708/1019: Getting information for mn2_e
# INFO:root:709/1019: Getting information for mn2_p
# INFO:root:710/1019: Getting information for mnl1p_c
# INFO:root:711/1019: Getting information for mnl_e
# INFO:root:712/1019: Getting information for mobd_c
# INFO:root:713/1019: Getting information for mobd_e
# INFO:root:714/1019: Getting information for mql7_c
# INFO:root:715/1019: Getting information for mql8_c
# INFO:root:716/1019: Getting information for mqn7_c
# INFO:root:717/1019: Getting information for mqn8_c
# INFO:root:718/1019: Getting information for msh_c
# INFO:root:719/1019: Getting information for mssg_c
# INFO:root:720/1019: Getting information for mthgxl_c
# INFO:root:721/1019: Getting information for mththf_c
# INFO:root:722/1019: Getting information for mththf_p
# INFO:root:723/1019: Getting information for na1_c
# INFO:root:724/1019: Getting information for na1_e
# INFO:root:725/1019: Getting information for na1_p
# INFO:root:726/1019: Getting information for nac_c
# INFO:root:727/1019: Getting information for nad_c
# INFO:root:728/1019: Getting information for nadh_c
# INFO:root:729/1019: Getting information for nadhx__R_c
# INFO:root:730/1019: Getting information for nadhx__S_c
# INFO:root:731/1019: Getting information for nadp_c
# INFO:root:732/1019: Getting information for nadph_c
# INFO:root:733/1019: Getting information for nadphx__R_c
# INFO:root:734/1019: Getting information for nadphx__S_c
# INFO:root:735/1019: Getting information for ncam_c
# INFO:root:736/1019: Getting information for nh3_c
# INFO:root:737/1019: Getting information for nh4_c
# INFO:root:738/1019: Getting information for nh4_e
# INFO:root:739/1019: Getting information for nh4_p
# INFO:root:740/1019: Getting information for ni2_c
# INFO:root:741/1019: Getting information for ni2_e
# INFO:root:742/1019: Getting information for ni2_p
# INFO:root:743/1019: Getting information for nicrns_c
# INFO:root:744/1019: Getting information for nicrnt_c
# INFO:root:745/1019: Getting information for nmn_c
# INFO:root:746/1019: Getting information for nmn_e
# INFO:root:747/1019: Getting information for no2_c
# INFO:root:748/1019: Getting information for no2_e
# INFO:root:749/1019: Getting information for no2_p
# INFO:root:750/1019: Getting information for nona_c
# INFO:root:751/1019: Getting information for nonacoa_c
# INFO:root:752/1019: Getting information for o2_c
# INFO:root:753/1019: Getting information for o2_e
# INFO:root:754/1019: Getting information for o2_p
# INFO:root:755/1019: Getting information for o2s_c
# INFO:root:756/1019: Getting information for oaa_c
# INFO:root:757/1019: Getting information for occoa_c
# INFO:root:758/1019: Getting information for ocdca_c
# INFO:root:759/1019: Getting information for ocdca_e
# INFO:root:760/1019: Getting information for ocdca_p
# INFO:root:761/1019: Getting information for ocdcea_c
# INFO:root:762/1019: Getting information for ocdcea_e
# INFO:root:763/1019: Getting information for ocdcea_p
# INFO:root:764/1019: Getting information for octa_c
# INFO:root:765/1019: Getting information for octa_e
# INFO:root:766/1019: Getting information for octa_p
# INFO:root:767/1019: Getting information for octdp_c
# INFO:root:768/1019: Getting information for odecoa_c
# INFO:root:769/1019: Getting information for orn_c
# INFO:root:770/1019: Getting information for orn_e
# INFO:root:771/1019: Getting information for orn_p
# INFO:root:772/1019: Getting information for orot5p_c
# INFO:root:773/1019: Getting information for orot_c
# INFO:root:774/1019: Getting information for oxptn_c
# INFO:root:775/1019: Getting information for pa140_c
# INFO:root:776/1019: Getting information for pa140_p
# INFO:root:777/1019: Getting information for pa141_c
# INFO:root:778/1019: Getting information for pa141_p
# INFO:root:779/1019: Getting information for pa160190_c
# INFO:root:780/1019: Getting information for pa160_c
# INFO:root:781/1019: Getting information for pa160_p
# INFO:root:782/1019: Getting information for pa180_c
# INFO:root:783/1019: Getting information for pa180_p
# INFO:root:784/1019: Getting information for pa181_c
# INFO:root:785/1019: Getting information for pa181_p
# INFO:root:786/1019: Getting information for pa190190_c
# INFO:root:787/1019: Getting information for pan4p_c
# INFO:root:788/1019: Getting information for pant__R_c
# INFO:root:789/1019: Getting information for pap_c
# INFO:root:790/1019: Getting information for paps_c
# INFO:root:791/1019: Getting information for pdx5p_c
# INFO:root:792/1019: Getting information for pe120_c
# INFO:root:793/1019: Getting information for pe120_p
# INFO:root:794/1019: Getting information for pe141_c
# INFO:root:795/1019: Getting information for pe141_p
# INFO:root:796/1019: Getting information for pe160_c
# INFO:root:797/1019: Getting information for pe160_p
# INFO:root:798/1019: Getting information for pe161_c
# INFO:root:799/1019: Getting information for pe161_p
# INFO:root:800/1019: Getting information for pea_c
# INFO:root:801/1019: Getting information for pea_e
# INFO:root:802/1019: Getting information for pep_c
# INFO:root:803/1019: Getting information for pg140_c
# INFO:root:804/1019: Getting information for pg140_p
# INFO:root:805/1019: Getting information for pg141_c
# INFO:root:806/1019: Getting information for pg141_p
# INFO:root:807/1019: Getting information for pg160_c
# INFO:root:808/1019: Getting information for pg160_p
# INFO:root:809/1019: Getting information for pg180_c
# INFO:root:810/1019: Getting information for pg180_p
# INFO:root:811/1019: Getting information for pg181_c
# INFO:root:812/1019: Getting information for pg181_p
# INFO:root:813/1019: Getting information for pgp141_c
# INFO:root:814/1019: Getting information for pgp160_c
# INFO:root:815/1019: Getting information for pgp160_p
# INFO:root:816/1019: Getting information for pgp181_c
# INFO:root:817/1019: Getting information for phe__L_c
# INFO:root:818/1019: Getting information for phe__L_e
# INFO:root:819/1019: Getting information for pheme_c
# INFO:root:820/1019: Getting information for pheme_e
# INFO:root:821/1019: Getting information for phom_c
# INFO:root:822/1019: Getting information for phpyr_c
# INFO:root:823/1019: Getting information for pi_c
# INFO:root:824/1019: Getting information for pi_e
# INFO:root:825/1019: Getting information for pi_p
# INFO:root:826/1019: Getting information for pmtcoa_c
# INFO:root:827/1019: Getting information for pnto__R_c
# INFO:root:828/1019: Getting information for pnto__R_e
# INFO:root:829/1019: Getting information for ppa_c
# INFO:root:830/1019: Getting information for ppa_e
# INFO:root:831/1019: Getting information for ppa_p
# INFO:root:832/1019: Getting information for ppap_c
# INFO:root:833/1019: Getting information for ppap_e
# INFO:root:834/1019: Getting information for ppbng_c
# INFO:root:835/1019: Getting information for ppcoa_c
# INFO:root:836/1019: Getting information for pphn_c
# INFO:root:837/1019: Getting information for ppi_c
# INFO:root:838/1019: Getting information for ppp9_c
# INFO:root:839/1019: Getting information for pppg9_c
# INFO:root:840/1019: Getting information for pppi_c
# INFO:root:841/1019: Getting information for pprdn_c
# INFO:root:842/1019: Getting information for pqq_p
# INFO:root:843/1019: Getting information for pqqh2_p
# INFO:root:844/1019: Getting information for pram_c
# INFO:root:845/1019: Getting information for pran_c
# INFO:root:846/1019: Getting information for prbamp_c
# INFO:root:847/1019: Getting information for prbatp_c
# INFO:root:848/1019: Getting information for prfp_c
# INFO:root:849/1019: Getting information for prlp_c
# INFO:root:850/1019: Getting information for pro__L_c
# INFO:root:851/1019: Getting information for pro__L_e
# INFO:root:852/1019: Getting information for pro__L_p
# INFO:root:853/1019: Getting information for progly_c
# INFO:root:854/1019: Getting information for progly_e
# INFO:root:855/1019: Getting information for progly_p
# INFO:root:856/1019: Getting information for prpncoa_c
# INFO:root:857/1019: Getting information for prpp_c
# INFO:root:858/1019: Getting information for psd5p_c
# INFO:root:859/1019: Getting information for pser__L_c
# INFO:root:860/1019: Getting information for pt2coa_c
# INFO:root:861/1019: Getting information for pta_c
# INFO:root:862/1019: Getting information for pta_e
# INFO:root:863/1019: Getting information for pta_p
# INFO:root:864/1019: Getting information for ptcoa_c
# INFO:root:865/1019: Getting information for ptcys_c
# INFO:root:866/1019: Getting information for ptrc_c
# INFO:root:867/1019: Getting information for ptrc_e
# INFO:root:868/1019: Getting information for ptrc_p
# INFO:root:869/1019: Getting information for ptth_c
# INFO:root:870/1019: Getting information for pyam5p_c
# INFO:root:871/1019: Getting information for pydam_c
# INFO:root:872/1019: Getting information for pydx5p_c
# INFO:root:873/1019: Getting information for pydx_c
# INFO:root:874/1019: Getting information for pydxn_c
# INFO:root:875/1019: Getting information for pyovd_kt_e
# INFO:root:876/1019: Getting information for pyovd_kt_p
# INFO:root:877/1019: Getting information for pyr_c
# INFO:root:878/1019: Getting information for pyr_e
# INFO:root:879/1019: Getting information for pyr_p
# INFO:root:880/1019: Getting information for q8_c
# INFO:root:881/1019: Getting information for q8h2_c
# INFO:root:882/1019: Getting information for r1p_c
# INFO:root:883/1019: Getting information for r5p_c
# INFO:root:884/1019: Getting information for rhcys_c
# INFO:root:885/1019: Getting information for rib__D_c
# INFO:root:886/1019: Getting information for rib__D_e
# INFO:root:887/1019: Getting information for rib__D_p
# INFO:root:888/1019: Getting information for ribflv_c
# INFO:root:889/1019: Getting information for ribflv_e
# INFO:root:890/1019: Getting information for rnam_c
# INFO:root:891/1019: Getting information for ru5p__D_c
# INFO:root:892/1019: Getting information for s7p_c
# INFO:root:893/1019: Getting information for s_c
# INFO:root:894/1019: Getting information for s_e
# INFO:root:895/1019: Getting information for salc_c
# INFO:root:896/1019: Getting information for salc_e
# INFO:root:897/1019: Getting information for sarcs_c
# INFO:root:898/1019: Getting information for sbt__D_c
# INFO:root:899/1019: Getting information for sbt__D_e
# INFO:root:900/1019: Getting information for sbzcoa_c
# INFO:root:901/1019: Getting information for scl_c
# INFO:root:902/1019: Getting information for sdhlam_c
# INFO:root:903/1019: Getting information for ser__D_c
# INFO:root:904/1019: Getting information for ser__L_c
# INFO:root:905/1019: Getting information for ser__L_e
# INFO:root:906/1019: Getting information for ser__L_p
# INFO:root:907/1019: Getting information for serglugly_c
# INFO:root:908/1019: Getting information for serglugly_e
# INFO:root:909/1019: Getting information for sheme_c
# INFO:root:910/1019: Getting information for skm5p_c
# INFO:root:911/1019: Getting information for skm_c
# INFO:root:912/1019: Getting information for sl26da_c
# INFO:root:913/1019: Getting information for sl2a6o_c
# INFO:root:914/1019: Getting information for so3_c
# INFO:root:915/1019: Getting information for so3_e
# INFO:root:916/1019: Getting information for so3_p
# INFO:root:917/1019: Getting information for so4_c
# INFO:root:918/1019: Getting information for so4_e
# INFO:root:919/1019: Getting information for spmd_c
# INFO:root:920/1019: Getting information for spmd_e
# INFO:root:921/1019: Getting information for spmd_p
# INFO:root:922/1019: Getting information for stcoa_c
# INFO:root:923/1019: Getting information for stfrnA_c
# INFO:root:924/1019: Getting information for stfrnA_e
# INFO:root:925/1019: Getting information for stfrnB_e
# INFO:root:926/1019: Getting information for suc6p_c
# INFO:root:927/1019: Getting information for sucbz_c
# INFO:root:928/1019: Getting information for succ_c
# INFO:root:929/1019: Getting information for succ_e
# INFO:root:930/1019: Getting information for succ_p
# INFO:root:931/1019: Getting information for succoa_c
# INFO:root:932/1019: Getting information for suchms_c
# INFO:root:933/1019: Getting information for sucr_e
# INFO:root:934/1019: Getting information for sucsal_c
# INFO:root:935/1019: Getting information for tag160_e
# INFO:root:936/1019: Getting information for tag180_e
# INFO:root:937/1019: Getting information for tag181d9_e
# INFO:root:938/1019: Getting information for tag182d9d12_e
# INFO:root:939/1019: Getting information for tartr__D_c
# INFO:root:940/1019: Getting information for tartr__D_p
# INFO:root:941/1019: Getting information for taur_c
# INFO:root:942/1019: Getting information for taur_e
# INFO:root:943/1019: Getting information for tdcoa_c
# INFO:root:944/1019: Getting information for tdecoa_c
# INFO:root:945/1019: Getting information for thdp_c
# INFO:root:946/1019: Getting information for thf_c
# INFO:root:947/1019: Getting information for thm_c
# INFO:root:948/1019: Getting information for thm_e
# INFO:root:949/1019: Getting information for thmmp_c
# INFO:root:950/1019: Getting information for thmpp_c
# INFO:root:951/1019: Getting information for thr__L_c
# INFO:root:952/1019: Getting information for thr__L_e
# INFO:root:953/1019: Getting information for thr__L_p
# INFO:root:954/1019: Getting information for thrp_c
# INFO:root:955/1019: Getting information for thym_c
# INFO:root:956/1019: Getting information for thym_e
# INFO:root:957/1019: Getting information for thymd_c
# INFO:root:958/1019: Getting information for tnt_c
# INFO:root:959/1019: Getting information for tnt_e
# INFO:root:960/1019: Getting information for tnt_p
# INFO:root:961/1019: Getting information for tntmdh_c
# INFO:root:962/1019: Getting information for tntmmh_c
# INFO:root:963/1019: Getting information for trdox_c
# INFO:root:964/1019: Getting information for trdrd_c
# INFO:root:965/1019: Getting information for tre6p_c
# INFO:root:966/1019: Getting information for tre_c
# INFO:root:967/1019: Getting information for tre_e
# INFO:root:968/1019: Getting information for trnaglu_c
# INFO:root:969/1019: Getting information for trp__L_c
# INFO:root:970/1019: Getting information for trp__L_e
# INFO:root:971/1019: Getting information for tsul_c
# INFO:root:972/1019: Getting information for tsul_e
# INFO:root:973/1019: Getting information for ttdca_c
# INFO:root:974/1019: Getting information for ttdca_p
# INFO:root:975/1019: Getting information for ttdcea_c
# INFO:root:976/1019: Getting information for ttdcea_p
# INFO:root:977/1019: Getting information for tyr__L_c
# INFO:root:978/1019: Getting information for tyr__L_e
# INFO:root:979/1019: Getting information for uaGgla_c
# INFO:root:980/1019: Getting information for uaaGgla_c
# INFO:root:981/1019: Getting information for uaagmda_c
# INFO:root:982/1019: Getting information for uaccg_c
# INFO:root:983/1019: Getting information for uacgam_c
# INFO:root:984/1019: Getting information for uagmda_c
# INFO:root:985/1019: Getting information for uama_c
# INFO:root:986/1019: Getting information for uamag_c
# INFO:root:987/1019: Getting information for uamr_c
# INFO:root:988/1019: Getting information for udcpdp_c
# INFO:root:989/1019: Getting information for udcpp_c
# INFO:root:990/1019: Getting information for udp_c
# INFO:root:991/1019: Getting information for udpg_c
# INFO:root:992/1019: Getting information for udpgal_c
# INFO:root:993/1019: Getting information for ugmd_c
# INFO:root:994/1019: Getting information for ugmda_c
# INFO:root:995/1019: Getting information for ump_c
# INFO:root:996/1019: Getting information for uppg3_c
# INFO:root:997/1019: Getting information for ura_c
# INFO:root:998/1019: Getting information for ura_e
# INFO:root:999/1019: Getting information for ura_p
# INFO:root:1000/1019: Getting information for urcan_c
# INFO:root:1001/1019: Getting information for urea_c
# INFO:root:1002/1019: Getting information for uri_c
# INFO:root:1003/1019: Getting information for utp_c
# INFO:root:1004/1019: Getting information for vacc_c
# INFO:root:1005/1019: Getting information for vacccoa_c
# INFO:root:1006/1019: Getting information for val__L_c
# INFO:root:1007/1019: Getting information for val__L_e
# INFO:root:1008/1019: Getting information for xan_c
# INFO:root:1009/1019: Getting information for xan_e
# INFO:root:1010/1019: Getting information for xan_p
# INFO:root:1011/1019: Getting information for xmp_c
# INFO:root:1012/1019: Getting information for xtp_c
# INFO:root:1013/1019: Getting information for xtsn_c
# INFO:root:1014/1019: Getting information for xu5p__D_c
# INFO:root:1015/1019: Getting information for xyl__D_c
# INFO:root:1016/1019: Getting information for xyl__D_e
# INFO:root:1017/1019: Getting information for zn2_c
# INFO:root:1018/1019: Getting information for zn2_e
# INFO:root:1019/1019: Getting information for zn2_p
# WARNING:root:Could not compute integer coefficients for reaction Growth... skipping it for now
# INFO:root:[17.662 s] Finished constructing model.
# INFO:root:[101.474 s] Finished balancibility check. 53 non-pseudo reactions were unbalancable.
# INFO:root:[101.617 s] Finished balancibility check. 256 non-pseudo reactions were unbalancable.
# INFO:root:[34.246 s] Finished adherence optimization.
# INFO:root:[48.048 s] Finished formula optimization.

# %% [markdown]
# If you have access (currently requires an explicit academic license or a subscription) and downloaded the BioCyc flat files, you can pass the corresponding directory as well. Assuming we have already updated all the ids in the last step, we can set _update_ids_ to _False_.
#
# The additional argument is:
# * **biocyc_path**: Directory containing BioCyc flat files.

# %%
#balancer_BioCyc = MCC.MassChargeCuration(model = model, data_path = "./data", update_ids = False, biocyc_path = "./data/23.5/data")

# %% [markdown]
# ## Evaluating the result
# To see the results at a first glance, we can generate a quick visual report, which tells us how many reactions are balanced now, and how many assignments were changed.

# %%
#balancer.generate_visual_report().show()

# %% [markdown]
# ### Metabolite Report
# The algorithm should be able to give a reason for every assignment that it chooses. We can have a look at these reasons in the metabolite report of the balancer.
#
# The report holds valuable information how the algorithm decided which assignment to choose and can be useful during further manual curation. The entries of the resulting DataFrame are the following:
# * **Id**: Id of the metabolite in the model.
# * **Name**: Name of the metabolite in the model.
# * **Determined Formula**: Formula that was assigned by the algorithm.
# * **Determined Charge**: Charge that was assigned by the algorithm.
# * **Previous Formula**: Formula that was assigned before the algorithm.
# * **Previous Charge**: Charge that was assigned before the algorithm.
# * **Inferrence Type**: Category of how the assignment was determined.
#     - Unconstrained: No information about the metabolite was found or only incomplete (wildcard containing) formulae were found and we could not find a concrete formula either. Should contain a wildcard.
#     - Inferred: No information about the metabolite was found or only incomplete (wildcard containing formulae were found, however we arrived at a concrete formula. Should not contain a wildcard.
#     - Clean: Information about the metabolite was found and used.
# * **Reasoning**: Reasoning how the assignment was determined. Can contain:
#     - database name:database identifier: The formula could be found in this database under this identifier.
#     - (unconstrained) Target: This assignment was chosen because it is the same as in the original (target) model. Unconstrained means that the original (target) model seemed to be missing a wildcard symbol that was thus added.
#     - Reaction_id (metabolite id -> Reasoning...): The assignment for this metabolite must follow from other reasons. The given reaction id and metabolite reasons make it so that if the model must be balanced, this metabolite must have the determined assignment.
#     - Used Databases: The databases which back up the determined assignment.
#     - Previous Databases: The databases which back up the previous assignment.

# %%
metabolite_report_df = balancer.generate_metabolite_report()
metabolite_report_df[::200]
# Out:
#                 Id                                               Name  \
# 0     M_12dgr140_c  1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 200   M_12dgr160_c   1,2-Diacyl-sn-glycerol (dihexadecanoyl, n-C16:0)
# 400        M_for_p                                            Formate
# 600     M_23dhdp_c                            2,3-Dihydrodipicolinate
# 800       M_mqn8_c                                      Menaquinone 8
# 1000      M_dmlz_c               6,7-Dimethyl-8-(1-D-ribityl)lumazine
#
#      Determined Formula  Determined Charge Previous Formula  Previous Charge  \
# 0              C31H60O5                  0         C31H60O5                0
# 200            C35H68O5                  0         C35H68O5                0
# 400                CHO2                 -1             CHO2               -1
# 600             C7H5NO4                 -2          C7H5NO4               -2
# 800            C51H72O2                  0         C51H72O2                0
# 1000         C13H17N4O6                 -1       C13H19N4O6                0
#
#      Inferrence Type                                          Reasoning  \
# 0           Inferred                                             Target
# 200            Clean                Target & metanetx.chemical:MNXM3132
# 400            Clean  Target & metanetx.chemical:MNXM39, biocyc:META...
# 600            Clean  Target & seed.compound:cpd02120, biocyc:META:2...
# 800            Clean  Target & biocyc:META:CPD-9728, metanetx.chemic...
# 1000           Clean  seed.compound:cpd02656, biocyc:META:DIMETHYL-D...
#
#                                          Used Databases  \
# 0
# 200                          metanetx.chemical:MNXM3132
# 400       metanetx.chemical:MNXM39, biocyc:META:FORMATE
# 600   seed.compound:cpd02120, biocyc:META:2-3-DIHYDR...
# 800   biocyc:META:CPD-9728, metanetx.chemical:MNXM50...
# 1000  seed.compound:cpd02656, biocyc:META:DIMETHYL-D...
#
#                                      Previous Databases Similarity
# 0                                                             Same
# 200                          metanetx.chemical:MNXM3132       Same
# 400       metanetx.chemical:MNXM39, biocyc:META:FORMATE       Same
# 600   seed.compound:cpd02120, biocyc:META:2-3-DIHYDR...       Same
# 800   biocyc:META:CPD-9728, metanetx.chemical:MNXM50...       Same
# 1000                                                          Diff

# %% [markdown]
# Usually we are interested in the assignments which differ from the original report. We can do this by indexing the Dataframe accordingly.

# %%
# If you like to see the entire report, uncomment the following line
#pandas.set_option("display.max_row", None)
metabolite_report_df[metabolite_report_df["Similarity"] != "Same"]
# Out:
#                   Id                                      Name  \
# 120         M_abg4_e                 4-aminobenzoate-glutamate
# 121       M_glyglu_e                       L glycinylglutamate
# 122    M_serglugly_e       Serine-glutamine-glycine tripeptide
# 123   M_R_3hcmrs7e_c               3 hydroxy cis myristol 7 en
# 124     M_R_3hdcaa_c                    3 hydroxydecanoic acid
# ...              ...                                       ...
# 1014       M_udcpp_c                    Undecaprenyl phosphate
# 1015       M_gdptp_c  Guanosine 3'-diphosphate 5'-triphosphate
# 1016         M_pqq_p                  Pyrroloquinoline-quinone
# 1017      M_ribflv_c                     Riboflavin C17H20N4O6
# 1018      M_ribflv_e                     Riboflavin C17H20N4O6
#
#      Determined Formula  Determined Charge Previous Formula  Previous Charge  \
# 120          C12H11N2O5                 -3       C12H11N2O5                0
# 121           C7H11N2O5                 -1        C7H11N2O5                0
# 122          C10H18N3O8                 -1       C10H18N3O8                0
# 123            C14H25O3                 -1         C14H25O3                0
# 124            C10H19O3                 -1         C10H19O3                0
# ...                 ...                ...              ...              ...
# 1014          C55H89O4P                 -2        C55H90O4P               -1
# 1015      C10H12N5O20P5                 -6    C10H11N5O20P5                0
# 1016          C14H3N2O8                 -3        C14H2N2O8                0
# 1017         C17H19N4O6                 -1       C17H22N4O6                0
# 1018         C17H19N4O6                 -1       C17H22N4O6                0
#
#      Inferrence Type                                          Reasoning  \
# 120         Inferred                                      R_EX_abg4_e:
# 121         Inferred                                    R_EX_glyglu_e:
# 122         Inferred                                 R_EX_serglugly_e:
# 123         Inferred  R_RHACOAE141: (coa_c -> Target & biocyc:META:C...
# 124         Inferred  R_RHACOAE100: (coa_c -> Target & biocyc:META:C...
# ...              ...                                                ...
# 1014           Clean  seed.compound:cpd00286, biocyc:META:UNDECAPREN...
# 1015           Clean  biocyc:META:GDP-TP, seed.compound:cpd02740, me...
# 1016           Clean  metanetx.chemical:MNXM601, biocyc:META:PQQ, se...
# 1017           Clean  seed.compound:cpd00220, metanetx.chemical:MNXM...
# 1018           Clean  seed.compound:cpd00220, metanetx.chemical:MNXM...
#
#                                          Used Databases Previous Databases  \
# 120
# 121
# 122
# 123
# 124
# ...                                                 ...                ...
# 1014  seed.compound:cpd00286, biocyc:META:UNDECAPREN...
# 1015  biocyc:META:GDP-TP, seed.compound:cpd02740, me...
# 1016  metanetx.chemical:MNXM601, biocyc:META:PQQ, se...
# 1017  seed.compound:cpd00220, metanetx.chemical:MNXM...
# 1018  seed.compound:cpd00220, metanetx.chemical:MNXM...
#
#        Similarity
# 120          Diff
# 121          Diff
# 122          Diff
# 123          Diff
# 124          Diff
# ...           ...
# 1014  Proton Diff
# 1015         Diff
# 1016         Diff
# 1017         Diff
# 1018         Diff
#
# [193 rows x 11 columns]

# %% [markdown]
# We might also be interested in all assignments which are not backed by a database:

# %%
metabolite_report_df[metabolite_report_df["Used Databases"] == ""]
# Out:
#                Id                                               Name  \
# 0    M_12dgr140_c  1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 1    M_12dgr140_p  1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 2      M_1ag160_e                  1 Acyl sn glycerol  hexadecanoate
# 3      M_1ag180_e                  1 Acyl sn glycerol  octadecanoate
# 4    M_1ag181d9_e                        1 Acyl sn glycerol  nC181d9
# ..            ...                                                ...
# 186      M_ugmd_c  UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl...
# 187      M_ddca_p                              Dodecanoate (n-C12:0)
# 188     M_hdcea_c                            Hexadecenoate (n-C16:1)
# 189     M_ttdca_c                           Tetradecanoate (n-C14:0)
# 192     M_trdox_c                               Oxidized thioredoxin
#
#     Determined Formula  Determined Charge Previous Formula  Previous Charge  \
# 0             C31H60O5                  0         C31H60O5                0
# 1             C31H60O5                  0         C31H60O5                0
# 2             C19H38O4                  0         C19H38O4                0
# 3             C21H42O4                  0         C21H42O4                0
# 4             C21H40O4                  0         C21H40O4                0
# ..                 ...                ...              ...              ...
# 186      C35H55N7O26P2                  0    C35H51N7O26P2               -4
# 187           C12H24O2                  0         C12H23O2               -1
# 188           C16H30O2                  0         C16H29O2               -1
# 189           C14H28O2                  0         C14H27O2               -1
# 192             Fe2RS6                  0     C10H12N4O4S2                0
#
#     Inferrence Type                                          Reasoning  \
# 0          Inferred                                             Target
# 1          Inferred                                             Target
# 2          Inferred                                             Target
# 3          Inferred                                             Target
# 4          Inferred                                             Target
# ..              ...                                                ...
# 186        Inferred  R_UGMDDS: (adp_c -> Target & biocyc:META:ADP; ...
# 187        Inferred  R_FACOAL120t2pp: (amp_c -> Target & biocyc:MET...
# 188        Inferred  R_KAS7: (co2_c -> Target & seed.compound:cpd00...
# 189        Inferred  R_FAO1: (accoa_c -> Target & biocyc:META:ACETY...
# 192   Unconstrained  R_METSOXR1: (h2o_c -> Target & biocyc:META:WAT...
#
#     Used Databases Previous Databases   Similarity
# 0                                             Same
# 1                                             Same
# 2                                             Same
# 3                                             Same
# 4                                             Same
# ..             ...                ...          ...
# 186                                    Proton Diff
# 187                                    Proton Diff
# 188                                    Proton Diff
# 189                                    Proton Diff
# 192                                           Diff
#
# [191 rows x 11 columns]

# %% [markdown]
# ### Reaction Report
# Finally, especially for further curation, we might be interested in the remaining imbalanced reactions. For this the algorithm can also provide a report.
#
# The report also includes reactions which are technically balanced but where many protons had to be added to arrive at that result.
#
# The fields are as follows:
# * **Id**: Id of the reaction in the model.
# * **Unbalanced Reaction**: Name of the reaction in the model and corresponding equation.
# * **Unbalanced Type**: Type of imbalance. Can be both Mass and charge, only mass, only charge or high proton count.
# * **Reason**: Set of reactions which caused the reaction to be imbalanced. This effectively means that these reactions could not be balanced together. The sets are minimal, but for example for BTS2, it would not help to remove HCYSMT, as BTS2 would require protons to have no charge and HCYSMT is only one of many reactions which then would not be balanced.
# * **Shared Metabolites**: Metabolites which are shared between the reactions which are listed in Reason. Can give an indication where the problem might lie.
# * **Mass Difference**: Mass imbalance.
# * **Charge Difference**: Charge imbalance.

# %%
balancer.generate_reaction_report()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0330e974ed7d> in <module>
# ----> 1 balancer.generate_reaction_report()
#
# ~/Systems Biology HiWi/MassChargeCuration/MCC/Balancing/MCC.py in generate_reaction_report(self, filename, proton_threshold)
#     267                                         "Unbalanced Type" : ", ".join(unbalance_type),
#     268                                         "Reason" : ", ".join(reason),
# --> 269                                         "Shared Metabolites" : ", ".join([m.id for m in get_shared_metabolites(reason)]),
#     270                                         "Mass Difference": difference_string(balance["mass"]),
#     271                                         "Charge Difference" : balance["charge"]
#
# ~/Systems Biology HiWi/MassChargeCuration/MCC/Balancing/MCC.py in get_shared_metabolites(reaction_ids)
#     242             metabolites = []
#     243             for reaction_id in reaction_ids:
# --> 244                 metabolites.append(set(self.model.reactions.get_by_id(reaction_id).metabolites.keys()))
#     245             if len(metabolites) == 0: return set()
#     246             else: return set.intersection(*metabolites)
#
# AttributeError: 'ListOfReactions' object has no attribute 'get_by_id'

# %% [markdown]
# ### Writing Files
# The mass charge curation writes directly to the model that was given to it. Thus, if we want to write our model, we can just pass the model to cobrapy. If you want to keep your old model, you should make sure to not overwrite it here.

# %%
cobra.io.write_sbml_model(model, f"{model.id}_MCC.xml")

# %% [markdown]
# For the reports, we can add filenames to the functions to write the visual report to a .png file and the metabolite and reaction DataFrames to .csv files.

# %%
balancer.generate_visual_report(f"{model.id}_visual")
balancer.generate_metabolite_report(f"{model.id}_metabolites")
balancer.generate_reaction_report(f"{model.id}_reactions")
pass
